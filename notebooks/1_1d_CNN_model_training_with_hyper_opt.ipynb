# %% [markdown]
# # 0. Imports

# %%
import os
import warnings

import numpy as np
import pandas as pd
from pandas.errors import SettingWithCopyWarning

warnings.simplefilter(action="ignore", category=SettingWithCopyWarning)
warnings.simplefilter(action="ignore", category=FutureWarning)

import datetime

import matplotlib.pyplot as plt
import optuna
import torch
import torch.optim as optim
from optuna.trial import TrialState
from sklearn.preprocessing import StandardScaler
from torch import nn
from torch.utils.data import DataLoader, TensorDataset
from torchsummary import summary
from torchvision import datasets, transforms
from torchvision.transforms import ToTensor
from tqdm import tqdm

torch.manual_seed(41)

# %% [markdown]
# # 1. 1-D CNN Setup

# %% [markdown]
# ## 1.1. Dataset and DataLoader Read In

# %%
feature_names = pd.read_csv(
    "../data/fine_dust_dataset.csv", nrows=1
).columns.tolist()

# %%
trainloader = torch.load("../models/trainloader.pth")
validloader = torch.load("../models/validloader.pth")
testloader = torch.load("../models/testloader.pth")

# %%
# Sample Check

weather, label = next(iter(trainloader))
i = np.random.randint(0, 28)
fig, axs = plt.subplots(nrows=2, ncols=4)
r = 0
c = 0
for j in range(8):
    axs[r, c].plot(weather[i, j, :])
    axs[r, c].set_title(f"{feature_names[j]}")
    if c < 3:
        c += 1
    else:
        r += 1
        c = 0
fig.suptitle(f"Air Quality Bad? {bool(label[i])}")
plt.tight_layout()
plt.show();

# %% [markdown]
# ## 1.2. Preparation of 1-D CNN

# %%
class ConvolutionalNeuralNetwork(nn.Module):
    def __init__(
        self,
        trial,
        num_filter_1,
        num_filter_2,
        num_filter_3,
        num_fc,
        drop_out_rate_1,
        drop_out_rate_2,
        drop_out_rate_3,
    ):
        """
        Parameters:
            - trial (optuna.trial._trial.Trial): Optuna trial
            - num_filters (int):                 Number of filters of conv layers
            - num_fc (int):                      Number of neurons of FC layers
            - drop_out_rate (float):             Dropout ratio
        """
        super(ConvolutionalNeuralNetwork, self).__init__()
        self.main = nn.Sequential(
            nn.Conv1d(8, num_filter_1, kernel_size=3, padding=1),  # num_filter_1, 24
            nn.ReLU(),
            nn.MaxPool1d(2),  # num_filter_1, 12
            nn.Dropout(drop_out_rate_1),
            nn.Conv1d(
                num_filter_1, num_filter_2, kernel_size=3, padding=1
            ),  # num_filter_2, 12
            nn.ReLU(),
            nn.MaxPool1d(2),  # num_filter_2,  6
            nn.Dropout(drop_out_rate_2),
            nn.Conv1d(
                num_filter_2, num_filter_3, kernel_size=3, padding=1
            ),  # num_filter_3, 6
            nn.ReLU(),
            nn.MaxPool1d(2),  # num_filter_3, 3
            nn.Dropout(drop_out_rate_3),
            nn.Flatten(),  # num_filter_3 x 3
            nn.Linear(num_filter_3 * 3, num_fc),  # num_fc
            nn.ReLU(),
            nn.Linear(num_fc, 1),
        )

    def forward(self, x):
        logits = self.main(x)
        return logits

# %%
def weights_init(m):
    if isinstance(m, nn.Conv1d):
        torch.nn.init.xavier_uniform_(m.weight.data)

# %% [markdown]
# ## 1.3. Preparation of Functions for Optuna Hyperparameter Tuning

# %%
def train(network, optimizer, trainloader, criterion):
    """Trains the model.

    Parameters:
        - network (__main__.Net):              The CNN
        - optimizer (torch.optim.<optimizer>): The optimizer for the CNN
    """
    network.train()  # Set the module in training mode 
    for batch_i, (X, y) in enumerate(trainloader):  # For each batch

        optimizer.zero_grad()  # Clear gradients
        y_hat = network(X)  # Forward propagation
        loss = criterion(
            y_hat, y.unsqueeze(1)
        )  # Compute loss (negative log likelihood: −log(y))
        loss.backward()  # Compute gradients
        optimizer.step()  # Update weights

# %%
def test(network, validloader, criterion):
    """Tests the model.

    Parameters:
        - network (__main__.Net): The CNN

    Returns:
        - accuracy_test (torch.Tensor): The test accuracy
    """
    network.eval()  # Set the module in evaluation mode 

    valid_batch_acc = 0

    with torch.no_grad():  # Disable gradient calculation 
        for batch_i, (X, y) in enumerate(validloader):  # For each batch

            y_hat = network(X)  # Forward propagation
            y_hat_labels = torch.sigmoid(y_hat) > 0.5
            valid_batch_acc += (
                (y_hat_labels.squeeze() == y).type(torch.float32).mean().item()
            )

    valid_accuracy = valid_batch_acc / len(validloader)  # accuracy

    return valid_accuracy

# %%
def objective(trial):
    """Objective function to be optimized by Optuna.

    Hyperparameters chosen to be optimized: optimizer, learning rate,
    number of filters, number of neurons in fully connected layer, and dropout values,

    Inputs:
        - trial (optuna.trial._trial.Trial): Optuna trial
    Returns:
        - accuracy(torch.Tensor): The test accuracy. Parameter to be maximized.
    """

    # Define range of values to be tested for the hyperparameters
    num_filter_1 = trial.suggest_int("num_filter_1", 4, 32, 4)
    num_filter_2 = trial.suggest_int("num_filter_2", 4, 32, 4)
    num_filter_3 = trial.suggest_int("num_filter_3", 4, 32, 4)
    num_fc = trial.suggest_int("num_fc", 2, 12, 2)
    drop_out_rate_1 = trial.suggest_float("drop_out_rate_1", 0.1, 0.35, step=0.05)
    drop_out_rate_2 = trial.suggest_float("drop_out_rate_2", 0.1, 0.35, step=0.05)
    drop_out_rate_3 = trial.suggest_float("drop_out_rate_3", 0.1, 0.35, step=0.05)

    # Generate the model
    model = ConvolutionalNeuralNetwork(
        trial,
        num_filter_1,
        num_filter_2,
        num_filter_3,
        num_fc,
        drop_out_rate_1,
        drop_out_rate_2,
        drop_out_rate_3,
    )  # .to(device)

    # Generate the optimizers
    optimizer_name = trial.suggest_categorical(
        "optimizer", ["Adam", "RMSprop", "SGD"]
    )  # Optimizers
    lr = trial.suggest_float("lr", 1e-5, 1e-1, log=True)  # Learning rates
    optimizer = getattr(optim, optimizer_name)(model.parameters(), lr=lr)

    for epoch in range(n_epochs):
        train(model, optimizer, trainloader, criterion)  # Train the model
        accuracy = test(model, validloader, criterion)  # Evaluate the model

        # For pruning (stops trial early if not promising)
        trial.report(accuracy, epoch)
        # Handle pruning based on the intermediate value.
        if trial.should_prune():
            raise optuna.exceptions.TrialPruned()

    return accuracy

# %% [markdown]
# # 2. Hyperparameter Optimization Using Optuna

# %% [markdown]
# ## 2.1. Hyperparameter Optimization

# %%
n_epochs = 100  # Number of training epochs
number_of_trials = 200  # Number of Optuna trials
criterion = nn.BCEWithLogitsLoss()

# %%
study = optuna.create_study(direction="maximize")
# Out:
# [I 2023-07-30 11:09:21,389] A new study created in memory with name: no-name-5d4cff2d-f87a-40a6-8d46-92242f680629

# %%
study.optimize(objective, n_trials=number_of_trials)
# Out:
# [I 2023-07-30 11:10:50,327] Trial 0 finished with value: 0.7770270258188248 and parameters: {'num_filter_1': 8, 'num_filter_2': 16, 'num_filter_3': 4, 'num_fc': 4, 'drop_out_rate_1': 0.25, 'drop_out_rate_2': 0.25, 'drop_out_rate_3': 0.25, 'optimizer': 'Adam', 'lr': 0.00027205697956488956}. Best is trial 0 with value: 0.7770270258188248.
# [I 2023-07-30 11:12:01,204] Trial 1 finished with value: 0.760810808958234 and parameters: {'num_filter_1': 12, 'num_filter_2': 32, 'num_filter_3': 28, 'num_fc': 4, 'drop_out_rate_1': 0.35, 'drop_out_rate_2': 0.35, 'drop_out_rate_3': 0.25, 'optimizer': 'RMSprop', 'lr': 2.6917883038381803e-05}. Best is trial 0 with value: 0.7770270258188248.
# [I 2023-07-30 11:13:36,595] Trial 2 finished with value: 0.7891891836314588 and parameters: {'num_filter_1': 12, 'num_filter_2': 8, 'num_filter_3': 28, 'num_fc': 2, 'drop_out_rate_1': 0.35, 'drop_out_rate_2': 0.15000000000000002, 'drop_out_rate_3': 0.1, 'optimizer': 'RMSprop', 'lr': 0.00583825455437186}. Best is trial 2 with value: 0.7891891836314588.
# [I 2023-07-30 11:15:06,750] Trial 3 finished with value: 0.44729730225092657 and parameters: {'num_filter_1': 24, 'num_filter_2': 8, 'num_filter_3': 28, 'num_fc': 4, 'drop_out_rate_1': 0.25, 'drop_out_rate_2': 0.1, 'drop_out_rate_3': 0.1, 'optimizer': 'SGD', 'lr': 4.47048675018432e-05}. Best is trial 2 with value: 0.7891891836314588.
# [I 2023-07-30 11:16:49,568] Trial 4 finished with value: 0.7662162188742612 and parameters: {'num_filter_1': 16, 'num_filter_2': 12, 'num_filter_3': 4, 'num_fc': 12, 'drop_out_rate_1': 0.15000000000000002, 'drop_out_rate_2': 0.30000000000000004, 'drop_out_rate_3': 0.35, 'optimizer': 'Adam', 'lr': 0.0006278761200687167}. Best is trial 2 with value: 0.7891891836314588.
# [I 2023-07-30 11:18:06,782] Trial 5 finished with value: 0.799999993395161 and parameters: {'num_filter_1': 8, 'num_filter_2': 12, 'num_filter_3': 28, 'num_fc': 8, 'drop_out_rate_1': 0.15000000000000002, 'drop_out_rate_2': 0.35, 'drop_out_rate_3': 0.2, 'optimizer': 'Adam', 'lr': 0.00048688846473517313}. Best is trial 5 with value: 0.799999993395161.
# [I 2023-07-30 11:19:36,089] Trial 6 finished with value: 0.8256756743869266 and parameters: {'num_filter_1': 24, 'num_filter_2': 16, 'num_filter_3': 24, 'num_fc': 6, 'drop_out_rate_1': 0.35, 'drop_out_rate_2': 0.2, 'drop_out_rate_3': 0.1, 'optimizer': 'RMSprop', 'lr': 0.0038095116489375554}. Best is trial 6 with value: 0.8256756743869266.
# [I 2023-07-30 11:19:36,998] Trial 7 pruned.
# [I 2023-07-30 11:19:41,762] Trial 8 pruned.
# [I 2023-07-30 11:19:42,702] Trial 9 pruned.
# [I 2023-07-30 11:19:45,148] Trial 10 pruned.
# [I 2023-07-30 11:21:00,941] Trial 11 finished with value: 0.7986486473598996 and parameters: {'num_filter_1': 4, 'num_filter_2': 24, 'num_filter_3': 20, 'num_fc': 8, 'drop_out_rate_1': 0.2, 'drop_out_rate_2': 0.2, 'drop_out_rate_3': 0.15000000000000002, 'optimizer': 'Adam', 'lr': 0.0022392317690459996}. Best is trial 6 with value: 0.8256756743869266.
# [I 2023-07-30 11:21:01,886] Trial 12 pruned.
# [I 2023-07-30 11:22:11,187] Trial 13 finished with value: 0.8067567533737904 and parameters: {'num_filter_1': 20, 'num_filter_2': 20, 'num_filter_3': 24, 'num_fc': 10, 'drop_out_rate_1': 0.15000000000000002, 'drop_out_rate_2': 0.15000000000000002, 'drop_out_rate_3': 0.2, 'optimizer': 'Adam', 'lr': 0.0026359984860542403}. Best is trial 6 with value: 0.8256756743869266.
# [I 2023-07-30 11:22:11,898] Trial 14 pruned.
# [I 2023-07-30 11:22:14,691] Trial 15 pruned.
# [I 2023-07-30 11:23:24,683] Trial 16 finished with value: 0.8081081050473291 and parameters: {'num_filter_1': 24, 'num_filter_2': 20, 'num_filter_3': 24, 'num_fc': 10, 'drop_out_rate_1': 0.30000000000000004, 'drop_out_rate_2': 0.2, 'drop_out_rate_3': 0.15000000000000002, 'optimizer': 'Adam', 'lr': 0.001700377818046732}. Best is trial 6 with value: 0.8256756743869266.
# [I 2023-07-30 11:24:20,544] Trial 17 finished with value: 0.8108108051725336 and parameters: {'num_filter_1': 28, 'num_filter_2': 28, 'num_filter_3': 12, 'num_fc': 6, 'drop_out_rate_1': 0.30000000000000004, 'drop_out_rate_2': 0.2, 'drop_out_rate_3': 0.15000000000000002, 'optimizer': 'RMSprop', 'lr': 0.0013742955719460571}. Best is trial 6 with value: 0.8256756743869266.
# [I 2023-07-30 11:24:21,176] Trial 18 pruned.
# [I 2023-07-30 11:24:21,760] Trial 19 pruned.
# [I 2023-07-30 11:25:40,298] Trial 20 finished with value: 0.8121621568460722 and parameters: {'num_filter_1': 32, 'num_filter_2': 28, 'num_filter_3': 8, 'num_fc': 6, 'drop_out_rate_1': 0.25, 'drop_out_rate_2': 0.30000000000000004, 'drop_out_rate_3': 0.1, 'optimizer': 'RMSprop', 'lr': 0.001119585084365744}. Best is trial 6 with value: 0.8256756743869266.
# [I 2023-07-30 11:26:59,070] Trial 21 finished with value: 0.8121621576515404 and parameters: {'num_filter_1': 32, 'num_filter_2': 28, 'num_filter_3': 8, 'num_fc': 6, 'drop_out_rate_1': 0.25, 'drop_out_rate_2': 0.30000000000000004, 'drop_out_rate_3': 0.1, 'optimizer': 'RMSprop', 'lr': 0.001313084203876011}. Best is trial 6 with value: 0.8256756743869266.
# [I 2023-07-30 11:28:17,266] Trial 22 finished with value: 0.8013513486933064 and parameters: {'num_filter_1': 32, 'num_filter_2': 32, 'num_filter_3': 8, 'num_fc': 6, 'drop_out_rate_1': 0.25, 'drop_out_rate_2': 0.30000000000000004, 'drop_out_rate_3': 0.1, 'optimizer': 'RMSprop', 'lr': 0.004822532221301256}. Best is trial 6 with value: 0.8256756743869266.
# [I 2023-07-30 11:29:34,760] Trial 23 finished with value: 0.818918913602829 and parameters: {'num_filter_1': 32, 'num_filter_2': 24, 'num_filter_3': 8, 'num_fc': 8, 'drop_out_rate_1': 0.2, 'drop_out_rate_2': 0.30000000000000004, 'drop_out_rate_3': 0.1, 'optimizer': 'RMSprop', 'lr': 0.0008867424185472083}. Best is trial 6 with value: 0.8256756743869266.
# [I 2023-07-30 11:29:40,894] Trial 24 pruned.
# [I 2023-07-30 11:29:41,769] Trial 25 pruned.
# [I 2023-07-30 11:29:42,544] Trial 26 pruned.
# [I 2023-07-30 11:29:43,185] Trial 27 pruned.
# [I 2023-07-30 11:30:54,438] Trial 28 finished with value: 0.80135134708237 and parameters: {'num_filter_1': 16, 'num_filter_2': 28, 'num_filter_3': 32, 'num_fc': 6, 'drop_out_rate_1': 0.25, 'drop_out_rate_2': 0.30000000000000004, 'drop_out_rate_3': 0.15000000000000002, 'optimizer': 'RMSprop', 'lr': 0.002242135252470132}. Best is trial 6 with value: 0.8256756743869266.
# [I 2023-07-30 11:30:55,317] Trial 29 pruned.
# [I 2023-07-30 11:30:56,195] Trial 30 pruned.
# [I 2023-07-30 11:32:13,248] Trial 31 finished with value: 0.7986486473598996 and parameters: {'num_filter_1': 32, 'num_filter_2': 28, 'num_filter_3': 8, 'num_fc': 6, 'drop_out_rate_1': 0.25, 'drop_out_rate_2': 0.30000000000000004, 'drop_out_rate_3': 0.1, 'optimizer': 'RMSprop', 'lr': 0.0010232565320965413}. Best is trial 6 with value: 0.8256756743869266.
# [I 2023-07-30 11:33:31,589] Trial 32 finished with value: 0.8121621588597426 and parameters: {'num_filter_1': 32, 'num_filter_2': 32, 'num_filter_3': 8, 'num_fc': 6, 'drop_out_rate_1': 0.25, 'drop_out_rate_2': 0.35, 'drop_out_rate_3': 0.1, 'optimizer': 'RMSprop', 'lr': 0.0015429257399668585}. Best is trial 6 with value: 0.8256756743869266.
# [I 2023-07-30 11:34:26,907] Trial 33 finished with value: 0.804054049221245 and parameters: {'num_filter_1': 28, 'num_filter_2': 32, 'num_filter_3': 12, 'num_fc': 4, 'drop_out_rate_1': 0.35, 'drop_out_rate_2': 0.35, 'drop_out_rate_3': 0.1, 'optimizer': 'RMSprop', 'lr': 0.005349851764314642}. Best is trial 6 with value: 0.8256756743869266.
# [I 2023-07-30 11:35:43,941] Trial 34 finished with value: 0.8013513482905723 and parameters: {'num_filter_1': 32, 'num_filter_2': 32, 'num_filter_3': 8, 'num_fc': 8, 'drop_out_rate_1': 0.25, 'drop_out_rate_2': 0.35, 'drop_out_rate_3': 0.1, 'optimizer': 'RMSprop', 'lr': 0.0015486365578039564}. Best is trial 6 with value: 0.8256756743869266.
# [I 2023-07-30 11:35:46,242] Trial 35 pruned.
# [I 2023-07-30 11:35:47,060] Trial 36 pruned.
# [I 2023-07-30 11:35:49,572] Trial 37 pruned.
# [I 2023-07-30 11:35:50,389] Trial 38 pruned.
# [I 2023-07-30 11:36:07,930] Trial 39 pruned.
# [I 2023-07-30 11:36:10,986] Trial 40 pruned.
# [I 2023-07-30 11:36:12,575] Trial 41 pruned.
# [I 2023-07-30 11:36:16,368] Trial 42 pruned.
# [I 2023-07-30 11:36:19,443] Trial 43 pruned.
# [I 2023-07-30 11:37:47,225] Trial 44 finished with value: 0.8027027019777814 and parameters: {'num_filter_1': 8, 'num_filter_2': 24, 'num_filter_3': 12, 'num_fc': 8, 'drop_out_rate_1': 0.2, 'drop_out_rate_2': 0.30000000000000004, 'drop_out_rate_3': 0.1, 'optimizer': 'RMSprop', 'lr': 0.0027422154947776244}. Best is trial 6 with value: 0.8256756743869266.
# [I 2023-07-30 11:39:14,754] Trial 45 finished with value: 0.8229729702343812 and parameters: {'num_filter_1': 28, 'num_filter_2': 12, 'num_filter_3': 16, 'num_fc': 6, 'drop_out_rate_1': 0.25, 'drop_out_rate_2': 0.35, 'drop_out_rate_3': 0.15000000000000002, 'optimizer': 'Adam', 'lr': 0.0019630276688041488}. Best is trial 6 with value: 0.8256756743869266.
# [I 2023-07-30 11:40:42,276] Trial 46 finished with value: 0.8054054000893155 and parameters: {'num_filter_1': 24, 'num_filter_2': 12, 'num_filter_3': 24, 'num_fc': 10, 'drop_out_rate_1': 0.30000000000000004, 'drop_out_rate_2': 0.35, 'drop_out_rate_3': 0.15000000000000002, 'optimizer': 'Adam', 'lr': 0.00792705873362551}. Best is trial 6 with value: 0.8256756743869266.
# [I 2023-07-30 11:40:43,188] Trial 47 pruned.
# [I 2023-07-30 11:40:44,111] Trial 48 pruned.
# [I 2023-07-30 11:40:45,342] Trial 49 pruned.
# [I 2023-07-30 11:42:10,144] Trial 50 finished with value: 0.797297296089095 and parameters: {'num_filter_1': 20, 'num_filter_2': 4, 'num_filter_3': 16, 'num_fc': 12, 'drop_out_rate_1': 0.2, 'drop_out_rate_2': 0.15000000000000002, 'drop_out_rate_3': 0.1, 'optimizer': 'Adam', 'lr': 0.004187291243496239}. Best is trial 6 with value: 0.8256756743869266.
# [I 2023-07-30 11:42:11,088] Trial 51 pruned.
# [I 2023-07-30 11:42:12,161] Trial 52 pruned.
# [I 2023-07-30 11:42:17,285] Trial 53 pruned.
# [I 2023-07-30 11:42:18,064] Trial 54 pruned.
# [I 2023-07-30 11:42:18,647] Trial 55 pruned.
# [I 2023-07-30 11:42:19,458] Trial 56 pruned.
# [I 2023-07-30 11:43:20,762] Trial 57 finished with value: 0.7918918889922064 and parameters: {'num_filter_1': 20, 'num_filter_2': 32, 'num_filter_3': 32, 'num_fc': 4, 'drop_out_rate_1': 0.15000000000000002, 'drop_out_rate_2': 0.30000000000000004, 'drop_out_rate_3': 0.15000000000000002, 'optimizer': 'Adam', 'lr': 0.0031985604144442615}. Best is trial 6 with value: 0.8256756743869266.
# [I 2023-07-30 11:43:21,691] Trial 58 pruned.
# [I 2023-07-30 11:43:22,592] Trial 59 pruned.
# [I 2023-07-30 11:43:23,457] Trial 60 pruned.
# [I 2023-07-30 11:43:24,089] Trial 61 pruned.
# [I 2023-07-30 11:43:24,726] Trial 62 pruned.
# [I 2023-07-30 11:43:25,566] Trial 63 pruned.
# [I 2023-07-30 11:43:26,411] Trial 64 pruned.
# [I 2023-07-30 11:43:27,360] Trial 65 pruned.
# [I 2023-07-30 11:44:43,580] Trial 66 finished with value: 0.7918918918113451 and parameters: {'num_filter_1': 32, 'num_filter_2': 20, 'num_filter_3': 16, 'num_fc': 6, 'drop_out_rate_1': 0.2, 'drop_out_rate_2': 0.2, 'drop_out_rate_3': 0.1, 'optimizer': 'RMSprop', 'lr': 0.0011940172908579984}. Best is trial 6 with value: 0.8256756743869266.
# [I 2023-07-30 11:45:59,566] Trial 67 finished with value: 0.7999999966170337 and parameters: {'num_filter_1': 28, 'num_filter_2': 32, 'num_filter_3': 8, 'num_fc': 8, 'drop_out_rate_1': 0.30000000000000004, 'drop_out_rate_2': 0.25, 'drop_out_rate_3': 0.15000000000000002, 'optimizer': 'RMSprop', 'lr': 0.0018542432961672834}. Best is trial 6 with value: 0.8256756743869266.
# [I 2023-07-30 11:46:00,513] Trial 68 pruned.
# [I 2023-07-30 11:46:01,464] Trial 69 pruned.
# [I 2023-07-30 11:46:02,174] Trial 70 pruned.
# [I 2023-07-30 11:46:02,928] Trial 71 pruned.
# [I 2023-07-30 11:47:11,889] Trial 72 finished with value: 0.7824324288883725 and parameters: {'num_filter_1': 24, 'num_filter_2': 24, 'num_filter_3': 28, 'num_fc': 10, 'drop_out_rate_1': 0.25, 'drop_out_rate_2': 0.2, 'drop_out_rate_3': 0.1, 'optimizer': 'Adam', 'lr': 0.0016718215637216757}. Best is trial 6 with value: 0.8256756743869266.
# [I 2023-07-30 11:48:17,705] Trial 73 finished with value: 0.7999999978252359 and parameters: {'num_filter_1': 20, 'num_filter_2': 20, 'num_filter_3': 24, 'num_fc': 10, 'drop_out_rate_1': 0.35, 'drop_out_rate_2': 0.25, 'drop_out_rate_3': 0.15000000000000002, 'optimizer': 'Adam', 'lr': 0.0022067348776371844}. Best is trial 6 with value: 0.8256756743869266.
# [I 2023-07-30 11:48:18,649] Trial 74 pruned.
# [I 2023-07-30 11:48:20,903] Trial 75 pruned.
# [I 2023-07-30 11:48:21,503] Trial 76 pruned.
# [I 2023-07-30 11:48:22,371] Trial 77 pruned.
# [I 2023-07-30 11:48:26,877] Trial 78 pruned.
# [I 2023-07-30 11:49:56,868] Trial 79 finished with value: 0.7837837821728474 and parameters: {'num_filter_1': 16, 'num_filter_2': 16, 'num_filter_3': 12, 'num_fc': 8, 'drop_out_rate_1': 0.2, 'drop_out_rate_2': 0.30000000000000004, 'drop_out_rate_3': 0.1, 'optimizer': 'RMSprop', 'lr': 0.005529861989458557}. Best is trial 6 with value: 0.8256756743869266.
# [I 2023-07-30 11:50:07,726] Trial 80 pruned.
# [I 2023-07-30 11:50:08,426] Trial 81 pruned.
# [I 2023-07-30 11:50:10,455] Trial 82 pruned.
# [I 2023-07-30 11:50:11,460] Trial 83 pruned.
# [I 2023-07-30 11:50:13,502] Trial 84 pruned.
# [I 2023-07-30 11:50:14,225] Trial 85 pruned.
# [I 2023-07-30 11:50:15,031] Trial 86 pruned.
# [I 2023-07-30 11:50:15,773] Trial 87 pruned.
# [I 2023-07-30 11:50:16,382] Trial 88 pruned.
# [I 2023-07-30 11:50:17,296] Trial 89 pruned.
# [I 2023-07-30 11:50:18,025] Trial 90 pruned.
# [I 2023-07-30 11:50:20,961] Trial 91 pruned.
# [I 2023-07-30 11:50:22,057] Trial 92 pruned.
# [I 2023-07-30 11:50:22,979] Trial 93 pruned.
# [I 2023-07-30 11:50:23,979] Trial 94 pruned.
# [I 2023-07-30 11:51:52,812] Trial 95 finished with value: 0.8108108083944063 and parameters: {'num_filter_1': 32, 'num_filter_2': 16, 'num_filter_3': 8, 'num_fc': 6, 'drop_out_rate_1': 0.30000000000000004, 'drop_out_rate_2': 0.30000000000000004, 'drop_out_rate_3': 0.1, 'optimizer': 'Adam', 'lr': 0.0036513846447811323}. Best is trial 6 with value: 0.8256756743869266.
# [I 2023-07-30 11:51:57,914] Trial 96 pruned.
# [I 2023-07-30 11:52:00,594] Trial 97 pruned.
# [I 2023-07-30 11:52:03,865] Trial 98 pruned.
# [I 2023-07-30 11:52:04,460] Trial 99 pruned.
# [I 2023-07-30 11:53:26,597] Trial 100 finished with value: 0.8148648589849472 and parameters: {'num_filter_1': 32, 'num_filter_2': 24, 'num_filter_3': 8, 'num_fc': 6, 'drop_out_rate_1': 0.2, 'drop_out_rate_2': 0.2, 'drop_out_rate_3': 0.1, 'optimizer': 'Adam', 'lr': 0.0018304750473482575}. Best is trial 6 with value: 0.8256756743869266.
# [I 2023-07-30 11:54:47,368] Trial 101 finished with value: 0.8175675639429608 and parameters: {'num_filter_1': 32, 'num_filter_2': 24, 'num_filter_3': 8, 'num_fc': 6, 'drop_out_rate_1': 0.2, 'drop_out_rate_2': 0.2, 'drop_out_rate_3': 0.1, 'optimizer': 'Adam', 'lr': 0.001984812224022678}. Best is trial 6 with value: 0.8256756743869266.
# [I 2023-07-30 11:54:48,238] Trial 102 pruned.
# [I 2023-07-30 11:54:49,088] Trial 103 pruned.
# [I 2023-07-30 11:54:49,937] Trial 104 pruned.
# [I 2023-07-30 11:56:11,216] Trial 105 finished with value: 0.8013513482905723 and parameters: {'num_filter_1': 32, 'num_filter_2': 28, 'num_filter_3': 8, 'num_fc': 6, 'drop_out_rate_1': 0.2, 'drop_out_rate_2': 0.2, 'drop_out_rate_3': 0.1, 'optimizer': 'Adam', 'lr': 0.0012300950755949288}. Best is trial 6 with value: 0.8256756743869266.
# [I 2023-07-30 11:56:12,098] Trial 106 pruned.
# [I 2023-07-30 11:57:28,867] Trial 107 finished with value: 0.7770270238051543 and parameters: {'num_filter_1': 32, 'num_filter_2': 24, 'num_filter_3': 12, 'num_fc': 6, 'drop_out_rate_1': 0.2, 'drop_out_rate_2': 0.2, 'drop_out_rate_3': 0.1, 'optimizer': 'RMSprop', 'lr': 0.0024609970185746435}. Best is trial 6 with value: 0.8256756743869266.
# [I 2023-07-30 11:57:29,736] Trial 108 pruned.
# [I 2023-07-30 11:57:30,308] Trial 109 pruned.
# [I 2023-07-30 11:57:31,349] Trial 110 pruned.
# [I 2023-07-30 11:57:32,262] Trial 111 pruned.
# [I 2023-07-30 11:58:53,259] Trial 112 finished with value: 0.786486482298052 and parameters: {'num_filter_1': 32, 'num_filter_2': 20, 'num_filter_3': 8, 'num_fc': 6, 'drop_out_rate_1': 0.30000000000000004, 'drop_out_rate_2': 0.25, 'drop_out_rate_3': 0.1, 'optimizer': 'Adam', 'lr': 0.003001925635240153}. Best is trial 6 with value: 0.8256756743869266.
# [I 2023-07-30 11:58:54,136] Trial 113 pruned.
# [I 2023-07-30 11:58:55,057] Trial 114 pruned.
# [I 2023-07-30 12:00:11,596] Trial 115 finished with value: 0.8135135101305472 and parameters: {'num_filter_1': 28, 'num_filter_2': 28, 'num_filter_3': 8, 'num_fc': 4, 'drop_out_rate_1': 0.25, 'drop_out_rate_2': 0.2, 'drop_out_rate_3': 0.1, 'optimizer': 'RMSprop', 'lr': 0.0027486244001560397}. Best is trial 6 with value: 0.8256756743869266.
# [I 2023-07-30 12:00:14,657] Trial 116 pruned.
# [I 2023-07-30 12:01:09,177] Trial 117 finished with value: 0.8054054017002518 and parameters: {'num_filter_1': 28, 'num_filter_2': 28, 'num_filter_3': 12, 'num_fc': 4, 'drop_out_rate_1': 0.25, 'drop_out_rate_2': 0.2, 'drop_out_rate_3': 0.1, 'optimizer': 'RMSprop', 'lr': 0.002777981399728726}. Best is trial 6 with value: 0.8256756743869266.
# [I 2023-07-30 12:01:10,111] Trial 118 pruned.
# [I 2023-07-30 12:02:26,900] Trial 119 finished with value: 0.8189189164219676 and parameters: {'num_filter_1': 32, 'num_filter_2': 28, 'num_filter_3': 8, 'num_fc': 4, 'drop_out_rate_1': 0.25, 'drop_out_rate_2': 0.2, 'drop_out_rate_3': 0.1, 'optimizer': 'RMSprop', 'lr': 0.0008991925190683861}. Best is trial 6 with value: 0.8256756743869266.
# [I 2023-07-30 12:02:27,718] Trial 120 pruned.
# [I 2023-07-30 12:02:30,092] Trial 121 pruned.
# [I 2023-07-30 12:02:31,765] Trial 122 pruned.
# [I 2023-07-30 12:03:49,786] Trial 123 finished with value: 0.7972972948808927 and parameters: {'num_filter_1': 32, 'num_filter_2': 32, 'num_filter_3': 8, 'num_fc': 2, 'drop_out_rate_1': 0.25, 'drop_out_rate_2': 0.2, 'drop_out_rate_3': 0.1, 'optimizer': 'RMSprop', 'lr': 0.0015873656994580072}. Best is trial 6 with value: 0.8256756743869266.
# [I 2023-07-30 12:03:50,646] Trial 124 pruned.
# [I 2023-07-30 12:03:51,501] Trial 125 pruned.
# [I 2023-07-30 12:03:52,315] Trial 126 pruned.
# [I 2023-07-30 12:04:47,848] Trial 127 finished with value: 0.8094594530962609 and parameters: {'num_filter_1': 32, 'num_filter_2': 28, 'num_filter_3': 16, 'num_fc': 6, 'drop_out_rate_1': 0.30000000000000004, 'drop_out_rate_2': 0.2, 'drop_out_rate_3': 0.1, 'optimizer': 'RMSprop', 'lr': 0.003545181653964828}. Best is trial 6 with value: 0.8256756743869266.
# [I 2023-07-30 12:04:48,393] Trial 128 pruned.
# [I 2023-07-30 12:05:45,510] Trial 129 finished with value: 0.7702702702702703 and parameters: {'num_filter_1': 32, 'num_filter_2': 28, 'num_filter_3': 16, 'num_fc': 6, 'drop_out_rate_1': 0.2, 'drop_out_rate_2': 0.30000000000000004, 'drop_out_rate_3': 0.1, 'optimizer': 'RMSprop', 'lr': 0.0035607097763457824}. Best is trial 6 with value: 0.8256756743869266.
# [I 2023-07-30 12:05:46,177] Trial 130 pruned.
# [I 2023-07-30 12:05:46,802] Trial 131 pruned.
# [I 2023-07-30 12:05:47,611] Trial 132 pruned.
# [I 2023-07-30 12:05:49,218] Trial 133 pruned.
# [I 2023-07-30 12:05:51,518] Trial 134 pruned.
# [I 2023-07-30 12:05:52,377] Trial 135 pruned.
# [I 2023-07-30 12:05:55,740] Trial 136 pruned.
# [I 2023-07-30 12:05:56,535] Trial 137 pruned.
# [I 2023-07-30 12:05:59,079] Trial 138 pruned.
# [I 2023-07-30 12:05:59,873] Trial 139 pruned.
# [I 2023-07-30 12:06:00,478] Trial 140 pruned.
# [I 2023-07-30 12:06:01,203] Trial 141 pruned.
# [I 2023-07-30 12:06:02,093] Trial 142 pruned.
# [I 2023-07-30 12:06:03,182] Trial 143 pruned.
# [I 2023-07-30 12:07:23,159] Trial 144 finished with value: 0.7837837817701133 and parameters: {'num_filter_1': 32, 'num_filter_2': 24, 'num_filter_3': 8, 'num_fc': 10, 'drop_out_rate_1': 0.15000000000000002, 'drop_out_rate_2': 0.25, 'drop_out_rate_3': 0.1, 'optimizer': 'Adam', 'lr': 0.0038435115399412636}. Best is trial 6 with value: 0.8256756743869266.
# [I 2023-07-30 12:07:23,790] Trial 145 pruned.
# [I 2023-07-30 12:07:24,641] Trial 146 pruned.
# [I 2023-07-30 12:07:27,698] Trial 147 pruned.
# [I 2023-07-30 12:07:28,324] Trial 148 pruned.
# [I 2023-07-30 12:07:29,106] Trial 149 pruned.
# [I 2023-07-30 12:07:30,103] Trial 150 pruned.
# [I 2023-07-30 12:08:25,405] Trial 151 finished with value: 0.7878378371934633 and parameters: {'num_filter_1': 28, 'num_filter_2': 28, 'num_filter_3': 16, 'num_fc': 4, 'drop_out_rate_1': 0.25, 'drop_out_rate_2': 0.2, 'drop_out_rate_3': 0.1, 'optimizer': 'RMSprop', 'lr': 0.002478886771914308}. Best is trial 6 with value: 0.8256756743869266.
# [I 2023-07-30 12:08:28,470] Trial 152 pruned.
# [I 2023-07-30 12:09:22,882] Trial 153 finished with value: 0.7810810804367065 and parameters: {'num_filter_1': 28, 'num_filter_2': 28, 'num_filter_3': 12, 'num_fc': 4, 'drop_out_rate_1': 0.25, 'drop_out_rate_2': 0.2, 'drop_out_rate_3': 0.1, 'optimizer': 'RMSprop', 'lr': 0.003459790777468173}. Best is trial 6 with value: 0.8256756743869266.
# [I 2023-07-30 12:09:23,755] Trial 154 pruned.
# [I 2023-07-30 12:09:24,641] Trial 155 pruned.
# [I 2023-07-30 12:09:29,489] Trial 156 pruned.
# [I 2023-07-30 12:09:30,142] Trial 157 pruned.
# [I 2023-07-30 12:09:30,960] Trial 158 pruned.
# [I 2023-07-30 12:10:27,101] Trial 159 finished with value: 0.8067567525683222 and parameters: {'num_filter_1': 28, 'num_filter_2': 28, 'num_filter_3': 24, 'num_fc': 6, 'drop_out_rate_1': 0.25, 'drop_out_rate_2': 0.30000000000000004, 'drop_out_rate_3': 0.1, 'optimizer': 'RMSprop', 'lr': 0.0013586957056648209}. Best is trial 6 with value: 0.8256756743869266.
# [I 2023-07-30 12:10:27,859] Trial 160 pruned.
# [I 2023-07-30 12:10:28,478] Trial 161 pruned.
# [I 2023-07-30 12:10:29,153] Trial 162 pruned.
# [I 2023-07-30 12:10:29,756] Trial 163 pruned.
# [I 2023-07-30 12:10:31,485] Trial 164 pruned.
# [I 2023-07-30 12:10:32,148] Trial 165 pruned.
# [I 2023-07-30 12:10:33,127] Trial 166 pruned.
# [I 2023-07-30 12:10:34,413] Trial 167 pruned.
# [I 2023-07-30 12:10:35,263] Trial 168 pruned.
# [I 2023-07-30 12:10:39,940] Trial 169 pruned.
# [I 2023-07-30 12:10:41,041] Trial 170 pruned.
# [I 2023-07-30 12:10:42,093] Trial 171 pruned.
# [I 2023-07-30 12:10:43,064] Trial 172 pruned.
# [I 2023-07-30 12:10:44,001] Trial 173 pruned.
# [I 2023-07-30 12:10:44,772] Trial 174 pruned.
# [I 2023-07-30 12:10:45,924] Trial 175 pruned.
# [I 2023-07-30 12:10:48,330] Trial 176 pruned.
# [I 2023-07-30 12:10:49,307] Trial 177 pruned.
# [I 2023-07-30 12:10:49,953] Trial 178 pruned.
# [I 2023-07-30 12:10:50,832] Trial 179 pruned.
# [I 2023-07-30 12:10:51,725] Trial 180 pruned.
# [I 2023-07-30 12:10:53,419] Trial 181 pruned.
# [I 2023-07-30 12:10:54,033] Trial 182 pruned.
# [I 2023-07-30 12:10:54,668] Trial 183 pruned.
# [I 2023-07-30 12:10:55,321] Trial 184 pruned.
# [I 2023-07-30 12:10:56,305] Trial 185 pruned.
# [I 2023-07-30 12:10:57,232] Trial 186 pruned.
# [I 2023-07-30 12:11:52,277] Trial 187 finished with value: 0.804054049221245 and parameters: {'num_filter_1': 24, 'num_filter_2': 32, 'num_filter_3': 12, 'num_fc': 6, 'drop_out_rate_1': 0.30000000000000004, 'drop_out_rate_2': 0.2, 'drop_out_rate_3': 0.1, 'optimizer': 'RMSprop', 'lr': 0.0029931038705561307}. Best is trial 6 with value: 0.8256756743869266.
# [I 2023-07-30 12:11:52,875] Trial 188 pruned.
# [I 2023-07-30 12:11:53,775] Trial 189 pruned.
# [I 2023-07-30 12:11:54,411] Trial 190 pruned.
# [I 2023-07-30 12:11:55,061] Trial 191 pruned.
# [I 2023-07-30 12:11:55,675] Trial 192 pruned.
# [I 2023-07-30 12:11:56,281] Trial 193 pruned.
# [I 2023-07-30 12:11:56,900] Trial 194 pruned.
# [I 2023-07-30 12:12:00,282] Trial 195 pruned.
# [I 2023-07-30 12:12:01,112] Trial 196 pruned.
# [I 2023-07-30 12:12:03,087] Trial 197 pruned.
# [I 2023-07-30 12:12:05,773] Trial 198 pruned.
# [I 2023-07-30 12:12:06,425] Trial 199 pruned.

# %% [markdown]
# ## 2.2. Optimization Results

# %%
# Find number of pruned and completed trials
pruned_trials = study.get_trials(deepcopy=False, states=[TrialState.PRUNED])
complete_trials = study.get_trials(deepcopy=False, states=[TrialState.COMPLETE])

# %%
# Display the study statistics
print("\nStudy statistics: ")
print("  Number of finished trials: ", len(study.trials))
print("  Number of pruned trials: ", len(pruned_trials))
print("  Number of complete trials: ", len(complete_trials))
# Out:
# Study statistics:
#   Number of finished trials:  200
#   Number of pruned trials:  153
#   Number of complete trials:  47

# %%
trial = study.best_trial
print("Best trial:")
print("  Value: ", trial.value)
print("  Params: ")
for key, value in trial.params.items():
    print("    {}: {}".format(key, value))
# Out:
# Best trial:
#   Value:  0.8256756743869266
#   Params:
#     num_filter_1: 24
#     num_filter_2: 16
#     num_filter_3: 24
#     num_fc: 6
#     drop_out_rate_1: 0.35
#     drop_out_rate_2: 0.2
#     drop_out_rate_3: 0.1
#     optimizer: RMSprop
#     lr: 0.0038095116489375554

# %%
# Save results to csv file
hyper_df = study.trials_dataframe().drop(
    ["datetime_start", "datetime_complete", "duration"], axis=1
)  # Exclude columns
hyper_df = hyper_df.loc[
    hyper_df["state"] == "COMPLETE"
]  # Keep only results that did not prune
hyper_df = hyper_df.drop("state", axis=1)  # Exclude state column
hyper_df = hyper_df.sort_values("value")  # Sort based on accuracy
hyper_df.to_csv("../data/optuna_results_1d.csv", index=False)  # Save to csv file

# %%
# Display results in a dataframe
print("\nOverall Results (ordered by accuracy):\n")
hyper_df
# Out:
# Overall Results (ordered by accuracy):
#      number     value  params_drop_out_rate_1  params_drop_out_rate_2  \
# 3         3  0.447297                    0.25                    0.10
# 1         1  0.760811                    0.35                    0.35
# 4         4  0.766216                    0.15                    0.30
# 129     129  0.770270                    0.20                    0.30
# 107     107  0.777027                    0.20                    0.20
# 0         0  0.777027                    0.25                    0.25
# 153     153  0.781081                    0.25                    0.20
# 72       72  0.782432                    0.25                    0.20
# 144     144  0.783784                    0.15                    0.25
# 79       79  0.783784                    0.20                    0.30
# 112     112  0.786486                    0.30                    0.25
# 151     151  0.787838                    0.25                    0.20
# 2         2  0.789189                    0.35                    0.15
# 57       57  0.791892                    0.15                    0.30
# 66       66  0.791892                    0.20                    0.20
# 123     123  0.797297                    0.25                    0.20
# 50       50  0.797297                    0.20                    0.15
# 31       31  0.798649                    0.25                    0.30
# 11       11  0.798649                    0.20                    0.20
# 5         5  0.800000                    0.15                    0.35
# 67       67  0.800000                    0.30                    0.25
# 73       73  0.800000                    0.35                    0.25
# 28       28  0.801351                    0.25                    0.30
# 105     105  0.801351                    0.20                    0.20
# 34       34  0.801351                    0.25                    0.35
# 22       22  0.801351                    0.25                    0.30
# 44       44  0.802703                    0.20                    0.30
# 187     187  0.804054                    0.30                    0.20
# 33       33  0.804054                    0.35                    0.35
# 46       46  0.805405                    0.30                    0.35
# 117     117  0.805405                    0.25                    0.20
# 159     159  0.806757                    0.25                    0.30
# 13       13  0.806757                    0.15                    0.15
# 16       16  0.808108                    0.30                    0.20
# 127     127  0.809459                    0.30                    0.20
# 17       17  0.810811                    0.30                    0.20
# 95       95  0.810811                    0.30                    0.30
# 20       20  0.812162                    0.25                    0.30
# 21       21  0.812162                    0.25                    0.30
# 32       32  0.812162                    0.25                    0.35
# 115     115  0.813514                    0.25                    0.20
# 100     100  0.814865                    0.20                    0.20
# 101     101  0.817568                    0.20                    0.20
# 23       23  0.818919                    0.20                    0.30
# 119     119  0.818919                    0.25                    0.20
# 45       45  0.822973                    0.25                    0.35
# 6         6  0.825676                    0.35                    0.20
#
#      params_drop_out_rate_3  params_lr  params_num_fc  params_num_filter_1  \
# 3                      0.10   0.000045              4                   24
# 1                      0.25   0.000027              4                   12
# 4                      0.35   0.000628             12                   16
# 129                    0.10   0.003561              6                   32
# 107                    0.10   0.002461              6                   32
# 0                      0.25   0.000272              4                    8
# 153                    0.10   0.003460              4                   28
# 72                     0.10   0.001672             10                   24
# 144                    0.10   0.003844             10                   32
# 79                     0.10   0.005530              8                   16
# 112                    0.10   0.003002              6                   32
# 151                    0.10   0.002479              4                   28
# 2                      0.10   0.005838              2                   12
# 57                     0.15   0.003199              4                   20
# 66                     0.10   0.001194              6                   32
# 123                    0.10   0.001587              2                   32
# 50                     0.10   0.004187             12                   20
# 31                     0.10   0.001023              6                   32
# 11                     0.15   0.002239              8                    4
# 5                      0.20   0.000487              8                    8
# 67                     0.15   0.001854              8                   28
# 73                     0.15   0.002207             10                   20
# 28                     0.15   0.002242              6                   16
# 105                    0.10   0.001230              6                   32
# 34                     0.10   0.001549              8                   32
# 22                     0.10   0.004823              6                   32
# 44                     0.10   0.002742              8                    8
# 187                    0.10   0.002993              6                   24
# 33                     0.10   0.005350              4                   28
# 46                     0.15   0.007927             10                   24
# 117                    0.10   0.002778              4                   28
# 159                    0.10   0.001359              6                   28
# 13                     0.20   0.002636             10                   20
# 16                     0.15   0.001700             10                   24
# 127                    0.10   0.003545              6                   32
# 17                     0.15   0.001374              6                   28
# 95                     0.10   0.003651              6                   32
# 20                     0.10   0.001120              6                   32
# 21                     0.10   0.001313              6                   32
# 32                     0.10   0.001543              6                   32
# 115                    0.10   0.002749              4                   28
# 100                    0.10   0.001830              6                   32
# 101                    0.10   0.001985              6                   32
# 23                     0.10   0.000887              8                   32
# 119                    0.10   0.000899              4                   32
# 45                     0.15   0.001963              6                   28
# 6                      0.10   0.003810              6                   24
#
#      params_num_filter_2  params_num_filter_3 params_optimizer
# 3                      8                   28              SGD
# 1                     32                   28          RMSprop
# 4                     12                    4             Adam
# 129                   28                   16          RMSprop
# 107                   24                   12          RMSprop
# 0                     16                    4             Adam
# 153                   28                   12          RMSprop
# 72                    24                   28             Adam
# 144                   24                    8             Adam
# 79                    16                   12          RMSprop
# 112                   20                    8             Adam
# 151                   28                   16          RMSprop
# 2                      8                   28          RMSprop
# 57                    32                   32             Adam
# 66                    20                   16          RMSprop
# 123                   32                    8          RMSprop
# 50                     4                   16             Adam
# 31                    28                    8          RMSprop
# 11                    24                   20             Adam
# 5                     12                   28             Adam
# 67                    32                    8          RMSprop
# 73                    20                   24             Adam
# 28                    28                   32          RMSprop
# 105                   28                    8             Adam
# 34                    32                    8          RMSprop
# 22                    32                    8          RMSprop
# 44                    24                   12          RMSprop
# 187                   32                   12          RMSprop
# 33                    32                   12          RMSprop
# 46                    12                   24             Adam
# 117                   28                   12          RMSprop
# 159                   28                   24          RMSprop
# 13                    20                   24             Adam
# 16                    20                   24             Adam
# 127                   28                   16          RMSprop
# 17                    28                   12          RMSprop
# 95                    16                    8             Adam
# 20                    28                    8          RMSprop
# 21                    28                    8          RMSprop
# 32                    32                    8          RMSprop
# 115                   28                    8          RMSprop
# 100                   24                    8             Adam
# 101                   24                    8             Adam
# 23                    24                    8          RMSprop
# 119                   28                    8          RMSprop
# 45                    12                   16             Adam
# 6                     16                   24          RMSprop

# %%
# Find the most important hyperparameters
most_important_parameters = optuna.importance.get_param_importances(study, target=None)

# %%
# Display the most important hyperparameters
print("\nMost important hyperparameters:")
for key, value in most_important_parameters.items():
    print("  {}:{}{:.2f}%".format(key, (15 - len(key)) * " ", value * 100))
# Out:
# Most important hyperparameters:
#   drop_out_rate_2:38.28%
#   optimizer:      34.95%
#   drop_out_rate_3:10.20%
#   drop_out_rate_1:5.53%
#   lr:             5.22%
#   num_filter_2:   2.23%
#   num_fc:         1.61%
#   num_filter_3:   1.38%
#   num_filter_1:   0.60%

# %% [markdown]
# # 3. 1-D CNN Model Training

# %% [markdown]
# ## 3.1. Model Setup with Optimized Hyperparameters

# %%
trial.params
# Out:
# {'num_filter_1': 24,
#  'num_filter_2': 16,
#  'num_filter_3': 24,
#  'num_fc': 6,
#  'drop_out_rate_1': 0.35,
#  'drop_out_rate_2': 0.2,
#  'drop_out_rate_3': 0.1,
#  'optimizer': 'RMSprop',
#  'lr': 0.0038095116489375554}

# %%
model = ConvolutionalNeuralNetwork(
    trial,
    num_filter_1=trial.params["num_filter_1"],
    num_filter_2=trial.params["num_filter_2"],
    num_filter_3=trial.params["num_filter_3"],
    num_fc=trial.params["num_fc"],
    drop_out_rate_1=trial.params["drop_out_rate_1"],
    drop_out_rate_2=trial.params["drop_out_rate_2"],
    drop_out_rate_3=trial.params["drop_out_rate_3"],
)

# %%
def trainer(
    model,
    criterion,
    optimizer,
    trainloader,
    validloader,
    epochs=5,
    patience=5,
    verbose=True,
):
    """Simple training wrapper for PyTorch network."""

    train_loss, valid_loss, train_accuracy, valid_accuracy = [], [], [], []
    for epoch in range(epochs):  # for each epoch
        train_batch_loss = 0
        valid_batch_loss = 0
        train_batch_acc = 0
        valid_batch_acc = 0

        # Training
        for X, y in trainloader:
            optimizer.zero_grad()  # Zero all the gradients w.r.t. parameters
            # X = X.to(device)
            # y = y.to(device)
            y_hat = model(X)  # forward pass to get output
            y_hat_labels = torch.sigmoid(y_hat) > 0.5
            loss = criterion(y_hat, y.unsqueeze(1))  # Calculate loss based on output
            loss.backward()  # Calculate gradients w.r.t. parameters
            optimizer.step()  # Update parameters
            train_batch_loss += loss.item()  # Add loss for this batch to running total
            train_batch_acc += (
                (y_hat_labels.squeeze() == y).type(torch.float32).mean().item()
            )
        train_loss.append(train_batch_loss / len(trainloader))
        train_accuracy.append(train_batch_acc / len(trainloader))  # accuracy

        # Validation
        model.eval()
        with torch.no_grad():  # this stops pytorch doing computational graph stuff under-the-hood and saves memory and time
            for X, y in validloader:
                # X = X.to(device)
                # y = y.to(device)
                y_hat = model(X)  # forward pass to get output
                y_hat_labels = torch.sigmoid(y_hat) > 0.5
                loss = criterion(y_hat, y.unsqueeze(1))
                valid_batch_loss += loss.item()
                valid_batch_acc += (
                    (y_hat_labels.squeeze() == y).type(torch.float32).mean().item()
                )
        valid_loss.append(valid_batch_loss / len(validloader))
        valid_accuracy.append(valid_batch_acc / len(validloader))  # accuracy

        model.train()

        # Print progress
        if verbose:
            if (epoch + 1) % 100 == 0:
                print(
                    f"Epoch {epoch + 1}:",
                    f"Train Loss: {train_loss[-1]:.3f}.",
                    f"Valid Loss: {valid_loss[-1]:.3f}.",
                    f"Train Accuracy: {train_accuracy[-1]:.2f}."
                    f"Valid Accuracy: {valid_accuracy[-1]:.2f}.",
                )

        # Early stopping
        if epoch > 0 and valid_loss[-1] > valid_loss[-2]:
            consec_increases += 1
        else:
            consec_increases = 0
        if consec_increases == patience:
            print(
                f"Stopped early at epoch {epoch + 1} - val loss increased for {consec_increases} consecutive epochs!"
            )
            break

    print("\nTraining ended.")

    loss_fig = pd.DataFrame(
        {"train_loss": train_loss, "valid_loss": valid_loss}
    ).plot.line()
    loss_fig.set_xlabel("Epoch")
    loss_fig.set_ylabel("Loss")

    accur_fig = pd.DataFrame(
        {"train_accuracy": train_accuracy, "valid_accuracy": valid_accuracy}
    ).plot.line()
    accur_fig.set_xlabel("Epoch")
    accur_fig.set_ylabel("Accuracy");

# %%
model.apply(weights_init)
# Out:
# ConvolutionalNeuralNetwork(
#   (main): Sequential(
#     (0): Conv1d(8, 24, kernel_size=(3,), stride=(1,), padding=(1,))
#     (1): ReLU()
#     (2): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (3): Dropout(p=0.35, inplace=False)
#     (4): Conv1d(24, 16, kernel_size=(3,), stride=(1,), padding=(1,))
#     (5): ReLU()
#     (6): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (7): Dropout(p=0.2, inplace=False)
#     (8): Conv1d(16, 24, kernel_size=(3,), stride=(1,), padding=(1,))
#     (9): ReLU()
#     (10): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (11): Dropout(p=0.1, inplace=False)
#     (12): Flatten(start_dim=1, end_dim=-1)
#     (13): Linear(in_features=72, out_features=6, bias=True)
#     (14): ReLU()
#     (15): Linear(in_features=6, out_features=1, bias=True)
#   )
# )

# %% [markdown]
# ## 3.2. Model Training

# %%
criterion = nn.BCEWithLogitsLoss()
optimizer = getattr(optim, trial.params["optimizer"])(
    model.parameters(), lr=trial.params["lr"]
)

# %%
trainer(
    model,
    criterion,
    optimizer,
    trainloader,
    validloader,
    epochs=2001,
    patience=5,
    verbose=True,
)
# Out:
# Epoch 100: Train Loss: 0.349. Valid Loss: 0.418. Train Accuracy: 0.84.Valid Accuracy: 0.81.
# Epoch 200: Train Loss: 0.337. Valid Loss: 0.423. Train Accuracy: 0.85.Valid Accuracy: 0.80.
# Epoch 300: Train Loss: 0.318. Valid Loss: 0.420. Train Accuracy: 0.86.Valid Accuracy: 0.82.
# Epoch 400: Train Loss: 0.295. Valid Loss: 0.479. Train Accuracy: 0.87.Valid Accuracy: 0.80.
# Epoch 500: Train Loss: 0.310. Valid Loss: 0.453. Train Accuracy: 0.87.Valid Accuracy: 0.80.
# Epoch 600: Train Loss: 0.303. Valid Loss: 0.433. Train Accuracy: 0.86.Valid Accuracy: 0.80.
# Stopped early at epoch 670 - val loss increased for 5 consecutive epochs!
#
# Training ended.

# %% [markdown]
# ## 3.3. Check on Accuracy on Test Set

# %%
test_accuracy = []
test_batch_acc = 0

model.eval()
with torch.no_grad():
    for X, y in testloader:
        y_hat = model(X)  # forward pass to get output
        y_hat_labels = torch.sigmoid(y_hat) > 0.5
        test_batch_acc += (
            (y_hat_labels.squeeze() == y).type(torch.float32).mean().item()
        )

test_accuracy.append(test_batch_acc / len(testloader))  # accuracy

# %%
test_accuracy
# Out:
# [0.834703191706579]

# %% [markdown]
# ## 3.4. Prediction

# %%
model.eval()
with torch.no_grad():
    wea, lab = next(iter(testloader))
    y_prob = torch.sigmoid(model(wea)[0])
    y_class = int(y_prob > 0.5)
    print(f"Prbability of Bad Air Quality: {y_prob.item():.3g}")
    fig, axs = plt.subplots(nrows=2, ncols=4)
    r = 0
    c = 0
    for j in range(8):
        axs[r, c].plot(weather[0, j, :])
        axs[r, c].set_title(f"{feature_names[j]}")
        if c < 3:
            c += 1
        else:
            r += 1
            c = 0
    fig.suptitle(f"Air Quality Bad? {bool(lab[0])}")
    plt.tight_layout()
    plt.show();
# Out:
# Prbability of Bad Air Quality: 0.431

# %% [markdown]
# ## 3.5. Model Save

# %%
torch.save(model, "../models/1d_cnn_model.pt")
