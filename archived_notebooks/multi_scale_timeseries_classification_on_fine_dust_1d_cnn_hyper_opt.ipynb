# %% [markdown]
# # 0. Imports

# %%
import os
import warnings

import numpy as np
import pandas as pd
from pandas.errors import SettingWithCopyWarning

warnings.simplefilter(action="ignore", category=SettingWithCopyWarning)
warnings.simplefilter(action="ignore", category=FutureWarning)

import datetime

import matplotlib.pyplot as plt
import optuna
import torch
import torch.optim as optim
from optuna.trial import TrialState
from sklearn.preprocessing import StandardScaler
from torch import nn
from torch.utils.data import DataLoader, TensorDataset
from torchsummary import summary
from torchvision import datasets, transforms
from torchvision.transforms import ToTensor
from tqdm import tqdm

torch.manual_seed(41)

# %%
def weights_init(m):
    if isinstance(m, nn.Conv1d):
        torch.nn.init.xavier_uniform_(m.weight.data)

# %% [markdown]
# # 1. Data

# %% [markdown]
# Processed dataset from [Part 1](https://github.com/johnwslee/fine_dust_analysis) will be used as raw data for study.

# %%
df = pd.read_csv(
    "../data/seoul_fine_dust_weather_2008_2021_for_ml.csv",
    index_col=0,
    parse_dates=True,
).reset_index()

# %%
df.head()
# Out:
#                  date  temp(°C)  precipitation(mm)  wind_speed(m/s)  \
# 0 2008-01-01 10:00:00      -7.6                0.0              4.6
# 1 2008-01-01 11:00:00      -6.9                0.0              4.1
# 2 2008-01-01 12:00:00      -5.8                0.0              4.1
# 3 2008-01-01 13:00:00      -5.0                0.0              4.1
# 4 2008-01-01 14:00:00      -4.4                0.0              4.1
#
#    wind_direction  humidity(%)  local_P(hPa)  cloud_cover  \
# 0           340.0         47.0        1010.7          2.0
# 1           290.0         42.0        1010.7          2.0
# 2           290.0         42.0        1010.7          2.0
# 3           290.0         36.0        1009.9          0.0
# 4           290.0         36.0        1009.9          0.0
#
#    lowest_ceiling(100m)  month  PM10_Counts  PM25_Counts  log_PM10_Counts  \
# 0                  12.0      1         30.0         11.0         3.433987
# 1                  12.0      1         29.0         13.0         3.401197
# 2                  12.0      1         29.0         12.0         3.401197
# 3                  10.0      1         28.0         12.0         3.367296
# 4                  10.0      1         27.0         13.0         3.332205
#
#    log_PM25_Counts
# 0         2.484907
# 1         2.639057
# 2         2.564949
# 3         2.564949
# 4         2.639057

# %% [markdown]
# The dataset above will be transformed so that it can be used for multi-scale timeseries classification. In order to do so, `wind_direction`, `humidity(%)`, `lowest_ceiling(100m)`, `temp(°C)`, `wind_speed(m/s)`, `local_P(hPa)`, `precipitation(mm)`, and `PM10_Counts` will be used as features, whereas the binary target, `Air_is_bad?` will be generated based on `PM10_Counts` of the next day.

# %%
new_columns = [
    "date",
    "wind_direction",
    "humidity(%)",
    "lowest_ceiling(100m)",
    "temp(°C)",
    "wind_speed(m/s)",
    "local_P(hPa)",
    "precipitation(mm)",
    "PM10_Counts",
]

# %%
df = df[new_columns]

# %%
df
# Out:
#                       date  wind_direction  humidity(%)  lowest_ceiling(100m)  \
# 0      2008-01-01 10:00:00           340.0         47.0                  12.0
# 1      2008-01-01 11:00:00           290.0         42.0                  12.0
# 2      2008-01-01 12:00:00           290.0         42.0                  12.0
# 3      2008-01-01 13:00:00           290.0         36.0                  10.0
# 4      2008-01-01 14:00:00           290.0         36.0                  10.0
# ...                    ...             ...          ...                   ...
# 122728 2021-12-31 05:00:00           270.0         39.0                  10.0
# 122729 2021-12-31 06:00:00           290.0         40.0                  10.0
# 122730 2021-12-31 07:00:00           270.0         42.0                  10.0
# 122731 2021-12-31 08:00:00           270.0         42.0                  10.0
# 122732 2021-12-31 09:00:00           270.0         40.0                  10.0
#
#         temp(°C)  wind_speed(m/s)  local_P(hPa)  precipitation(mm)  \
# 0           -7.6              4.6        1010.7                0.0
# 1           -6.9              4.1        1010.7                0.0
# 2           -5.8              4.1        1010.7                0.0
# 3           -5.0              4.1        1009.9                0.0
# 4           -4.4              4.1        1009.9                0.0
# ...          ...              ...           ...                ...
# 122728      -7.7              3.5        1018.5                0.0
# 122729      -8.0              3.2        1019.2                0.0
# 122730      -8.6              2.7        1019.9                0.0
# 122731      -8.8              2.9        1020.8                0.0
# 122732      -8.4              3.7        1021.2                0.0
#
#         PM10_Counts
# 0              30.0
# 1              29.0
# 2              29.0
# 3              28.0
# 4              27.0
# ...             ...
# 122728         25.0
# 122729         23.0
# 122730         22.0
# 122731         22.0
# 122732         22.0
#
# [122733 rows x 9 columns]

# %% [markdown]
# Since the time starts from 10 for 2008-01-01, the dataset should start from 2008-01-02 so that all features have equal length of data per day. The same goes for 2021-12-31. So Feature will range from 2008-01-02 to 2021-12-29, while it will be from 2008-01-03 to 2021-12-30 for target.

# %% [markdown]
# ## 1.1. Target Preparation

# %%
df.loc[df["PM10_Counts"] > 45].shape[0]
# Out:
# 46562

# %%
df.shape[0]
# Out:
# 122733

# %%
pm10_count = df[["date", "PM10_Counts"]]

# %%
pm10_count
# Out:
#                       date  PM10_Counts
# 0      2008-01-01 10:00:00         30.0
# 1      2008-01-01 11:00:00         29.0
# 2      2008-01-01 12:00:00         29.0
# 3      2008-01-01 13:00:00         28.0
# 4      2008-01-01 14:00:00         27.0
# ...                    ...          ...
# 122728 2021-12-31 05:00:00         25.0
# 122729 2021-12-31 06:00:00         23.0
# 122730 2021-12-31 07:00:00         22.0
# 122731 2021-12-31 08:00:00         22.0
# 122732 2021-12-31 09:00:00         22.0
#
# [122733 rows x 2 columns]

# %%
pm10_count["date_new"] = pm10_count["date"].dt.date

# %%
target = pm10_count.groupby("date_new").mean().reset_index()

# %%
target["date_new"] = pd.to_datetime(target["date_new"])

# %%
target["Air_is_bad?"] = np.where(target["PM10_Counts"] >= 45, 1, 0)

# %%
target = target[["date_new", "Air_is_bad?"]]

# %%
target = target.loc[
    (target["date_new"].dt.date >= datetime.date(2008, 1, 3))
    & (target["date_new"].dt.date <= datetime.date(2021, 12, 30))
].reset_index(drop=True)

# %%
target
# Out:
#        date_new  Air_is_bad?
# 0    2008-01-03            1
# 1    2008-01-04            1
# 2    2008-01-05            1
# 3    2008-01-06            1
# 4    2008-01-07            1
# ...         ...          ...
# 5106 2021-12-26            0
# 5107 2021-12-27            0
# 5108 2021-12-28            1
# 5109 2021-12-29            1
# 5110 2021-12-30            0
#
# [5111 rows x 2 columns]

# %% [markdown]
# ## 1.2. Train/Test Split

# %%
train_df = df.loc[df["date"].dt.date < datetime.date(2016, 1, 1)]
test_df = df.loc[df["date"].dt.date >= datetime.date(2016, 1, 1)]

# %% [markdown]
# ## 1.3. Feature Preparation

# %%
feature_names = list(df.columns[1:])

# %%
scaler = StandardScaler()

# %%
train_df[feature_names] = scaler.fit_transform(train_df[feature_names])

# %%
test_df[feature_names] = scaler.transform(test_df[feature_names])

# %%
# Concatenate train/test df just for convenience of dataset preparation

features = pd.concat([train_df, test_df], axis=0)

# %%
features["date_new"] = features["date"].dt.date

# %%
features
# Out:
#                       date  wind_direction  humidity(%)  lowest_ceiling(100m)  \
# 0      2008-01-01 10:00:00        1.379492    -0.665907             -0.223685
# 1      2008-01-01 11:00:00        0.924452    -0.916402             -0.223685
# 2      2008-01-01 12:00:00        0.924452    -0.916402             -0.223685
# 3      2008-01-01 13:00:00        0.924452    -1.216997             -0.438062
# 4      2008-01-01 14:00:00        0.924452    -1.216997             -0.438062
# ...                    ...             ...          ...                   ...
# 122728 2021-12-31 05:00:00        0.742436    -1.066699             -0.438062
# 122729 2021-12-31 06:00:00        0.924452    -1.016600             -0.438062
# 122730 2021-12-31 07:00:00        0.742436    -0.916402             -0.438062
# 122731 2021-12-31 08:00:00        0.742436    -0.916402             -0.438062
# 122732 2021-12-31 09:00:00        0.742436    -1.016600             -0.438062
#
#         temp(°C)  wind_speed(m/s)  local_P(hPa)  precipitation(mm)  \
# 0      -1.837310         1.384209      0.614341          -0.119068
# 1      -1.774089         1.032243      0.614341          -0.119068
# 2      -1.674743         1.032243      0.614341          -0.119068
# 3      -1.602491         1.032243      0.513459          -0.119068
# 4      -1.548302         1.032243      0.513459          -0.119068
# ...          ...              ...           ...                ...
# 122728 -1.846341         0.609884      1.597937          -0.119068
# 122729 -1.873436         0.398704      1.686208          -0.119068
# 122730 -1.927625         0.046738      1.774479          -0.119068
# 122731 -1.945688         0.187525      1.887971          -0.119068
# 122732 -1.909562         0.750670      1.938412          -0.119068
#
#         PM10_Counts    date_new
# 0         -0.484375  2008-01-01
# 1         -0.511732  2008-01-01
# 2         -0.511732  2008-01-01
# 3         -0.539090  2008-01-01
# 4         -0.566447  2008-01-01
# ...             ...         ...
# 122728    -0.621163  2021-12-31
# 122729    -0.675878  2021-12-31
# 122730    -0.703235  2021-12-31
# 122731    -0.703235  2021-12-31
# 122732    -0.703235  2021-12-31
#
# [122733 rows x 10 columns]

# %%
features = (
    features.groupby("date_new")
    .agg(list)[
        [
            "wind_direction",
            "humidity(%)",
            "lowest_ceiling(100m)",
            "temp(°C)",
            "wind_speed(m/s)",
            "local_P(hPa)",
            "precipitation(mm)",
            "PM10_Counts",
        ]
    ]
    .reset_index()
)

# %%
features["date_new"] = pd.to_datetime(features["date_new"])

# %%
features.head()
# Out:
#     date_new                                     wind_direction  \
# 0 2008-01-01  [1.3794924231559433, 0.924452475006894, 0.9244...
# 1 2008-01-02  [0.924452475006894, 1.1974764438963235, 1.1974...
# 2 2008-01-03  [-1.7147792242575914, -1.2597392761085422, -1....
# 3 2008-01-04  [0.924452475006894, -1.5327632449979716, 1.379...
# 4 2008-01-05  [0.7424364957472743, -1.5327632449979716, -1.2...
#
#                                          humidity(%)  \
# 0  [-0.665906724059201, -0.9164020855164998, -0.9...
# 1  [-0.16491600114460359, -0.665906724059201, -0....
# 2  [-0.06471785656168408, -0.11481692885314383, -...
# 3  [0.035480288021235415, -0.01461878427022433, -...
# 4  [-0.6158076517677413, 0.035480288021235415, -0...
#
#                                 lowest_ceiling(100m)  \
# 0  [-0.22368526895253332, -0.22368526895253332, -...
# 1  [-0.5452500390488106, -0.5452500390488106, -0....
# 2  [-0.22368526895253332, -0.8668148091450879, -0...
# 3  [-0.8668148091450879, -0.8668148091450879, -0....
# 4  [-0.5452500390488106, -0.5452500390488106, -0....
#
#                                             temp(°C)  \
# 0  [-1.8373098159974528, -1.7740892697507045, -1....
# 1  [-1.7379632433239907, -1.62958516404385, -1.53...
# 2  [-1.3496084592368196, -1.1870413403166087, -1....
# 3  [-1.2231673667433223, -1.2592933931700356, -1....
# 4  [-1.1328523006765383, -1.12382079406986, -0.97...
#
#                                      wind_speed(m/s)  \
# 0  [1.3842093884999658, 1.0322432575055385, 1.032...
# 1  [-0.5164077188699413, 0.11713131692002768, 0.1...
# 2  [-1.8538790166487649, -0.6571941712677122, -0....
# 3  [0.046738090721142475, -0.5164077188699413, -1...
# 4  [-0.9387670760632539, -0.6571941712677122, -1....
#
#                                         local_P(hPa)  \
# 0  [0.6143406738734757, 0.6143406738734757, 0.614...
# 1  [0.9043753409882764, 1.1817998051850536, 1.181...
# 2  [1.1187487905948783, 0.7782733118079257, 0.778...
# 3  [1.1817998051850536, 1.3331222402014657, 1.333...
# 4  [0.9548161526604138, 0.9043753409882764, 0.904...
#
#                                    precipitation(mm)  \
# 0  [-0.11906781300263639, -0.11906781300263639, -...
# 1  [-0.11906781300263639, -0.11906781300263639, -...
# 2  [-0.11906781300263639, -0.11906781300263639, -...
# 3  [-0.11906781300263639, -0.11906781300263639, -...
# 4  [-0.11906781300263639, -0.11906781300263639, -...
#
#                                          PM10_Counts
# 0  [-0.48437493777652446, -0.5117324550480038, -0...
# 1  [-0.32022983414764833, -0.15608473051877228, -...
# 2  [-0.15608473051877228, 0.19956299401045927, 0....
# 3  [0.500495683996732, 1.1570760985122364, 1.4032...
# 4  [0.500495683996732, 0.9929309948833603, 1.4032...

# %%
features = features.loc[
    (features["date_new"].dt.date >= datetime.date(2008, 1, 2))
    & (features["date_new"].dt.date <= datetime.date(2021, 12, 29))
].reset_index(drop=True)

# %%
features
# Out:
#        date_new                                     wind_direction  \
# 0    2008-01-02  [0.924452475006894, 1.1974764438963235, 1.1974...
# 1    2008-01-03  [-1.7147792242575914, -1.2597392761085422, -1....
# 2    2008-01-04  [0.924452475006894, -1.5327632449979716, 1.379...
# 3    2008-01-05  [0.7424364957472743, -1.5327632449979716, -1.2...
# 4    2008-01-06  [-1.5327632449979716, -0.8957073175893028, -0....
# ...         ...                                                ...
# 5106 2021-12-25  [0.924452475006894, 0.924452475006894, 0.74243...
# 5107 2021-12-26  [0.7424364957472743, 0.7424364957472743, 0.924...
# 5108 2021-12-27  [1.1974764438963235, -1.2597392761085422, -0.8...
# 5109 2021-12-28  [-1.5327632449979716, -1.2597392761085422, -1....
# 5110 2021-12-29  [-1.5327632449979716, -1.0777232968489225, -1....
#
#                                             humidity(%)  \
# 0     [-0.16491600114460359, -0.665906724059201, -0....
# 1     [-0.06471785656168408, -0.11481692885314383, -...
# 2     [0.035480288021235415, -0.01461878427022433, -...
# 3     [-0.6158076517677413, 0.035480288021235415, -0...
# 4     [0.8871645169760511, 0.5364710109358329, 0.436...
# ...                                                 ...
# 5106  [-0.4655104348933621, -0.9164020855164998, -1....
# 5107  [-0.7160057963506608, -0.8162039409335803, -0....
# 5108  [-0.36531229031044254, -0.31521321801898283, -...
# 5109  [1.1376598784333498, 1.0374617338504304, 0.636...
# 5110  [0.8871645169760511, 1.0374617338504304, 0.887...
#
#                                    lowest_ceiling(100m)  \
# 0     [-0.5452500390488106, -0.5452500390488106, -0....
# 1     [-0.22368526895253332, -0.8668148091450879, -0...
# 2     [-0.8668148091450879, -0.8668148091450879, -0....
# 3     [-0.5452500390488106, -0.5452500390488106, -0....
# 4     [-0.4380617823500515, -0.974003065843847, -0.9...
# ...                                                 ...
# 5106  [-0.11649701225377423, -0.11649701225377423, -...
# 5107  [-0.11649701225377423, -0.11649701225377423, -...
# 5108  [-0.11649701225377423, -0.11649701225377423, -...
# 5109  [-0.3308735256512924, -0.3308735256512924, -0....
# 5110  [-0.11649701225377423, -0.4380617823500515, -0...
#
#                                                temp(°C)  \
# 0     [-1.7379632433239907, -1.62958516404385, -1.53...
# 1     [-1.3496084592368196, -1.1870413403166087, -1....
# 2     [-1.2231673667433223, -1.2592933931700356, -1....
# 3     [-1.1328523006765383, -1.12382079406986, -0.97...
# 4     [-1.0515687412164327, -0.8619071024761865, -0....
# ...                                                 ...
# 5106  [-1.8102152961774178, -2.252759119904659, -2.1...
# 5107  [-2.451452265251584, -2.388231719004835, -2.29...
# 5108  [-2.2437276132979806, -1.9185933754575586, -1....
# 5109  [-1.7199002301106339, -1.6657111904705635, -1....
# 5110  [-1.4399235253036036, -1.1328523006765383, -1....
#
#                                         wind_speed(m/s)  \
# 0     [-0.5164077188699413, 0.11713131692002768, 0.1...
# 1     [-1.8538790166487649, -0.6571941712677122, -0....
# 2     [0.046738090721142475, -0.5164077188699413, -1...
# 3     [-0.9387670760632539, -0.6571941712677122, -1....
# 4     [-1.0091603022621394, -1.0795535284610247, -1....
# ...                                                 ...
# 5106  [1.5953890670966224, 0.609883900312226, 0.6802...
# 5107  [-0.3756212664721703, 0.6802771265111115, 0.18...
# 5108  [-0.23483481407439957, -0.5164077188699413, -0...
# 5109  [-0.30522804027328476, -0.3756212664721703, -0...
# 5110  [-0.7275873974665975, -1.0091603022621394, -0....
#
#                                            local_P(hPa)  \
# 0     [0.9043753409882764, 1.1817998051850536, 1.181...
# 1     [1.1187487905948783, 0.7782733118079257, 0.778...
# 2     [1.1817998051850536, 1.3331222402014657, 1.333...
# 3     [0.9548161526604138, 0.9043753409882764, 0.904...
# 4     [0.9548161526604138, 0.9043753409882764, 0.904...
# ...                                                 ...
# 5106  [1.2700712256112905, 2.039293603611432, 2.0392...
# 5107  [2.3671588794803324, 2.518481314496759, 2.4680...
# 5108  [2.1275650240376835, 1.963632386103219, 1.9258...
# 5109  [1.7114283277425177, 1.7240385306605557, 1.686...
# 5110  [0.9800365584964896, 0.43779783302097325, 0.39...
#
#                                       precipitation(mm)  \
# 0     [-0.11906781300263639, -0.11906781300263639, -...
# 1     [-0.11906781300263639, -0.11906781300263639, -...
# 2     [-0.11906781300263639, -0.11906781300263639, -...
# 3     [-0.11906781300263639, -0.11906781300263639, -...
# 4     [-0.11906781300263639, -0.11906781300263639, -...
# ...                                                 ...
# 5106  [-0.11906781300263639, -0.11906781300263639, -...
# 5107  [-0.11906781300263639, -0.11906781300263639, -...
# 5108  [-0.11906781300263639, -0.11906781300263639, -...
# 5109  [-0.11906781300263639, -0.11906781300263639, -...
# 5110  [-0.11906781300263639, -0.11906781300263639, -...
#
#                                             PM10_Counts
# 0     [-0.32022983414764833, -0.15608473051877228, -...
# 1     [-0.15608473051877228, 0.19956299401045927, 0....
# 2     [0.500495683996732, 1.1570760985122364, 1.4032...
# 3     [0.500495683996732, 0.9929309948833603, 1.4032...
# 4     [0.36370809763933537, 1.512723823041468, 1.649...
# ...                                                 ...
# 5106  [-0.21079976506173095, -0.7853076277627973, -0...
# 5107  [-0.8126651450342767, -0.9494527313916734, -0....
# 5108  [-0.8673801795772353, -0.48437493777652446, -0...
# 5109  [-0.18344224779025162, 0.06277540765306251, 0....
# 5110  [0.14484795946750056, 0.36370809763933537, 0.5...
#
# [5111 rows x 9 columns]

# %% [markdown]
# ## 1.5. Dataset Preparation

# %%
data = pd.concat([features, target["Air_is_bad?"]], axis=1)

# %%
data
# Out:
#        date_new                                     wind_direction  \
# 0    2008-01-02  [0.924452475006894, 1.1974764438963235, 1.1974...
# 1    2008-01-03  [-1.7147792242575914, -1.2597392761085422, -1....
# 2    2008-01-04  [0.924452475006894, -1.5327632449979716, 1.379...
# 3    2008-01-05  [0.7424364957472743, -1.5327632449979716, -1.2...
# 4    2008-01-06  [-1.5327632449979716, -0.8957073175893028, -0....
# ...         ...                                                ...
# 5106 2021-12-25  [0.924452475006894, 0.924452475006894, 0.74243...
# 5107 2021-12-26  [0.7424364957472743, 0.7424364957472743, 0.924...
# 5108 2021-12-27  [1.1974764438963235, -1.2597392761085422, -0.8...
# 5109 2021-12-28  [-1.5327632449979716, -1.2597392761085422, -1....
# 5110 2021-12-29  [-1.5327632449979716, -1.0777232968489225, -1....
#
#                                             humidity(%)  \
# 0     [-0.16491600114460359, -0.665906724059201, -0....
# 1     [-0.06471785656168408, -0.11481692885314383, -...
# 2     [0.035480288021235415, -0.01461878427022433, -...
# 3     [-0.6158076517677413, 0.035480288021235415, -0...
# 4     [0.8871645169760511, 0.5364710109358329, 0.436...
# ...                                                 ...
# 5106  [-0.4655104348933621, -0.9164020855164998, -1....
# 5107  [-0.7160057963506608, -0.8162039409335803, -0....
# 5108  [-0.36531229031044254, -0.31521321801898283, -...
# 5109  [1.1376598784333498, 1.0374617338504304, 0.636...
# 5110  [0.8871645169760511, 1.0374617338504304, 0.887...
#
#                                    lowest_ceiling(100m)  \
# 0     [-0.5452500390488106, -0.5452500390488106, -0....
# 1     [-0.22368526895253332, -0.8668148091450879, -0...
# 2     [-0.8668148091450879, -0.8668148091450879, -0....
# 3     [-0.5452500390488106, -0.5452500390488106, -0....
# 4     [-0.4380617823500515, -0.974003065843847, -0.9...
# ...                                                 ...
# 5106  [-0.11649701225377423, -0.11649701225377423, -...
# 5107  [-0.11649701225377423, -0.11649701225377423, -...
# 5108  [-0.11649701225377423, -0.11649701225377423, -...
# 5109  [-0.3308735256512924, -0.3308735256512924, -0....
# 5110  [-0.11649701225377423, -0.4380617823500515, -0...
#
#                                                temp(°C)  \
# 0     [-1.7379632433239907, -1.62958516404385, -1.53...
# 1     [-1.3496084592368196, -1.1870413403166087, -1....
# 2     [-1.2231673667433223, -1.2592933931700356, -1....
# 3     [-1.1328523006765383, -1.12382079406986, -0.97...
# 4     [-1.0515687412164327, -0.8619071024761865, -0....
# ...                                                 ...
# 5106  [-1.8102152961774178, -2.252759119904659, -2.1...
# 5107  [-2.451452265251584, -2.388231719004835, -2.29...
# 5108  [-2.2437276132979806, -1.9185933754575586, -1....
# 5109  [-1.7199002301106339, -1.6657111904705635, -1....
# 5110  [-1.4399235253036036, -1.1328523006765383, -1....
#
#                                         wind_speed(m/s)  \
# 0     [-0.5164077188699413, 0.11713131692002768, 0.1...
# 1     [-1.8538790166487649, -0.6571941712677122, -0....
# 2     [0.046738090721142475, -0.5164077188699413, -1...
# 3     [-0.9387670760632539, -0.6571941712677122, -1....
# 4     [-1.0091603022621394, -1.0795535284610247, -1....
# ...                                                 ...
# 5106  [1.5953890670966224, 0.609883900312226, 0.6802...
# 5107  [-0.3756212664721703, 0.6802771265111115, 0.18...
# 5108  [-0.23483481407439957, -0.5164077188699413, -0...
# 5109  [-0.30522804027328476, -0.3756212664721703, -0...
# 5110  [-0.7275873974665975, -1.0091603022621394, -0....
#
#                                            local_P(hPa)  \
# 0     [0.9043753409882764, 1.1817998051850536, 1.181...
# 1     [1.1187487905948783, 0.7782733118079257, 0.778...
# 2     [1.1817998051850536, 1.3331222402014657, 1.333...
# 3     [0.9548161526604138, 0.9043753409882764, 0.904...
# 4     [0.9548161526604138, 0.9043753409882764, 0.904...
# ...                                                 ...
# 5106  [1.2700712256112905, 2.039293603611432, 2.0392...
# 5107  [2.3671588794803324, 2.518481314496759, 2.4680...
# 5108  [2.1275650240376835, 1.963632386103219, 1.9258...
# 5109  [1.7114283277425177, 1.7240385306605557, 1.686...
# 5110  [0.9800365584964896, 0.43779783302097325, 0.39...
#
#                                       precipitation(mm)  \
# 0     [-0.11906781300263639, -0.11906781300263639, -...
# 1     [-0.11906781300263639, -0.11906781300263639, -...
# 2     [-0.11906781300263639, -0.11906781300263639, -...
# 3     [-0.11906781300263639, -0.11906781300263639, -...
# 4     [-0.11906781300263639, -0.11906781300263639, -...
# ...                                                 ...
# 5106  [-0.11906781300263639, -0.11906781300263639, -...
# 5107  [-0.11906781300263639, -0.11906781300263639, -...
# 5108  [-0.11906781300263639, -0.11906781300263639, -...
# 5109  [-0.11906781300263639, -0.11906781300263639, -...
# 5110  [-0.11906781300263639, -0.11906781300263639, -...
#
#                                             PM10_Counts  Air_is_bad?
# 0     [-0.32022983414764833, -0.15608473051877228, -...            1
# 1     [-0.15608473051877228, 0.19956299401045927, 0....            1
# 2     [0.500495683996732, 1.1570760985122364, 1.4032...            1
# 3     [0.500495683996732, 0.9929309948833603, 1.4032...            1
# 4     [0.36370809763933537, 1.512723823041468, 1.649...            1
# ...                                                 ...          ...
# 5106  [-0.21079976506173095, -0.7853076277627973, -0...            0
# 5107  [-0.8126651450342767, -0.9494527313916734, -0....            0
# 5108  [-0.8673801795772353, -0.48437493777652446, -0...            1
# 5109  [-0.18344224779025162, 0.06277540765306251, 0....            1
# 5110  [0.14484795946750056, 0.36370809763933537, 0.5...            0
#
# [5111 rows x 10 columns]

# %% [markdown]
# ### 1.5.1. Preparation of X

# %%
# To filter out data with inconsistent length

for i in tqdm(range(len(data))):
    for j in range(1, 7):
        if len(data.iloc[i, j]) != 24:
            print(i, j, len(data.iloc[i, j]))
        else:
            continue
# Out:
#  74%|████████████████████████████████████████████████████████▍                   | 3797/5111 [00:00<00:00, 6345.30it/s]
# 2791 1 23
# 2791 2 23
# 2791 3 23
# 2791 4 23
# 2791 5 23
# 2791 6 23
# 2801 1 23
# 2801 2 23
# 2801 3 23
# 2801 4 23
# 2801 5 23
# 2801 6 23
# 100%|████████████████████████████████████████████████████████████████████████████| 5111/5111 [00:00<00:00, 6237.65it/s]

# %%
data = data.drop([2791, 2801], axis=0)

# %%
feature_array = []
for i in tqdm(range(len(data))):
    row_array = []
    for j in range(1, 9):
        row_array.append(np.array(data.iloc[i, j]))
    stacked_row_array = np.stack(row_array, axis=0)
    feature_array.append(stacked_row_array)

X = np.stack(feature_array, axis=0)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████| 5109/5109 [00:01<00:00, 3870.47it/s]

# %%
X.shape
# Out:
# (5109, 8, 24)

# %% [markdown]
# ### 1.5.2. Preparation of y

# %%
y = np.array(data["Air_is_bad?"])

# %%
y.shape
# Out:
# (5109,)

# %% [markdown]
# ### 1.5.3. Train/Valid/Test Split for Deep Learning

# %%
# To find the index to split the data into train and test set
len(data.loc[data["date_new"].dt.date < datetime.date(2016, 1, 1)])
# Out:
# 2919

# %%
# To find the index to split the test data into valid and test set
len(data.loc[data["date_new"].dt.date < datetime.date(2018, 1, 1)])
# Out:
# 3650

# %%
X_train = X[:2919, :, :]
X_valid = X[2919:3650, :, :]
X_test = X[3650:, :, :]

y_train = y[:2919]
y_valid = y[2919:3650]
y_test = y[3650:]

# %% [markdown]
# # 2. Multi-Scale Timeseries Classification Using 1-D CNN

# %% [markdown]
# ## 2.1. DataLoader Preparation

# %%
X_train_tensor = torch.Tensor(X_train)
X_valid_tensor = torch.Tensor(X_valid)
X_test_tensor = torch.Tensor(X_test)

y_train_tensor = torch.Tensor(y_train)
y_valid_tensor = torch.Tensor(y_valid)
y_test_tensor = torch.Tensor(y_test)

# %%
train_dataset = TensorDataset(X_train_tensor, y_train_tensor)
trainloader = DataLoader(train_dataset, batch_size=28, shuffle=True)

valid_dataset = TensorDataset(X_valid_tensor, y_valid_tensor)
validloader = DataLoader(valid_dataset, batch_size=10, shuffle=True)

test_dataset = TensorDataset(X_test_tensor, y_test_tensor)
testloader = DataLoader(test_dataset, batch_size=10, shuffle=True)

# %% [markdown]
# ## 2.2. Sample Check

# %%
weather, label = next(iter(trainloader))
i = np.random.randint(0, 28)
fig, axs = plt.subplots(nrows=2, ncols=4)
r = 0
c = 0
for j in range(8):
    axs[r, c].plot(weather[i, j, :])
    axs[r, c].set_title(f"{feature_names[j]}")
    if c < 3:
        c += 1
    else:
        r += 1
        c = 0
fig.suptitle(f"Air Quality Bad? {bool(label[i])}")
plt.tight_layout()
plt.show();

# %% [markdown]
# ## 2.3. Preparation of CNN

# %%
class ConvolutionalNeuralNetwork(nn.Module):
    def __init__(
        self,
        trial,
        num_filter_1,
        num_filter_2,
        num_filter_3,
        num_fc,
        drop_out_rate_1,
        drop_out_rate_2,
        drop_out_rate_3,
    ):
        """
        Parameters:
            - trial (optuna.trial._trial.Trial): Optuna trial
            - num_filters (int):                 Number of filters of conv layers
            - num_fc (int):                      Number of neurons of FC layers
            - drop_out_rate (float):             Dropout ratio
        """
        super(ConvolutionalNeuralNetwork, self).__init__()
        self.main = nn.Sequential(
            nn.Conv1d(8, num_filter_1, kernel_size=3, padding=1),  # num_filter_1, 24
            nn.ReLU(),
            nn.MaxPool1d(2),  # num_filter_1, 12
            nn.Dropout(drop_out_rate_1),
            nn.Conv1d(
                num_filter_1, num_filter_2, kernel_size=3, padding=1
            ),  # num_filter_2, 12
            nn.ReLU(),
            nn.MaxPool1d(2),  # num_filter_2,  6
            nn.Dropout(drop_out_rate_2),
            nn.Conv1d(
                num_filter_2, num_filter_3, kernel_size=3, padding=1
            ),  # num_filter_3, 6
            nn.ReLU(),
            nn.MaxPool1d(2),  # num_filter_3, 3
            nn.Dropout(drop_out_rate_3),
            nn.Flatten(),  # num_filter_3 x 3
            nn.Linear(num_filter_3 * 3, num_fc),  # num_fc
            nn.ReLU(),
            nn.Linear(num_fc, 1),
        )

    def forward(self, x):
        logits = self.main(x)
        return logits

# %% [markdown]
# ## 2.4. Preparation of Optuna Objective Function

# %%
def train(network, optimizer, trainloader, criterion):
    """Trains the model.

    Parameters:
        - network (__main__.Net):              The CNN
        - optimizer (torch.optim.<optimizer>): The optimizer for the CNN
    """
    network.train()  # Set the module in training mode (only affects certain modules)
    for batch_i, (X, y) in enumerate(trainloader):  # For each batch

        optimizer.zero_grad()  # Clear gradients
        y_hat = network(X)  # Forward propagation
        loss = criterion(
            y_hat, y.unsqueeze(1)
        )  # Compute loss (negative log likelihood: −log(y))
        loss.backward()  # Compute gradients
        optimizer.step()  # Update weights

# %%
def test(network, validloader, criterion):
    """Tests the model.

    Parameters:
        - network (__main__.Net): The CNN

    Returns:
        - accuracy_test (torch.Tensor): The test accuracy
    """
    network.eval()  # Set the module in evaluation mode (only affects certain modules)

    valid_batch_acc = 0

    with torch.no_grad():  # Disable gradient calculation (when you are sure that you will not call Tensor.backward())
        for batch_i, (X, y) in enumerate(validloader):  # For each batch

            y_hat = network(X)  # Forward propagation
            y_hat_labels = torch.sigmoid(y_hat) > 0.5
            valid_batch_acc += (
                (y_hat_labels.squeeze() == y).type(torch.float32).mean().item()
            )

    valid_accuracy = valid_batch_acc / len(validloader)  # accuracy

    return valid_accuracy

# %%
def objective(trial):
    """Objective function to be optimized by Optuna.

    Hyperparameters chosen to be optimized: optimizer, learning rate,
    number of filters, number of neurons in fully connected layer, and dropout values,

    Inputs:
        - trial (optuna.trial._trial.Trial): Optuna trial
    Returns:
        - accuracy(torch.Tensor): The test accuracy. Parameter to be maximized.
    """

    # Define range of values to be tested for the hyperparameters
    num_filter_1 = trial.suggest_int("num_filter_1", 4, 32, 4)
    num_filter_2 = trial.suggest_int("num_filter_2", 4, 32, 4)
    num_filter_3 = trial.suggest_int("num_filter_3", 4, 32, 4)
    num_fc = trial.suggest_int("num_fc", 2, 12, 2)
    drop_out_rate_1 = trial.suggest_float("drop_out_rate_1", 0.1, 0.35, step=0.05)
    drop_out_rate_2 = trial.suggest_float("drop_out_rate_2", 0.1, 0.35, step=0.05)
    drop_out_rate_3 = trial.suggest_float("drop_out_rate_3", 0.1, 0.35, step=0.05)

    # Generate the model
    model = ConvolutionalNeuralNetwork(
        trial,
        num_filter_1,
        num_filter_2,
        num_filter_3,
        num_fc,
        drop_out_rate_1,
        drop_out_rate_2,
        drop_out_rate_3,
    )  # .to(device)

    # Generate the optimizers
    optimizer_name = trial.suggest_categorical(
        "optimizer", ["Adam", "RMSprop", "SGD"]
    )  # Optimizers
    lr = trial.suggest_float("lr", 1e-5, 1e-1, log=True)  # Learning rates
    optimizer = getattr(optim, optimizer_name)(model.parameters(), lr=lr)

    for epoch in range(n_epochs):
        train(model, optimizer, trainloader, criterion)  # Train the model
        accuracy = test(model, validloader, criterion)  # Evaluate the model

        # For pruning (stops trial early if not promising)
        trial.report(accuracy, epoch)
        # Handle pruning based on the intermediate value.
        if trial.should_prune():
            raise optuna.exceptions.TrialPruned()

    return accuracy

# %% [markdown]
# ## 2.5. Hyperparameter Optimization

# %%
n_epochs = 100  # Number of training epochs
number_of_trials = 200  # Number of Optuna trials
criterion = nn.BCEWithLogitsLoss()

# %%
study = optuna.create_study(direction="maximize")
# Out:
# [I 2023-07-29 17:55:05,318] A new study created in memory with name: no-name-b1bdab8f-cbe5-4a6c-bb77-dc754315edb3

# %%
study.optimize(objective, n_trials=number_of_trials)
# Out:
# [I 2023-07-29 17:56:24,069] Trial 0 finished with value: 0.766216213235984 and parameters: {'num_filter_1': 32, 'num_filter_2': 16, 'num_filter_3': 16, 'num_fc': 2, 'drop_out_rate_1': 0.15000000000000002, 'drop_out_rate_2': 0.2, 'drop_out_rate_3': 0.35, 'optimizer': 'RMSprop', 'lr': 5.72045898195759e-05}. Best is trial 0 with value: 0.766216213235984.
# [I 2023-07-29 17:57:31,978] Trial 1 finished with value: 0.7540540526042113 and parameters: {'num_filter_1': 16, 'num_filter_2': 12, 'num_filter_3': 32, 'num_fc': 6, 'drop_out_rate_1': 0.35, 'drop_out_rate_2': 0.2, 'drop_out_rate_3': 0.2, 'optimizer': 'RMSprop', 'lr': 4.017559794868801e-05}. Best is trial 0 with value: 0.766216213235984.
# [I 2023-07-29 17:58:50,452] Trial 2 finished with value: 0.5675675730044777 and parameters: {'num_filter_1': 28, 'num_filter_2': 8, 'num_filter_3': 8, 'num_fc': 12, 'drop_out_rate_1': 0.25, 'drop_out_rate_2': 0.15000000000000002, 'drop_out_rate_3': 0.1, 'optimizer': 'SGD', 'lr': 0.0006350599571656369}. Best is trial 0 with value: 0.766216213235984.
# [I 2023-07-29 18:00:24,985] Trial 3 finished with value: 0.8121621608734131 and parameters: {'num_filter_1': 16, 'num_filter_2': 24, 'num_filter_3': 8, 'num_fc': 8, 'drop_out_rate_1': 0.25, 'drop_out_rate_2': 0.2, 'drop_out_rate_3': 0.35, 'optimizer': 'Adam', 'lr': 0.002978364828064917}. Best is trial 3 with value: 0.8121621608734131.
# [I 2023-07-29 18:01:42,573] Trial 4 finished with value: 0.5662162225391414 and parameters: {'num_filter_1': 24, 'num_filter_2': 4, 'num_filter_3': 20, 'num_fc': 8, 'drop_out_rate_1': 0.2, 'drop_out_rate_2': 0.1, 'drop_out_rate_3': 0.25, 'optimizer': 'SGD', 'lr': 2.6396718794206437e-05}. Best is trial 3 with value: 0.8121621608734131.
# [I 2023-07-29 18:01:49,845] Trial 5 pruned.
# [I 2023-07-29 18:03:24,218] Trial 6 finished with value: 0.7810810828531111 and parameters: {'num_filter_1': 4, 'num_filter_2': 24, 'num_filter_3': 12, 'num_fc': 6, 'drop_out_rate_1': 0.25, 'drop_out_rate_2': 0.1, 'drop_out_rate_3': 0.30000000000000004, 'optimizer': 'Adam', 'lr': 0.01828546550962063}. Best is trial 3 with value: 0.8121621608734131.
# [I 2023-07-29 18:03:24,997] Trial 7 pruned.
# [I 2023-07-29 18:04:25,383] Trial 8 finished with value: 0.7810810766107327 and parameters: {'num_filter_1': 28, 'num_filter_2': 32, 'num_filter_3': 16, 'num_fc': 8, 'drop_out_rate_1': 0.15000000000000002, 'drop_out_rate_2': 0.2, 'drop_out_rate_3': 0.25, 'optimizer': 'Adam', 'lr': 0.009334257858737531}. Best is trial 3 with value: 0.8121621608734131.
# [I 2023-07-29 18:04:26,302] Trial 9 pruned.
# [I 2023-07-29 18:04:45,648] Trial 10 pruned.
# [I 2023-07-29 18:04:56,198] Trial 11 pruned.
# [I 2023-07-29 18:06:27,317] Trial 12 finished with value: 0.7662162136387181 and parameters: {'num_filter_1': 4, 'num_filter_2': 24, 'num_filter_3': 4, 'num_fc': 6, 'drop_out_rate_1': 0.30000000000000004, 'drop_out_rate_2': 0.15000000000000002, 'drop_out_rate_3': 0.30000000000000004, 'optimizer': 'Adam', 'lr': 0.011082101404402085}. Best is trial 3 with value: 0.8121621608734131.
# [I 2023-07-29 18:07:25,261] Trial 13 finished with value: 0.8013513478878382 and parameters: {'num_filter_1': 20, 'num_filter_2': 28, 'num_filter_3': 12, 'num_fc': 10, 'drop_out_rate_1': 0.30000000000000004, 'drop_out_rate_2': 0.25, 'drop_out_rate_3': 0.35, 'optimizer': 'Adam', 'lr': 0.000924938052503446}. Best is trial 3 with value: 0.8121621608734131.
# [I 2023-07-29 18:07:25,875] Trial 14 pruned.
# [I 2023-07-29 18:08:23,905] Trial 15 finished with value: 0.8162162122694222 and parameters: {'num_filter_1': 20, 'num_filter_2': 28, 'num_filter_3': 24, 'num_fc': 10, 'drop_out_rate_1': 0.30000000000000004, 'drop_out_rate_2': 0.30000000000000004, 'drop_out_rate_3': 0.35, 'optimizer': 'Adam', 'lr': 0.0022195754664554633}. Best is trial 15 with value: 0.8162162122694222.
# [I 2023-07-29 18:09:56,797] Trial 16 finished with value: 0.8135135125469517 and parameters: {'num_filter_1': 12, 'num_filter_2': 16, 'num_filter_3': 24, 'num_fc': 8, 'drop_out_rate_1': 0.2, 'drop_out_rate_2': 0.30000000000000004, 'drop_out_rate_3': 0.15000000000000002, 'optimizer': 'Adam', 'lr': 0.002552910713520236}. Best is trial 15 with value: 0.8162162122694222.
# [I 2023-07-29 18:09:57,774] Trial 17 pruned.
# [I 2023-07-29 18:09:58,500] Trial 18 pruned.
# [I 2023-07-29 18:09:59,359] Trial 19 pruned.
# [I 2023-07-29 18:10:00,108] Trial 20 pruned.
# [I 2023-07-29 18:11:13,128] Trial 21 finished with value: 0.7972972940754246 and parameters: {'num_filter_1': 16, 'num_filter_2': 28, 'num_filter_3': 20, 'num_fc': 8, 'drop_out_rate_1': 0.25, 'drop_out_rate_2': 0.30000000000000004, 'drop_out_rate_3': 0.30000000000000004, 'optimizer': 'Adam', 'lr': 0.002864041963009194}. Best is trial 15 with value: 0.8162162122694222.
# [I 2023-07-29 18:12:18,749] Trial 22 finished with value: 0.7999999962142996 and parameters: {'num_filter_1': 20, 'num_filter_2': 20, 'num_filter_3': 28, 'num_fc': 10, 'drop_out_rate_1': 0.2, 'drop_out_rate_2': 0.25, 'drop_out_rate_3': 0.35, 'optimizer': 'Adam', 'lr': 0.004756543186959891}. Best is trial 15 with value: 0.8162162122694222.
# [I 2023-07-29 18:12:19,528] Trial 23 pruned.
# [I 2023-07-29 18:13:33,458] Trial 24 finished with value: 0.7972972896453496 and parameters: {'num_filter_1': 16, 'num_filter_2': 32, 'num_filter_3': 24, 'num_fc': 10, 'drop_out_rate_1': 0.30000000000000004, 'drop_out_rate_2': 0.2, 'drop_out_rate_3': 0.15000000000000002, 'optimizer': 'Adam', 'lr': 0.004836268214610294}. Best is trial 15 with value: 0.8162162122694222.
# [I 2023-07-29 18:15:02,207] Trial 25 finished with value: 0.8027027011723131 and parameters: {'num_filter_1': 24, 'num_filter_2': 20, 'num_filter_3': 16, 'num_fc': 8, 'drop_out_rate_1': 0.2, 'drop_out_rate_2': 0.25, 'drop_out_rate_3': 0.1, 'optimizer': 'Adam', 'lr': 0.004885556246562998}. Best is trial 15 with value: 0.8162162122694222.
# [I 2023-07-29 18:15:02,956] Trial 26 pruned.
# [I 2023-07-29 18:15:03,621] Trial 27 pruned.
# [I 2023-07-29 18:16:37,013] Trial 28 finished with value: 0.8067567533737904 and parameters: {'num_filter_1': 16, 'num_filter_2': 28, 'num_filter_3': 8, 'num_fc': 10, 'drop_out_rate_1': 0.30000000000000004, 'drop_out_rate_2': 0.25, 'drop_out_rate_3': 0.2, 'optimizer': 'RMSprop', 'lr': 0.001191518635828248}. Best is trial 15 with value: 0.8162162122694222.
# [I 2023-07-29 18:16:37,937] Trial 29 pruned.
# [I 2023-07-29 18:17:47,579] Trial 30 finished with value: 0.8189189123946268 and parameters: {'num_filter_1': 12, 'num_filter_2': 20, 'num_filter_3': 24, 'num_fc': 6, 'drop_out_rate_1': 0.35, 'drop_out_rate_2': 0.15000000000000002, 'drop_out_rate_3': 0.30000000000000004, 'optimizer': 'RMSprop', 'lr': 0.003172317460779573}. Best is trial 30 with value: 0.8189189123946268.
# [I 2023-07-29 18:17:53,148] Trial 31 pruned.
# [I 2023-07-29 18:19:00,906] Trial 32 finished with value: 0.7783783754786929 and parameters: {'num_filter_1': 8, 'num_filter_2': 24, 'num_filter_3': 32, 'num_fc': 6, 'drop_out_rate_1': 0.35, 'drop_out_rate_2': 0.15000000000000002, 'drop_out_rate_3': 0.35, 'optimizer': 'RMSprop', 'lr': 0.005269217695657296}. Best is trial 30 with value: 0.8189189123946268.
# [I 2023-07-29 18:19:01,845] Trial 33 pruned.
# [I 2023-07-29 18:19:02,575] Trial 34 pruned.
# [I 2023-07-29 18:20:03,384] Trial 35 finished with value: 0.8175675639429608 and parameters: {'num_filter_1': 20, 'num_filter_2': 20, 'num_filter_3': 24, 'num_fc': 6, 'drop_out_rate_1': 0.25, 'drop_out_rate_2': 0.2, 'drop_out_rate_3': 0.25, 'optimizer': 'RMSprop', 'lr': 0.002200122415355043}. Best is trial 30 with value: 0.8189189123946268.
# [I 2023-07-29 18:20:04,244] Trial 36 pruned.
# [I 2023-07-29 18:20:05,098] Trial 37 pruned.
# [I 2023-07-29 18:20:09,923] Trial 38 pruned.
# [I 2023-07-29 18:21:10,845] Trial 39 finished with value: 0.7864864859226588 and parameters: {'num_filter_1': 24, 'num_filter_2': 20, 'num_filter_3': 20, 'num_fc': 4, 'drop_out_rate_1': 0.15000000000000002, 'drop_out_rate_2': 0.30000000000000004, 'drop_out_rate_3': 0.2, 'optimizer': 'RMSprop', 'lr': 0.0020600415421683205}. Best is trial 30 with value: 0.8189189123946268.
# [I 2023-07-29 18:21:11,737] Trial 40 pruned.
# [I 2023-07-29 18:22:19,696] Trial 41 finished with value: 0.8027026991586428 and parameters: {'num_filter_1': 12, 'num_filter_2': 24, 'num_filter_3': 24, 'num_fc': 8, 'drop_out_rate_1': 0.2, 'drop_out_rate_2': 0.2, 'drop_out_rate_3': 0.30000000000000004, 'optimizer': 'RMSprop', 'lr': 0.0033221512083193554}. Best is trial 30 with value: 0.8189189123946268.
# [I 2023-07-29 18:22:20,394] Trial 42 pruned.
# [I 2023-07-29 18:22:21,435] Trial 43 pruned.
# [I 2023-07-29 18:23:28,880] Trial 44 finished with value: 0.7797297255412953 and parameters: {'num_filter_1': 8, 'num_filter_2': 20, 'num_filter_3': 24, 'num_fc': 8, 'drop_out_rate_1': 0.30000000000000004, 'drop_out_rate_2': 0.2, 'drop_out_rate_3': 0.30000000000000004, 'optimizer': 'RMSprop', 'lr': 0.002786281979125832}. Best is trial 30 with value: 0.8189189123946268.
# [I 2023-07-29 18:24:27,046] Trial 45 finished with value: 0.8013513442632314 and parameters: {'num_filter_1': 20, 'num_filter_2': 28, 'num_filter_3': 16, 'num_fc': 6, 'drop_out_rate_1': 0.2, 'drop_out_rate_2': 0.15000000000000002, 'drop_out_rate_3': 0.35, 'optimizer': 'Adam', 'lr': 0.010699103797816838}. Best is trial 30 with value: 0.8189189123946268.
# [I 2023-07-29 18:24:27,826] Trial 46 pruned.
# [I 2023-07-29 18:24:33,749] Trial 47 pruned.
# [I 2023-07-29 18:24:34,444] Trial 48 pruned.
# [I 2023-07-29 18:24:35,572] Trial 49 pruned.
# [I 2023-07-29 18:25:42,787] Trial 50 finished with value: 0.7864864843117224 and parameters: {'num_filter_1': 24, 'num_filter_2': 24, 'num_filter_3': 32, 'num_fc': 8, 'drop_out_rate_1': 0.1, 'drop_out_rate_2': 0.25, 'drop_out_rate_3': 0.15000000000000002, 'optimizer': 'Adam', 'lr': 0.007114074223242913}. Best is trial 30 with value: 0.8189189123946268.
# [I 2023-07-29 18:25:43,747] Trial 51 pruned.
# [I 2023-07-29 18:25:44,720] Trial 52 pruned.
# [I 2023-07-29 18:26:37,745] Trial 53 finished with value: 0.8081081050473291 and parameters: {'num_filter_1': 20, 'num_filter_2': 32, 'num_filter_3': 12, 'num_fc': 12, 'drop_out_rate_1': 0.25, 'drop_out_rate_2': 0.25, 'drop_out_rate_3': 0.15000000000000002, 'optimizer': 'RMSprop', 'lr': 0.0012386138182171953}. Best is trial 30 with value: 0.8189189123946268.
# [I 2023-07-29 18:26:38,331] Trial 54 pruned.
# [I 2023-07-29 18:27:52,957] Trial 55 finished with value: 0.8094594543044632 and parameters: {'num_filter_1': 20, 'num_filter_2': 32, 'num_filter_3': 4, 'num_fc': 12, 'drop_out_rate_1': 0.2, 'drop_out_rate_2': 0.2, 'drop_out_rate_3': 0.15000000000000002, 'optimizer': 'RMSprop', 'lr': 0.002055405129248472}. Best is trial 30 with value: 0.8189189123946268.
# [I 2023-07-29 18:27:53,801] Trial 56 pruned.
# [I 2023-07-29 18:27:54,795] Trial 57 pruned.
# [I 2023-07-29 18:27:55,505] Trial 58 pruned.
# [I 2023-07-29 18:28:02,957] Trial 59 pruned.
# [I 2023-07-29 18:29:09,611] Trial 60 finished with value: 0.7972972964918291 and parameters: {'num_filter_1': 28, 'num_filter_2': 16, 'num_filter_3': 28, 'num_fc': 8, 'drop_out_rate_1': 0.2, 'drop_out_rate_2': 0.2, 'drop_out_rate_3': 0.35, 'optimizer': 'Adam', 'lr': 0.0025756192509969653}. Best is trial 30 with value: 0.8189189123946268.
# [I 2023-07-29 18:30:02,269] Trial 61 finished with value: 0.7702702670483976 and parameters: {'num_filter_1': 20, 'num_filter_2': 32, 'num_filter_3': 12, 'num_fc': 12, 'drop_out_rate_1': 0.25, 'drop_out_rate_2': 0.25, 'drop_out_rate_3': 0.15000000000000002, 'optimizer': 'RMSprop', 'lr': 0.0016716814020292826}. Best is trial 30 with value: 0.8189189123946268.
# [I 2023-07-29 18:30:02,854] Trial 62 pruned.
# [I 2023-07-29 18:30:03,696] Trial 63 pruned.
# [I 2023-07-29 18:30:04,323] Trial 64 pruned.
# [I 2023-07-29 18:30:09,684] Trial 65 pruned.
# [I 2023-07-29 18:31:02,933] Trial 66 finished with value: 0.7986486473598996 and parameters: {'num_filter_1': 20, 'num_filter_2': 28, 'num_filter_3': 16, 'num_fc': 10, 'drop_out_rate_1': 0.25, 'drop_out_rate_2': 0.25, 'drop_out_rate_3': 0.1, 'optimizer': 'RMSprop', 'lr': 0.0018599052527616918}. Best is trial 30 with value: 0.8189189123946268.
# [I 2023-07-29 18:31:03,567] Trial 67 pruned.
# [I 2023-07-29 18:31:04,455] Trial 68 pruned.
# [I 2023-07-29 18:31:08,233] Trial 69 pruned.
# [I 2023-07-29 18:31:09,206] Trial 70 pruned.
# [I 2023-07-29 18:32:40,482] Trial 71 finished with value: 0.7837837857974542 and parameters: {'num_filter_1': 16, 'num_filter_2': 28, 'num_filter_3': 8, 'num_fc': 10, 'drop_out_rate_1': 0.30000000000000004, 'drop_out_rate_2': 0.25, 'drop_out_rate_3': 0.2, 'optimizer': 'RMSprop', 'lr': 0.002454518878097023}. Best is trial 30 with value: 0.8189189123946268.
# [I 2023-07-29 18:32:41,505] Trial 72 pruned.
# [I 2023-07-29 18:32:42,404] Trial 73 pruned.
# [I 2023-07-29 18:32:43,132] Trial 74 pruned.
# [I 2023-07-29 18:33:36,011] Trial 75 finished with value: 0.8013513486933064 and parameters: {'num_filter_1': 20, 'num_filter_2': 32, 'num_filter_3': 12, 'num_fc': 8, 'drop_out_rate_1': 0.30000000000000004, 'drop_out_rate_2': 0.25, 'drop_out_rate_3': 0.2, 'optimizer': 'RMSprop', 'lr': 0.002162821488492381}. Best is trial 30 with value: 0.8189189123946268.
# [I 2023-07-29 18:33:36,929] Trial 76 pruned.
# [I 2023-07-29 18:35:05,299] Trial 77 finished with value: 0.7932432406657451 and parameters: {'num_filter_1': 20, 'num_filter_2': 20, 'num_filter_3': 16, 'num_fc': 6, 'drop_out_rate_1': 0.35, 'drop_out_rate_2': 0.25, 'drop_out_rate_3': 0.15000000000000002, 'optimizer': 'Adam', 'lr': 0.00267131761920775}. Best is trial 30 with value: 0.8189189123946268.
# [I 2023-07-29 18:35:06,059] Trial 78 pruned.
# [I 2023-07-29 18:35:06,971] Trial 79 pruned.
# [I 2023-07-29 18:35:08,149] Trial 80 pruned.
# [I 2023-07-29 18:36:35,782] Trial 81 finished with value: 0.797297295686361 and parameters: {'num_filter_1': 24, 'num_filter_2': 20, 'num_filter_3': 16, 'num_fc': 8, 'drop_out_rate_1': 0.2, 'drop_out_rate_2': 0.30000000000000004, 'drop_out_rate_3': 0.1, 'optimizer': 'Adam', 'lr': 0.00436140958668182}. Best is trial 30 with value: 0.8189189123946268.
# [I 2023-07-29 18:36:36,670] Trial 82 pruned.
# [I 2023-07-29 18:36:41,899] Trial 83 pruned.
# [I 2023-07-29 18:36:42,815] Trial 84 pruned.
# [I 2023-07-29 18:36:43,853] Trial 85 pruned.
# [I 2023-07-29 18:36:44,545] Trial 86 pruned.
# [I 2023-07-29 18:36:45,463] Trial 87 pruned.
# [I 2023-07-29 18:36:46,124] Trial 88 pruned.
# [I 2023-07-29 18:36:47,021] Trial 89 pruned.
# [I 2023-07-29 18:36:47,996] Trial 90 pruned.
# [I 2023-07-29 18:36:48,740] Trial 91 pruned.
# [I 2023-07-29 18:36:49,479] Trial 92 pruned.
# [I 2023-07-29 18:36:50,216] Trial 93 pruned.
# [I 2023-07-29 18:36:50,955] Trial 94 pruned.
# [I 2023-07-29 18:36:51,715] Trial 95 pruned.
# [I 2023-07-29 18:36:54,326] Trial 96 pruned.
# [I 2023-07-29 18:36:54,946] Trial 97 pruned.
# [I 2023-07-29 18:36:55,684] Trial 98 pruned.
# [I 2023-07-29 18:36:56,607] Trial 99 pruned.
# [I 2023-07-29 18:36:57,609] Trial 100 pruned.
# [I 2023-07-29 18:36:58,240] Trial 101 pruned.
# [I 2023-07-29 18:36:59,028] Trial 102 pruned.
# [I 2023-07-29 18:36:59,879] Trial 103 pruned.
# [I 2023-07-29 18:37:53,608] Trial 104 finished with value: 0.8040540540540541 and parameters: {'num_filter_1': 24, 'num_filter_2': 32, 'num_filter_3': 16, 'num_fc': 8, 'drop_out_rate_1': 0.30000000000000004, 'drop_out_rate_2': 0.2, 'drop_out_rate_3': 0.2, 'optimizer': 'RMSprop', 'lr': 0.0027581104853361777}. Best is trial 30 with value: 0.8189189123946268.
# [I 2023-07-29 18:38:47,338] Trial 105 finished with value: 0.7932432434848837 and parameters: {'num_filter_1': 24, 'num_filter_2': 32, 'num_filter_3': 24, 'num_fc': 8, 'drop_out_rate_1': 0.35, 'drop_out_rate_2': 0.2, 'drop_out_rate_3': 0.35, 'optimizer': 'RMSprop', 'lr': 0.003769466936319116}. Best is trial 30 with value: 0.8189189123946268.
# [I 2023-07-29 18:38:47,929] Trial 106 pruned.
# [I 2023-07-29 18:38:48,544] Trial 107 pruned.
# [I 2023-07-29 18:38:49,185] Trial 108 pruned.
# [I 2023-07-29 18:38:49,917] Trial 109 pruned.
# [I 2023-07-29 18:38:50,913] Trial 110 pruned.
# [I 2023-07-29 18:39:43,795] Trial 111 finished with value: 0.8040540500267132 and parameters: {'num_filter_1': 20, 'num_filter_2': 32, 'num_filter_3': 12, 'num_fc': 8, 'drop_out_rate_1': 0.30000000000000004, 'drop_out_rate_2': 0.25, 'drop_out_rate_3': 0.2, 'optimizer': 'RMSprop', 'lr': 0.0023106583794870145}. Best is trial 30 with value: 0.8189189123946268.
# [I 2023-07-29 18:39:44,596] Trial 112 pruned.
# [I 2023-07-29 18:39:45,229] Trial 113 pruned.
# [I 2023-07-29 18:39:45,804] Trial 114 pruned.
# [I 2023-07-29 18:39:46,604] Trial 115 pruned.
# [I 2023-07-29 18:39:47,415] Trial 116 pruned.
# [I 2023-07-29 18:39:48,184] Trial 117 pruned.
# [I 2023-07-29 18:39:48,854] Trial 118 pruned.
# [I 2023-07-29 18:39:49,812] Trial 119 pruned.
# [I 2023-07-29 18:40:44,972] Trial 120 finished with value: 0.8067567533737904 and parameters: {'num_filter_1': 28, 'num_filter_2': 32, 'num_filter_3': 24, 'num_fc': 6, 'drop_out_rate_1': 0.2, 'drop_out_rate_2': 0.25, 'drop_out_rate_3': 0.15000000000000002, 'optimizer': 'RMSprop', 'lr': 0.0009256222697539482}. Best is trial 30 with value: 0.8189189123946268.
# [I 2023-07-29 18:40:45,541] Trial 121 pruned.
# [I 2023-07-29 18:40:46,149] Trial 122 pruned.
# [I 2023-07-29 18:40:47,841] Trial 123 pruned.
# [I 2023-07-29 18:40:50,087] Trial 124 pruned.
# [I 2023-07-29 18:41:47,677] Trial 125 finished with value: 0.80540540250572 and parameters: {'num_filter_1': 20, 'num_filter_2': 28, 'num_filter_3': 24, 'num_fc': 6, 'drop_out_rate_1': 0.2, 'drop_out_rate_2': 0.2, 'drop_out_rate_3': 0.2, 'optimizer': 'Adam', 'lr': 0.002939040572121036}. Best is trial 30 with value: 0.8189189123946268.
# [I 2023-07-29 18:41:48,314] Trial 126 pruned.
# [I 2023-07-29 18:41:48,941] Trial 127 pruned.
# [I 2023-07-29 18:41:49,588] Trial 128 pruned.
# [I 2023-07-29 18:41:50,280] Trial 129 pruned.
# [I 2023-07-29 18:41:51,183] Trial 130 pruned.
# [I 2023-07-29 18:42:59,461] Trial 131 finished with value: 0.799999993395161 and parameters: {'num_filter_1': 16, 'num_filter_2': 20, 'num_filter_3': 24, 'num_fc': 8, 'drop_out_rate_1': 0.2, 'drop_out_rate_2': 0.2, 'drop_out_rate_3': 0.15000000000000002, 'optimizer': 'RMSprop', 'lr': 0.0032771964513452173}. Best is trial 30 with value: 0.8189189123946268.
# [I 2023-07-29 18:43:00,138] Trial 132 pruned.
# [I 2023-07-29 18:43:00,947] Trial 133 pruned.
# [I 2023-07-29 18:43:01,732] Trial 134 pruned.
# [I 2023-07-29 18:43:03,545] Trial 135 pruned.
# [I 2023-07-29 18:43:04,373] Trial 136 pruned.
# [I 2023-07-29 18:43:06,443] Trial 137 pruned.
# [I 2023-07-29 18:43:07,357] Trial 138 pruned.
# [I 2023-07-29 18:43:08,078] Trial 139 pruned.
# [I 2023-07-29 18:43:08,719] Trial 140 pruned.
# [I 2023-07-29 18:43:09,595] Trial 141 pruned.
# [I 2023-07-29 18:43:10,215] Trial 142 pruned.
# [I 2023-07-29 18:43:13,582] Trial 143 pruned.
# [I 2023-07-29 18:43:14,507] Trial 144 pruned.
# [I 2023-07-29 18:43:15,232] Trial 145 pruned.
# [I 2023-07-29 18:43:16,127] Trial 146 pruned.
# [I 2023-07-29 18:43:16,941] Trial 147 pruned.
# [I 2023-07-29 18:43:17,701] Trial 148 pruned.
# [I 2023-07-29 18:44:51,143] Trial 149 finished with value: 0.8027026967422383 and parameters: {'num_filter_1': 24, 'num_filter_2': 24, 'num_filter_3': 8, 'num_fc': 8, 'drop_out_rate_1': 0.25, 'drop_out_rate_2': 0.30000000000000004, 'drop_out_rate_3': 0.2, 'optimizer': 'Adam', 'lr': 0.0020359237959924554}. Best is trial 30 with value: 0.8189189123946268.
# [I 2023-07-29 18:44:52,063] Trial 150 pruned.
# [I 2023-07-29 18:44:53,010] Trial 151 pruned.
# [I 2023-07-29 18:44:53,980] Trial 152 pruned.
# [I 2023-07-29 18:44:54,938] Trial 153 pruned.
# [I 2023-07-29 18:44:55,843] Trial 154 pruned.
# [I 2023-07-29 18:44:56,469] Trial 155 pruned.
# [I 2023-07-29 18:44:57,169] Trial 156 pruned.
# [I 2023-07-29 18:44:58,197] Trial 157 pruned.
# [I 2023-07-29 18:44:58,844] Trial 158 pruned.
# [I 2023-07-29 18:44:59,466] Trial 159 pruned.
# [I 2023-07-29 18:45:00,443] Trial 160 pruned.
# [I 2023-07-29 18:45:01,122] Trial 161 pruned.
# [I 2023-07-29 18:45:01,799] Trial 162 pruned.
# [I 2023-07-29 18:45:02,723] Trial 163 pruned.
# [I 2023-07-29 18:45:03,504] Trial 164 pruned.
# [I 2023-07-29 18:45:04,201] Trial 165 pruned.
# [I 2023-07-29 18:45:05,163] Trial 166 pruned.
# [I 2023-07-29 18:45:59,565] Trial 167 finished with value: 0.8094594575263359 and parameters: {'num_filter_1': 20, 'num_filter_2': 28, 'num_filter_3': 24, 'num_fc': 10, 'drop_out_rate_1': 0.2, 'drop_out_rate_2': 0.2, 'drop_out_rate_3': 0.15000000000000002, 'optimizer': 'RMSprop', 'lr': 0.001944412199295145}. Best is trial 30 with value: 0.8189189123946268.
# [I 2023-07-29 18:46:01,292] Trial 168 pruned.
# [I 2023-07-29 18:46:01,952] Trial 169 pruned.
# [I 2023-07-29 18:47:04,803] Trial 170 finished with value: 0.8054054033111882 and parameters: {'num_filter_1': 24, 'num_filter_2': 24, 'num_filter_3': 24, 'num_fc': 8, 'drop_out_rate_1': 0.2, 'drop_out_rate_2': 0.2, 'drop_out_rate_3': 0.15000000000000002, 'optimizer': 'RMSprop', 'lr': 0.0032314709434937477}. Best is trial 30 with value: 0.8189189123946268.
# [I 2023-07-29 18:48:07,806] Trial 171 finished with value: 0.7905405405405406 and parameters: {'num_filter_1': 24, 'num_filter_2': 24, 'num_filter_3': 24, 'num_fc': 8, 'drop_out_rate_1': 0.2, 'drop_out_rate_2': 0.2, 'drop_out_rate_3': 0.15000000000000002, 'optimizer': 'RMSprop', 'lr': 0.003274608537803289}. Best is trial 30 with value: 0.8189189123946268.
# [I 2023-07-29 18:48:08,557] Trial 172 pruned.
# [I 2023-07-29 18:48:09,244] Trial 173 pruned.
# [I 2023-07-29 18:48:09,940] Trial 174 pruned.
# [I 2023-07-29 18:48:11,885] Trial 175 pruned.
# [I 2023-07-29 18:48:13,499] Trial 176 pruned.
# [I 2023-07-29 18:48:14,253] Trial 177 pruned.
# [I 2023-07-29 18:48:14,853] Trial 178 pruned.
# [I 2023-07-29 18:48:16,495] Trial 179 pruned.
# [I 2023-07-29 18:48:17,145] Trial 180 pruned.
# [I 2023-07-29 18:48:17,792] Trial 181 pruned.
# [I 2023-07-29 18:48:18,496] Trial 182 pruned.
# [I 2023-07-29 18:48:19,108] Trial 183 pruned.
# [I 2023-07-29 18:48:21,820] Trial 184 pruned.
# [I 2023-07-29 18:48:24,543] Trial 185 pruned.
# [I 2023-07-29 18:48:25,336] Trial 186 pruned.
# [I 2023-07-29 18:48:26,001] Trial 187 pruned.
# [I 2023-07-29 18:48:26,684] Trial 188 pruned.
# [I 2023-07-29 18:48:29,429] Trial 189 pruned.
# [I 2023-07-29 18:49:28,137] Trial 190 finished with value: 0.7972972940754246 and parameters: {'num_filter_1': 28, 'num_filter_2': 24, 'num_filter_3': 24, 'num_fc': 12, 'drop_out_rate_1': 0.30000000000000004, 'drop_out_rate_2': 0.30000000000000004, 'drop_out_rate_3': 0.30000000000000004, 'optimizer': 'Adam', 'lr': 0.003107946283747139}. Best is trial 30 with value: 0.8189189123946268.
# [I 2023-07-29 18:50:24,544] Trial 191 finished with value: 0.80270269593677 and parameters: {'num_filter_1': 20, 'num_filter_2': 28, 'num_filter_3': 16, 'num_fc': 6, 'drop_out_rate_1': 0.2, 'drop_out_rate_2': 0.15000000000000002, 'drop_out_rate_3': 0.35, 'optimizer': 'Adam', 'lr': 0.0089308037711228}. Best is trial 30 with value: 0.8189189123946268.
# [I 2023-07-29 18:50:25,206] Trial 192 pruned.
# [I 2023-07-29 18:50:25,903] Trial 193 pruned.
# [I 2023-07-29 18:50:26,500] Trial 194 pruned.
# [I 2023-07-29 18:51:23,350] Trial 195 finished with value: 0.7891891882629007 and parameters: {'num_filter_1': 20, 'num_filter_2': 32, 'num_filter_3': 16, 'num_fc': 6, 'drop_out_rate_1': 0.2, 'drop_out_rate_2': 0.15000000000000002, 'drop_out_rate_3': 0.35, 'optimizer': 'Adam', 'lr': 0.005627082812763371}. Best is trial 30 with value: 0.8189189123946268.
# [I 2023-07-29 18:51:25,068] Trial 196 pruned.
# [I 2023-07-29 18:52:50,892] Trial 197 finished with value: 0.7999999990334382 and parameters: {'num_filter_1': 20, 'num_filter_2': 20, 'num_filter_3': 8, 'num_fc': 8, 'drop_out_rate_1': 0.2, 'drop_out_rate_2': 0.15000000000000002, 'drop_out_rate_3': 0.2, 'optimizer': 'Adam', 'lr': 0.009662906370553748}. Best is trial 30 with value: 0.8189189123946268.
# [I 2023-07-29 18:52:51,520] Trial 198 pruned.
# [I 2023-07-29 18:52:52,253] Trial 199 pruned.

# %%
# Find number of pruned and completed trials
pruned_trials = study.get_trials(deepcopy=False, states=[TrialState.PRUNED])
complete_trials = study.get_trials(deepcopy=False, states=[TrialState.COMPLETE])

# %%
# Display the study statistics
print("\nStudy statistics: ")
print("  Number of finished trials: ", len(study.trials))
print("  Number of pruned trials: ", len(pruned_trials))
print("  Number of complete trials: ", len(complete_trials))
# Out:
# Study statistics:
#   Number of finished trials:  200
#   Number of pruned trials:  153
#   Number of complete trials:  47

# %%
trial = study.best_trial
print("Best trial:")
print("  Value: ", trial.value)
print("  Params: ")
for key, value in trial.params.items():
    print("    {}: {}".format(key, value))
# Out:
# Best trial:
#   Value:  0.8189189123946268
#   Params:
#     num_filter_1: 12
#     num_filter_2: 20
#     num_filter_3: 24
#     num_fc: 6
#     drop_out_rate_1: 0.35
#     drop_out_rate_2: 0.15000000000000002
#     drop_out_rate_3: 0.30000000000000004
#     optimizer: RMSprop
#     lr: 0.003172317460779573

# %%
# Save results to csv file
hyper_df = study.trials_dataframe().drop(
    ["datetime_start", "datetime_complete", "duration"], axis=1
)  # Exclude columns
hyper_df = hyper_df.loc[
    hyper_df["state"] == "COMPLETE"
]  # Keep only results that did not prune
hyper_df = hyper_df.drop("state", axis=1)  # Exclude state column
hyper_df = hyper_df.sort_values("value")  # Sort based on accuracy
hyper_df.to_csv("../data/optuna_results.csv", index=False)  # Save to csv file

# %%
# Display results in a dataframe
print("\nOverall Results (ordered by accuracy):\n")
hyper_df
# Out:
# Overall Results (ordered by accuracy):
#      number     value  params_drop_out_rate_1  params_drop_out_rate_2  \
# 4         4  0.566216                    0.20                    0.10
# 2         2  0.567568                    0.25                    0.15
# 1         1  0.754054                    0.35                    0.20
# 0         0  0.766216                    0.15                    0.20
# 12       12  0.766216                    0.30                    0.15
# 61       61  0.770270                    0.25                    0.25
# 32       32  0.778378                    0.35                    0.15
# 44       44  0.779730                    0.30                    0.20
# 8         8  0.781081                    0.15                    0.20
# 6         6  0.781081                    0.25                    0.10
# 71       71  0.783784                    0.30                    0.25
# 50       50  0.786486                    0.10                    0.25
# 39       39  0.786486                    0.15                    0.30
# 195     195  0.789189                    0.20                    0.15
# 171     171  0.790541                    0.20                    0.20
# 77       77  0.793243                    0.35                    0.25
# 105     105  0.793243                    0.35                    0.20
# 24       24  0.797297                    0.30                    0.20
# 190     190  0.797297                    0.30                    0.30
# 21       21  0.797297                    0.25                    0.30
# 81       81  0.797297                    0.20                    0.30
# 60       60  0.797297                    0.20                    0.20
# 66       66  0.798649                    0.25                    0.25
# 131     131  0.800000                    0.20                    0.20
# 22       22  0.800000                    0.20                    0.25
# 197     197  0.800000                    0.20                    0.15
# 45       45  0.801351                    0.20                    0.15
# 13       13  0.801351                    0.30                    0.25
# 75       75  0.801351                    0.30                    0.25
# 191     191  0.802703                    0.20                    0.15
# 149     149  0.802703                    0.25                    0.30
# 41       41  0.802703                    0.20                    0.20
# 25       25  0.802703                    0.20                    0.25
# 111     111  0.804054                    0.30                    0.25
# 104     104  0.804054                    0.30                    0.20
# 125     125  0.805405                    0.20                    0.20
# 170     170  0.805405                    0.20                    0.20
# 120     120  0.806757                    0.20                    0.25
# 28       28  0.806757                    0.30                    0.25
# 53       53  0.808108                    0.25                    0.25
# 55       55  0.809459                    0.20                    0.20
# 167     167  0.809459                    0.20                    0.20
# 3         3  0.812162                    0.25                    0.20
# 16       16  0.813514                    0.20                    0.30
# 15       15  0.816216                    0.30                    0.30
# 35       35  0.817568                    0.25                    0.20
# 30       30  0.818919                    0.35                    0.15
#
#      params_drop_out_rate_3  params_lr  params_num_fc  params_num_filter_1  \
# 4                      0.25   0.000026              8                   24
# 2                      0.10   0.000635             12                   28
# 1                      0.20   0.000040              6                   16
# 0                      0.35   0.000057              2                   32
# 12                     0.30   0.011082              6                    4
# 61                     0.15   0.001672             12                   20
# 32                     0.35   0.005269              6                    8
# 44                     0.30   0.002786              8                    8
# 8                      0.25   0.009334              8                   28
# 6                      0.30   0.018285              6                    4
# 71                     0.20   0.002455             10                   16
# 50                     0.15   0.007114              8                   24
# 39                     0.20   0.002060              4                   24
# 195                    0.35   0.005627              6                   20
# 171                    0.15   0.003275              8                   24
# 77                     0.15   0.002671              6                   20
# 105                    0.35   0.003769              8                   24
# 24                     0.15   0.004836             10                   16
# 190                    0.30   0.003108             12                   28
# 21                     0.30   0.002864              8                   16
# 81                     0.10   0.004361              8                   24
# 60                     0.35   0.002576              8                   28
# 66                     0.10   0.001860             10                   20
# 131                    0.15   0.003277              8                   16
# 22                     0.35   0.004757             10                   20
# 197                    0.20   0.009663              8                   20
# 45                     0.35   0.010699              6                   20
# 13                     0.35   0.000925             10                   20
# 75                     0.20   0.002163              8                   20
# 191                    0.35   0.008931              6                   20
# 149                    0.20   0.002036              8                   24
# 41                     0.30   0.003322              8                   12
# 25                     0.10   0.004886              8                   24
# 111                    0.20   0.002311              8                   20
# 104                    0.20   0.002758              8                   24
# 125                    0.20   0.002939              6                   20
# 170                    0.15   0.003231              8                   24
# 120                    0.15   0.000926              6                   28
# 28                     0.20   0.001192             10                   16
# 53                     0.15   0.001239             12                   20
# 55                     0.15   0.002055             12                   20
# 167                    0.15   0.001944             10                   20
# 3                      0.35   0.002978              8                   16
# 16                     0.15   0.002553              8                   12
# 15                     0.35   0.002220             10                   20
# 35                     0.25   0.002200              6                   20
# 30                     0.30   0.003172              6                   12
#
#      params_num_filter_2  params_num_filter_3 params_optimizer
# 4                      4                   20              SGD
# 2                      8                    8              SGD
# 1                     12                   32          RMSprop
# 0                     16                   16          RMSprop
# 12                    24                    4             Adam
# 61                    32                   12          RMSprop
# 32                    24                   32          RMSprop
# 44                    20                   24          RMSprop
# 8                     32                   16             Adam
# 6                     24                   12             Adam
# 71                    28                    8          RMSprop
# 50                    24                   32             Adam
# 39                    20                   20          RMSprop
# 195                   32                   16             Adam
# 171                   24                   24          RMSprop
# 77                    20                   16             Adam
# 105                   32                   24          RMSprop
# 24                    32                   24             Adam
# 190                   24                   24             Adam
# 21                    28                   20             Adam
# 81                    20                   16             Adam
# 60                    16                   28             Adam
# 66                    28                   16          RMSprop
# 131                   20                   24          RMSprop
# 22                    20                   28             Adam
# 197                   20                    8             Adam
# 45                    28                   16             Adam
# 13                    28                   12             Adam
# 75                    32                   12          RMSprop
# 191                   28                   16             Adam
# 149                   24                    8             Adam
# 41                    24                   24          RMSprop
# 25                    20                   16             Adam
# 111                   32                   12          RMSprop
# 104                   32                   16          RMSprop
# 125                   28                   24             Adam
# 170                   24                   24          RMSprop
# 120                   32                   24          RMSprop
# 28                    28                    8          RMSprop
# 53                    32                   12          RMSprop
# 55                    32                    4          RMSprop
# 167                   28                   24          RMSprop
# 3                     24                    8             Adam
# 16                    16                   24             Adam
# 15                    28                   24             Adam
# 35                    20                   24          RMSprop
# 30                    20                   24          RMSprop

# %%
# Find the most important hyperparameters
most_important_parameters = optuna.importance.get_param_importances(study, target=None)

# %%
# Display the most important hyperparameters
print("\nMost important hyperparameters:")
for key, value in most_important_parameters.items():
    print("  {}:{}{:.2f}%".format(key, (15 - len(key)) * " ", value * 100))
# Out:
# Most important hyperparameters:
#   num_filter_2:   37.96%
#   optimizer:      36.30%
#   num_filter_1:   10.33%
#   drop_out_rate_1:4.33%
#   lr:             4.14%
#   drop_out_rate_3:3.45%
#   drop_out_rate_2:1.98%
#   num_fc:         0.92%
#   num_filter_3:   0.59%

# %% [markdown]
# ## 2.6. Model Training

# %%
trial.params
# Out:
# {'num_filter_1': 12,
#  'num_filter_2': 20,
#  'num_filter_3': 24,
#  'num_fc': 6,
#  'drop_out_rate_1': 0.35,
#  'drop_out_rate_2': 0.15000000000000002,
#  'drop_out_rate_3': 0.30000000000000004,
#  'optimizer': 'RMSprop',
#  'lr': 0.003172317460779573}

# %%
model = ConvolutionalNeuralNetwork(
    trial,
    num_filter_1=trial.params["num_filter_1"],
    num_filter_2=trial.params["num_filter_2"],
    num_filter_3=trial.params["num_filter_3"],
    num_fc=trial.params["num_fc"],
    drop_out_rate_1=trial.params["drop_out_rate_1"],
    drop_out_rate_2=trial.params["drop_out_rate_2"],
    drop_out_rate_3=trial.params["drop_out_rate_3"],
)

# %%
def trainer(
    model,
    criterion,
    optimizer,
    trainloader,
    validloader,
    epochs=5,
    patience=5,
    verbose=True,
):
    """Simple training wrapper for PyTorch network."""

    train_loss, valid_loss, train_accuracy, valid_accuracy = [], [], [], []
    for epoch in range(epochs):  # for each epoch
        train_batch_loss = 0
        valid_batch_loss = 0
        train_batch_acc = 0
        valid_batch_acc = 0

        # Training
        for X, y in trainloader:
            optimizer.zero_grad()  # Zero all the gradients w.r.t. parameters
            # X = X.to(device)
            # y = y.to(device)
            y_hat = model(X)  # forward pass to get output
            y_hat_labels = torch.sigmoid(y_hat) > 0.5
            loss = criterion(y_hat, y.unsqueeze(1))  # Calculate loss based on output
            loss.backward()  # Calculate gradients w.r.t. parameters
            optimizer.step()  # Update parameters
            train_batch_loss += loss.item()  # Add loss for this batch to running total
            train_batch_acc += (
                (y_hat_labels.squeeze() == y).type(torch.float32).mean().item()
            )
        train_loss.append(train_batch_loss / len(trainloader))
        train_accuracy.append(train_batch_acc / len(trainloader))  # accuracy

        # Validation
        model.eval()
        with torch.no_grad():  # this stops pytorch doing computational graph stuff under-the-hood and saves memory and time
            for X, y in validloader:
                # X = X.to(device)
                # y = y.to(device)
                y_hat = model(X)  # forward pass to get output
                y_hat_labels = torch.sigmoid(y_hat) > 0.5
                loss = criterion(y_hat, y.unsqueeze(1))
                valid_batch_loss += loss.item()
                valid_batch_acc += (
                    (y_hat_labels.squeeze() == y).type(torch.float32).mean().item()
                )
        valid_loss.append(valid_batch_loss / len(validloader))
        valid_accuracy.append(valid_batch_acc / len(validloader))  # accuracy

        model.train()

        # Print progress
        if verbose:
            if (epoch + 1) % 100 == 0:
                print(
                    f"Epoch {epoch + 1}:",
                    f"Train Loss: {train_loss[-1]:.3f}.",
                    f"Valid Loss: {valid_loss[-1]:.3f}.",
                    f"Train Accuracy: {train_accuracy[-1]:.2f}."
                    f"Valid Accuracy: {valid_accuracy[-1]:.2f}.",
                )

        # Early stopping
        if epoch > 0 and valid_loss[-1] > valid_loss[-2]:
            consec_increases += 1
        else:
            consec_increases = 0
        if consec_increases == patience:
            print(
                f"Stopped early at epoch {epoch + 1} - val loss increased for {consec_increases} consecutive epochs!"
            )
            break

    print("\nTraining ended.")

    loss_fig = pd.DataFrame(
        {"train_loss": train_loss, "valid_loss": valid_loss}
    ).plot.line()
    loss_fig.set_xlabel("Epoch")
    loss_fig.set_ylabel("Loss")

    accur_fig = pd.DataFrame(
        {"train_accuracy": train_accuracy, "valid_accuracy": valid_accuracy}
    ).plot.line()
    accur_fig.set_xlabel("Epoch")
    accur_fig.set_ylabel("Accuracy");

# %%
model.apply(weights_init)
# Out:
# ConvolutionalNeuralNetwork(
#   (main): Sequential(
#     (0): Conv1d(8, 12, kernel_size=(3,), stride=(1,), padding=(1,))
#     (1): ReLU()
#     (2): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (3): Dropout(p=0.35, inplace=False)
#     (4): Conv1d(12, 20, kernel_size=(3,), stride=(1,), padding=(1,))
#     (5): ReLU()
#     (6): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (7): Dropout(p=0.15000000000000002, inplace=False)
#     (8): Conv1d(20, 24, kernel_size=(3,), stride=(1,), padding=(1,))
#     (9): ReLU()
#     (10): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (11): Dropout(p=0.30000000000000004, inplace=False)
#     (12): Flatten(start_dim=1, end_dim=-1)
#     (13): Linear(in_features=72, out_features=6, bias=True)
#     (14): ReLU()
#     (15): Linear(in_features=6, out_features=1, bias=True)
#   )
# )

# %%
criterion = nn.BCEWithLogitsLoss()
optimizer = getattr(optim, trial.params["optimizer"])(
    model.parameters(), lr=trial.params["lr"]
)

# %%
trainer(
    model,
    criterion,
    optimizer,
    trainloader,
    validloader,
    epochs=2001,
    patience=5,
    verbose=True,
)
# Out:
# Epoch 100: Train Loss: 0.377. Valid Loss: 0.420. Train Accuracy: 0.83.Valid Accuracy: 0.81.
# Epoch 200: Train Loss: 0.358. Valid Loss: 0.422. Train Accuracy: 0.83.Valid Accuracy: 0.80.
# Epoch 300: Train Loss: 0.354. Valid Loss: 0.440. Train Accuracy: 0.83.Valid Accuracy: 0.80.
# Epoch 400: Train Loss: 0.334. Valid Loss: 0.430. Train Accuracy: 0.85.Valid Accuracy: 0.81.
# Epoch 500: Train Loss: 0.336. Valid Loss: 0.432. Train Accuracy: 0.85.Valid Accuracy: 0.81.
# Epoch 600: Train Loss: 0.330. Valid Loss: 0.476. Train Accuracy: 0.85.Valid Accuracy: 0.78.
# Epoch 700: Train Loss: 0.337. Valid Loss: 0.439. Train Accuracy: 0.85.Valid Accuracy: 0.80.
# Epoch 800: Train Loss: 0.337. Valid Loss: 0.428. Train Accuracy: 0.84.Valid Accuracy: 0.80.
# Epoch 900: Train Loss: 0.334. Valid Loss: 0.439. Train Accuracy: 0.85.Valid Accuracy: 0.80.
# Stopped early at epoch 948 - val loss increased for 5 consecutive epochs!
#
# Training ended.

# %% [markdown]
# ## 2.7. Accuracy on Test Set

# %%
test_accuracy = []
test_batch_acc = 0

model.eval()
with torch.no_grad():
    for X, y in testloader:
        y_hat = model(X)  # forward pass to get output
        y_hat_labels = torch.sigmoid(y_hat) > 0.5
        test_batch_acc += (
            (y_hat_labels.squeeze() == y).type(torch.float32).mean().item()
        )

test_accuracy.append(test_batch_acc / len(testloader))  # accuracy

# %%
test_accuracy
# Out:
# [0.8265601176105134]

# %% [markdown]
# ## 2.8. Prediction

# %%
model.eval()
with torch.no_grad():
    wea, lab = next(iter(testloader))
    y_prob = torch.sigmoid(model(wea)[0])
    y_class = int(y_prob > 0.5)
    print(f"Prbability of Bad Air Quality: {y_prob.item():.3g}")
    fig, axs = plt.subplots(nrows=2, ncols=4)
    r = 0
    c = 0
    for j in range(8):
        axs[r, c].plot(weather[0, j, :])
        axs[r, c].set_title(f"{feature_names[j]}")
        if c < 3:
            c += 1
        else:
            r += 1
            c = 0
    fig.suptitle(f"Air Quality Bad? {bool(lab[0])}")
    plt.tight_layout()
    plt.show();
# Out:
# Prbability of Bad Air Quality: 0.345
