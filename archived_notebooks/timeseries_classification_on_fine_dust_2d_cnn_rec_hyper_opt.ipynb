# %% [markdown]
# # 0. Imports

# %%
import os
import warnings

import numpy as np
import pandas as pd
from pandas.errors import SettingWithCopyWarning

warnings.simplefilter(action="ignore", category=SettingWithCopyWarning)
warnings.simplefilter(action="ignore", category=FutureWarning)

import datetime

import matplotlib.pyplot as plt

import torch
from sklearn.preprocessing import StandardScaler
from torch import nn
from torch.utils.data import DataLoader, TensorDataset
from torchsummary import summary
from torchvision import datasets, transforms
from torchvision.transforms import ToTensor
import torch.optim as optim
from tqdm import tqdm

from pyts.image import RecurrencePlot

import optuna
from optuna.trial import TrialState
torch.manual_seed(41)

# %%
def weights_init(m):
    if isinstance(m, nn.Conv1d):
        torch.nn.init.xavier_uniform_(m.weight.data)

# %% [markdown]
# # 1. Data

# %% [markdown]
# Processed dataset from [Part 1](https://github.com/johnwslee/fine_dust_analysis) will be used as raw data for study.

# %%
df = pd.read_csv(
    "../data/seoul_fine_dust_weather_2008_2021_for_ml.csv",
    index_col=0,
    parse_dates=True,
).reset_index()

# %%
df.head()
# Out:
#                  date  temp(°C)  precipitation(mm)  wind_speed(m/s)  \
# 0 2008-01-01 10:00:00      -7.6                0.0              4.6
# 1 2008-01-01 11:00:00      -6.9                0.0              4.1
# 2 2008-01-01 12:00:00      -5.8                0.0              4.1
# 3 2008-01-01 13:00:00      -5.0                0.0              4.1
# 4 2008-01-01 14:00:00      -4.4                0.0              4.1
#
#    wind_direction  humidity(%)  local_P(hPa)  cloud_cover  \
# 0           340.0         47.0        1010.7          2.0
# 1           290.0         42.0        1010.7          2.0
# 2           290.0         42.0        1010.7          2.0
# 3           290.0         36.0        1009.9          0.0
# 4           290.0         36.0        1009.9          0.0
#
#    lowest_ceiling(100m)  month  PM10_Counts  PM25_Counts  log_PM10_Counts  \
# 0                  12.0      1         30.0         11.0         3.433987
# 1                  12.0      1         29.0         13.0         3.401197
# 2                  12.0      1         29.0         12.0         3.401197
# 3                  10.0      1         28.0         12.0         3.367296
# 4                  10.0      1         27.0         13.0         3.332205
#
#    log_PM25_Counts
# 0         2.484907
# 1         2.639057
# 2         2.564949
# 3         2.564949
# 4         2.639057

# %% [markdown]
# The dataset above will be transformed so that it can be used for multi-scale timeseries classification. In order to do so, `wind_direction`, `humidity(%)`, `lowest_ceiling(100m)`, `temp(°C)`, `wind_speed(m/s)`, `local_P(hPa)`, `precipitation(mm)`, and `PM10_Counts` will be used as features, whereas the binary target, `Air_is_bad?` will be generated based on `PM10_Counts` of the next day.

# %%
new_columns = [
    "date",
    "wind_direction",
    "humidity(%)",
    "lowest_ceiling(100m)",
    "temp(°C)",
    "wind_speed(m/s)",
    "local_P(hPa)",
    "precipitation(mm)",
    "PM10_Counts",
]

# %%
df = df[new_columns]

# %%
df
# Out:
#                       date  wind_direction  humidity(%)  lowest_ceiling(100m)  \
# 0      2008-01-01 10:00:00           340.0         47.0                  12.0
# 1      2008-01-01 11:00:00           290.0         42.0                  12.0
# 2      2008-01-01 12:00:00           290.0         42.0                  12.0
# 3      2008-01-01 13:00:00           290.0         36.0                  10.0
# 4      2008-01-01 14:00:00           290.0         36.0                  10.0
# ...                    ...             ...          ...                   ...
# 122728 2021-12-31 05:00:00           270.0         39.0                  10.0
# 122729 2021-12-31 06:00:00           290.0         40.0                  10.0
# 122730 2021-12-31 07:00:00           270.0         42.0                  10.0
# 122731 2021-12-31 08:00:00           270.0         42.0                  10.0
# 122732 2021-12-31 09:00:00           270.0         40.0                  10.0
#
#         temp(°C)  wind_speed(m/s)  local_P(hPa)  precipitation(mm)  \
# 0           -7.6              4.6        1010.7                0.0
# 1           -6.9              4.1        1010.7                0.0
# 2           -5.8              4.1        1010.7                0.0
# 3           -5.0              4.1        1009.9                0.0
# 4           -4.4              4.1        1009.9                0.0
# ...          ...              ...           ...                ...
# 122728      -7.7              3.5        1018.5                0.0
# 122729      -8.0              3.2        1019.2                0.0
# 122730      -8.6              2.7        1019.9                0.0
# 122731      -8.8              2.9        1020.8                0.0
# 122732      -8.4              3.7        1021.2                0.0
#
#         PM10_Counts
# 0              30.0
# 1              29.0
# 2              29.0
# 3              28.0
# 4              27.0
# ...             ...
# 122728         25.0
# 122729         23.0
# 122730         22.0
# 122731         22.0
# 122732         22.0
#
# [122733 rows x 9 columns]

# %% [markdown]
# Since the time starts from 10 for 2008-01-01, the dataset should start from 2008-01-02 so that all features have equal length of data per day. The same goes for 2021-12-31. So Feature will range from 2008-01-02 to 2021-12-29, while it will be from 2008-01-03 to 2021-12-30 for target.

# %% [markdown]
# ## 1.1. Target Preparation

# %%
df.loc[df["PM10_Counts"] > 45].shape[0]
# Out:
# 46562

# %%
df.shape[0]
# Out:
# 122733

# %%
pm10_count = df[["date", "PM10_Counts"]]

# %%
pm10_count
# Out:
#                       date  PM10_Counts
# 0      2008-01-01 10:00:00         30.0
# 1      2008-01-01 11:00:00         29.0
# 2      2008-01-01 12:00:00         29.0
# 3      2008-01-01 13:00:00         28.0
# 4      2008-01-01 14:00:00         27.0
# ...                    ...          ...
# 122728 2021-12-31 05:00:00         25.0
# 122729 2021-12-31 06:00:00         23.0
# 122730 2021-12-31 07:00:00         22.0
# 122731 2021-12-31 08:00:00         22.0
# 122732 2021-12-31 09:00:00         22.0
#
# [122733 rows x 2 columns]

# %%
pm10_count["date_new"] = pm10_count["date"].dt.date

# %%
target = pm10_count.groupby("date_new").mean().reset_index()

# %%
target["date_new"] = pd.to_datetime(target["date_new"])

# %%
target["Air_is_bad?"] = np.where(target["PM10_Counts"] >= 45, 1, 0)

# %%
target = target[["date_new", "Air_is_bad?"]]

# %%
target = target.loc[
    (target["date_new"].dt.date >= datetime.date(2008, 1, 3)) &
    (target["date_new"].dt.date <= datetime.date(2021, 12, 30))
].reset_index(drop=True)

# %%
target
# Out:
#        date_new  Air_is_bad?
# 0    2008-01-03            1
# 1    2008-01-04            1
# 2    2008-01-05            1
# 3    2008-01-06            1
# 4    2008-01-07            1
# ...         ...          ...
# 5106 2021-12-26            0
# 5107 2021-12-27            0
# 5108 2021-12-28            1
# 5109 2021-12-29            1
# 5110 2021-12-30            0
#
# [5111 rows x 2 columns]

# %% [markdown]
# ## 1.2. Train/Test Split

# %%
train_df = df.loc[df["date"].dt.date < datetime.date(2016, 1, 1)]
test_df = df.loc[df["date"].dt.date >= datetime.date(2016, 1, 1)]

# %% [markdown]
# ## 1.3. Feature Preparation

# %%
feature_names = list(df.columns[1:])

# %%
scaler = StandardScaler()

# %%
train_df[feature_names] = scaler.fit_transform(train_df[feature_names])

# %%
test_df[feature_names] = scaler.transform(test_df[feature_names])

# %%
# Concatenate train/test df just for convenience of dataset preparation

features = pd.concat([train_df, test_df], axis=0)

# %%
features["date_new"] = features["date"].dt.date

# %%
features
# Out:
#                       date  wind_direction  humidity(%)  lowest_ceiling(100m)  \
# 0      2008-01-01 10:00:00        1.379492    -0.665907             -0.223685
# 1      2008-01-01 11:00:00        0.924452    -0.916402             -0.223685
# 2      2008-01-01 12:00:00        0.924452    -0.916402             -0.223685
# 3      2008-01-01 13:00:00        0.924452    -1.216997             -0.438062
# 4      2008-01-01 14:00:00        0.924452    -1.216997             -0.438062
# ...                    ...             ...          ...                   ...
# 122728 2021-12-31 05:00:00        0.742436    -1.066699             -0.438062
# 122729 2021-12-31 06:00:00        0.924452    -1.016600             -0.438062
# 122730 2021-12-31 07:00:00        0.742436    -0.916402             -0.438062
# 122731 2021-12-31 08:00:00        0.742436    -0.916402             -0.438062
# 122732 2021-12-31 09:00:00        0.742436    -1.016600             -0.438062
#
#         temp(°C)  wind_speed(m/s)  local_P(hPa)  precipitation(mm)  \
# 0      -1.837310         1.384209      0.614341          -0.119068
# 1      -1.774089         1.032243      0.614341          -0.119068
# 2      -1.674743         1.032243      0.614341          -0.119068
# 3      -1.602491         1.032243      0.513459          -0.119068
# 4      -1.548302         1.032243      0.513459          -0.119068
# ...          ...              ...           ...                ...
# 122728 -1.846341         0.609884      1.597937          -0.119068
# 122729 -1.873436         0.398704      1.686208          -0.119068
# 122730 -1.927625         0.046738      1.774479          -0.119068
# 122731 -1.945688         0.187525      1.887971          -0.119068
# 122732 -1.909562         0.750670      1.938412          -0.119068
#
#         PM10_Counts    date_new
# 0         -0.484375  2008-01-01
# 1         -0.511732  2008-01-01
# 2         -0.511732  2008-01-01
# 3         -0.539090  2008-01-01
# 4         -0.566447  2008-01-01
# ...             ...         ...
# 122728    -0.621163  2021-12-31
# 122729    -0.675878  2021-12-31
# 122730    -0.703235  2021-12-31
# 122731    -0.703235  2021-12-31
# 122732    -0.703235  2021-12-31
#
# [122733 rows x 10 columns]

# %%
features = (
    features.groupby("date_new")
    .agg(list)[
        [
            "wind_direction",
            "humidity(%)",
            "lowest_ceiling(100m)",
            "temp(°C)",
            "wind_speed(m/s)",
            "local_P(hPa)",
            "precipitation(mm)",
            "PM10_Counts",
        ]
    ]
    .reset_index()
)

# %%
features["date_new"] = pd.to_datetime(features["date_new"])

# %%
features.head()
# Out:
#     date_new                                     wind_direction  \
# 0 2008-01-01  [1.3794924231559433, 0.924452475006894, 0.9244...
# 1 2008-01-02  [0.924452475006894, 1.1974764438963235, 1.1974...
# 2 2008-01-03  [-1.7147792242575914, -1.2597392761085422, -1....
# 3 2008-01-04  [0.924452475006894, -1.5327632449979716, 1.379...
# 4 2008-01-05  [0.7424364957472743, -1.5327632449979716, -1.2...
#
#                                          humidity(%)  \
# 0  [-0.665906724059201, -0.9164020855164998, -0.9...
# 1  [-0.16491600114460359, -0.665906724059201, -0....
# 2  [-0.06471785656168408, -0.11481692885314383, -...
# 3  [0.035480288021235415, -0.01461878427022433, -...
# 4  [-0.6158076517677413, 0.035480288021235415, -0...
#
#                                 lowest_ceiling(100m)  \
# 0  [-0.22368526895253332, -0.22368526895253332, -...
# 1  [-0.5452500390488106, -0.5452500390488106, -0....
# 2  [-0.22368526895253332, -0.8668148091450879, -0...
# 3  [-0.8668148091450879, -0.8668148091450879, -0....
# 4  [-0.5452500390488106, -0.5452500390488106, -0....
#
#                                             temp(°C)  \
# 0  [-1.8373098159974528, -1.7740892697507045, -1....
# 1  [-1.7379632433239907, -1.62958516404385, -1.53...
# 2  [-1.3496084592368196, -1.1870413403166087, -1....
# 3  [-1.2231673667433223, -1.2592933931700356, -1....
# 4  [-1.1328523006765383, -1.12382079406986, -0.97...
#
#                                      wind_speed(m/s)  \
# 0  [1.3842093884999658, 1.0322432575055385, 1.032...
# 1  [-0.5164077188699413, 0.11713131692002768, 0.1...
# 2  [-1.8538790166487649, -0.6571941712677122, -0....
# 3  [0.046738090721142475, -0.5164077188699413, -1...
# 4  [-0.9387670760632539, -0.6571941712677122, -1....
#
#                                         local_P(hPa)  \
# 0  [0.6143406738734757, 0.6143406738734757, 0.614...
# 1  [0.9043753409882764, 1.1817998051850536, 1.181...
# 2  [1.1187487905948783, 0.7782733118079257, 0.778...
# 3  [1.1817998051850536, 1.3331222402014657, 1.333...
# 4  [0.9548161526604138, 0.9043753409882764, 0.904...
#
#                                    precipitation(mm)  \
# 0  [-0.11906781300263639, -0.11906781300263639, -...
# 1  [-0.11906781300263639, -0.11906781300263639, -...
# 2  [-0.11906781300263639, -0.11906781300263639, -...
# 3  [-0.11906781300263639, -0.11906781300263639, -...
# 4  [-0.11906781300263639, -0.11906781300263639, -...
#
#                                          PM10_Counts
# 0  [-0.48437493777652446, -0.5117324550480038, -0...
# 1  [-0.32022983414764833, -0.15608473051877228, -...
# 2  [-0.15608473051877228, 0.19956299401045927, 0....
# 3  [0.500495683996732, 1.1570760985122364, 1.4032...
# 4  [0.500495683996732, 0.9929309948833603, 1.4032...

# %%
features = features.loc[
    (features["date_new"].dt.date >= datetime.date(2008, 1, 2))
    & (features["date_new"].dt.date <= datetime.date(2021, 12, 29))
].reset_index(drop=True)

# %%
features
# Out:
#        date_new                                     wind_direction  \
# 0    2008-01-02  [0.924452475006894, 1.1974764438963235, 1.1974...
# 1    2008-01-03  [-1.7147792242575914, -1.2597392761085422, -1....
# 2    2008-01-04  [0.924452475006894, -1.5327632449979716, 1.379...
# 3    2008-01-05  [0.7424364957472743, -1.5327632449979716, -1.2...
# 4    2008-01-06  [-1.5327632449979716, -0.8957073175893028, -0....
# ...         ...                                                ...
# 5106 2021-12-25  [0.924452475006894, 0.924452475006894, 0.74243...
# 5107 2021-12-26  [0.7424364957472743, 0.7424364957472743, 0.924...
# 5108 2021-12-27  [1.1974764438963235, -1.2597392761085422, -0.8...
# 5109 2021-12-28  [-1.5327632449979716, -1.2597392761085422, -1....
# 5110 2021-12-29  [-1.5327632449979716, -1.0777232968489225, -1....
#
#                                             humidity(%)  \
# 0     [-0.16491600114460359, -0.665906724059201, -0....
# 1     [-0.06471785656168408, -0.11481692885314383, -...
# 2     [0.035480288021235415, -0.01461878427022433, -...
# 3     [-0.6158076517677413, 0.035480288021235415, -0...
# 4     [0.8871645169760511, 0.5364710109358329, 0.436...
# ...                                                 ...
# 5106  [-0.4655104348933621, -0.9164020855164998, -1....
# 5107  [-0.7160057963506608, -0.8162039409335803, -0....
# 5108  [-0.36531229031044254, -0.31521321801898283, -...
# 5109  [1.1376598784333498, 1.0374617338504304, 0.636...
# 5110  [0.8871645169760511, 1.0374617338504304, 0.887...
#
#                                    lowest_ceiling(100m)  \
# 0     [-0.5452500390488106, -0.5452500390488106, -0....
# 1     [-0.22368526895253332, -0.8668148091450879, -0...
# 2     [-0.8668148091450879, -0.8668148091450879, -0....
# 3     [-0.5452500390488106, -0.5452500390488106, -0....
# 4     [-0.4380617823500515, -0.974003065843847, -0.9...
# ...                                                 ...
# 5106  [-0.11649701225377423, -0.11649701225377423, -...
# 5107  [-0.11649701225377423, -0.11649701225377423, -...
# 5108  [-0.11649701225377423, -0.11649701225377423, -...
# 5109  [-0.3308735256512924, -0.3308735256512924, -0....
# 5110  [-0.11649701225377423, -0.4380617823500515, -0...
#
#                                                temp(°C)  \
# 0     [-1.7379632433239907, -1.62958516404385, -1.53...
# 1     [-1.3496084592368196, -1.1870413403166087, -1....
# 2     [-1.2231673667433223, -1.2592933931700356, -1....
# 3     [-1.1328523006765383, -1.12382079406986, -0.97...
# 4     [-1.0515687412164327, -0.8619071024761865, -0....
# ...                                                 ...
# 5106  [-1.8102152961774178, -2.252759119904659, -2.1...
# 5107  [-2.451452265251584, -2.388231719004835, -2.29...
# 5108  [-2.2437276132979806, -1.9185933754575586, -1....
# 5109  [-1.7199002301106339, -1.6657111904705635, -1....
# 5110  [-1.4399235253036036, -1.1328523006765383, -1....
#
#                                         wind_speed(m/s)  \
# 0     [-0.5164077188699413, 0.11713131692002768, 0.1...
# 1     [-1.8538790166487649, -0.6571941712677122, -0....
# 2     [0.046738090721142475, -0.5164077188699413, -1...
# 3     [-0.9387670760632539, -0.6571941712677122, -1....
# 4     [-1.0091603022621394, -1.0795535284610247, -1....
# ...                                                 ...
# 5106  [1.5953890670966224, 0.609883900312226, 0.6802...
# 5107  [-0.3756212664721703, 0.6802771265111115, 0.18...
# 5108  [-0.23483481407439957, -0.5164077188699413, -0...
# 5109  [-0.30522804027328476, -0.3756212664721703, -0...
# 5110  [-0.7275873974665975, -1.0091603022621394, -0....
#
#                                            local_P(hPa)  \
# 0     [0.9043753409882764, 1.1817998051850536, 1.181...
# 1     [1.1187487905948783, 0.7782733118079257, 0.778...
# 2     [1.1817998051850536, 1.3331222402014657, 1.333...
# 3     [0.9548161526604138, 0.9043753409882764, 0.904...
# 4     [0.9548161526604138, 0.9043753409882764, 0.904...
# ...                                                 ...
# 5106  [1.2700712256112905, 2.039293603611432, 2.0392...
# 5107  [2.3671588794803324, 2.518481314496759, 2.4680...
# 5108  [2.1275650240376835, 1.963632386103219, 1.9258...
# 5109  [1.7114283277425177, 1.7240385306605557, 1.686...
# 5110  [0.9800365584964896, 0.43779783302097325, 0.39...
#
#                                       precipitation(mm)  \
# 0     [-0.11906781300263639, -0.11906781300263639, -...
# 1     [-0.11906781300263639, -0.11906781300263639, -...
# 2     [-0.11906781300263639, -0.11906781300263639, -...
# 3     [-0.11906781300263639, -0.11906781300263639, -...
# 4     [-0.11906781300263639, -0.11906781300263639, -...
# ...                                                 ...
# 5106  [-0.11906781300263639, -0.11906781300263639, -...
# 5107  [-0.11906781300263639, -0.11906781300263639, -...
# 5108  [-0.11906781300263639, -0.11906781300263639, -...
# 5109  [-0.11906781300263639, -0.11906781300263639, -...
# 5110  [-0.11906781300263639, -0.11906781300263639, -...
#
#                                             PM10_Counts
# 0     [-0.32022983414764833, -0.15608473051877228, -...
# 1     [-0.15608473051877228, 0.19956299401045927, 0....
# 2     [0.500495683996732, 1.1570760985122364, 1.4032...
# 3     [0.500495683996732, 0.9929309948833603, 1.4032...
# 4     [0.36370809763933537, 1.512723823041468, 1.649...
# ...                                                 ...
# 5106  [-0.21079976506173095, -0.7853076277627973, -0...
# 5107  [-0.8126651450342767, -0.9494527313916734, -0....
# 5108  [-0.8673801795772353, -0.48437493777652446, -0...
# 5109  [-0.18344224779025162, 0.06277540765306251, 0....
# 5110  [0.14484795946750056, 0.36370809763933537, 0.5...
#
# [5111 rows x 9 columns]

# %% [markdown]
# ## 1.5. Dataset Preparation

# %%
data = pd.concat([features, target["Air_is_bad?"]], axis=1)

# %%
data
# Out:
#        date_new                                     wind_direction  \
# 0    2008-01-02  [0.924452475006894, 1.1974764438963235, 1.1974...
# 1    2008-01-03  [-1.7147792242575914, -1.2597392761085422, -1....
# 2    2008-01-04  [0.924452475006894, -1.5327632449979716, 1.379...
# 3    2008-01-05  [0.7424364957472743, -1.5327632449979716, -1.2...
# 4    2008-01-06  [-1.5327632449979716, -0.8957073175893028, -0....
# ...         ...                                                ...
# 5106 2021-12-25  [0.924452475006894, 0.924452475006894, 0.74243...
# 5107 2021-12-26  [0.7424364957472743, 0.7424364957472743, 0.924...
# 5108 2021-12-27  [1.1974764438963235, -1.2597392761085422, -0.8...
# 5109 2021-12-28  [-1.5327632449979716, -1.2597392761085422, -1....
# 5110 2021-12-29  [-1.5327632449979716, -1.0777232968489225, -1....
#
#                                             humidity(%)  \
# 0     [-0.16491600114460359, -0.665906724059201, -0....
# 1     [-0.06471785656168408, -0.11481692885314383, -...
# 2     [0.035480288021235415, -0.01461878427022433, -...
# 3     [-0.6158076517677413, 0.035480288021235415, -0...
# 4     [0.8871645169760511, 0.5364710109358329, 0.436...
# ...                                                 ...
# 5106  [-0.4655104348933621, -0.9164020855164998, -1....
# 5107  [-0.7160057963506608, -0.8162039409335803, -0....
# 5108  [-0.36531229031044254, -0.31521321801898283, -...
# 5109  [1.1376598784333498, 1.0374617338504304, 0.636...
# 5110  [0.8871645169760511, 1.0374617338504304, 0.887...
#
#                                    lowest_ceiling(100m)  \
# 0     [-0.5452500390488106, -0.5452500390488106, -0....
# 1     [-0.22368526895253332, -0.8668148091450879, -0...
# 2     [-0.8668148091450879, -0.8668148091450879, -0....
# 3     [-0.5452500390488106, -0.5452500390488106, -0....
# 4     [-0.4380617823500515, -0.974003065843847, -0.9...
# ...                                                 ...
# 5106  [-0.11649701225377423, -0.11649701225377423, -...
# 5107  [-0.11649701225377423, -0.11649701225377423, -...
# 5108  [-0.11649701225377423, -0.11649701225377423, -...
# 5109  [-0.3308735256512924, -0.3308735256512924, -0....
# 5110  [-0.11649701225377423, -0.4380617823500515, -0...
#
#                                                temp(°C)  \
# 0     [-1.7379632433239907, -1.62958516404385, -1.53...
# 1     [-1.3496084592368196, -1.1870413403166087, -1....
# 2     [-1.2231673667433223, -1.2592933931700356, -1....
# 3     [-1.1328523006765383, -1.12382079406986, -0.97...
# 4     [-1.0515687412164327, -0.8619071024761865, -0....
# ...                                                 ...
# 5106  [-1.8102152961774178, -2.252759119904659, -2.1...
# 5107  [-2.451452265251584, -2.388231719004835, -2.29...
# 5108  [-2.2437276132979806, -1.9185933754575586, -1....
# 5109  [-1.7199002301106339, -1.6657111904705635, -1....
# 5110  [-1.4399235253036036, -1.1328523006765383, -1....
#
#                                         wind_speed(m/s)  \
# 0     [-0.5164077188699413, 0.11713131692002768, 0.1...
# 1     [-1.8538790166487649, -0.6571941712677122, -0....
# 2     [0.046738090721142475, -0.5164077188699413, -1...
# 3     [-0.9387670760632539, -0.6571941712677122, -1....
# 4     [-1.0091603022621394, -1.0795535284610247, -1....
# ...                                                 ...
# 5106  [1.5953890670966224, 0.609883900312226, 0.6802...
# 5107  [-0.3756212664721703, 0.6802771265111115, 0.18...
# 5108  [-0.23483481407439957, -0.5164077188699413, -0...
# 5109  [-0.30522804027328476, -0.3756212664721703, -0...
# 5110  [-0.7275873974665975, -1.0091603022621394, -0....
#
#                                            local_P(hPa)  \
# 0     [0.9043753409882764, 1.1817998051850536, 1.181...
# 1     [1.1187487905948783, 0.7782733118079257, 0.778...
# 2     [1.1817998051850536, 1.3331222402014657, 1.333...
# 3     [0.9548161526604138, 0.9043753409882764, 0.904...
# 4     [0.9548161526604138, 0.9043753409882764, 0.904...
# ...                                                 ...
# 5106  [1.2700712256112905, 2.039293603611432, 2.0392...
# 5107  [2.3671588794803324, 2.518481314496759, 2.4680...
# 5108  [2.1275650240376835, 1.963632386103219, 1.9258...
# 5109  [1.7114283277425177, 1.7240385306605557, 1.686...
# 5110  [0.9800365584964896, 0.43779783302097325, 0.39...
#
#                                       precipitation(mm)  \
# 0     [-0.11906781300263639, -0.11906781300263639, -...
# 1     [-0.11906781300263639, -0.11906781300263639, -...
# 2     [-0.11906781300263639, -0.11906781300263639, -...
# 3     [-0.11906781300263639, -0.11906781300263639, -...
# 4     [-0.11906781300263639, -0.11906781300263639, -...
# ...                                                 ...
# 5106  [-0.11906781300263639, -0.11906781300263639, -...
# 5107  [-0.11906781300263639, -0.11906781300263639, -...
# 5108  [-0.11906781300263639, -0.11906781300263639, -...
# 5109  [-0.11906781300263639, -0.11906781300263639, -...
# 5110  [-0.11906781300263639, -0.11906781300263639, -...
#
#                                             PM10_Counts  Air_is_bad?
# 0     [-0.32022983414764833, -0.15608473051877228, -...            1
# 1     [-0.15608473051877228, 0.19956299401045927, 0....            1
# 2     [0.500495683996732, 1.1570760985122364, 1.4032...            1
# 3     [0.500495683996732, 0.9929309948833603, 1.4032...            1
# 4     [0.36370809763933537, 1.512723823041468, 1.649...            1
# ...                                                 ...          ...
# 5106  [-0.21079976506173095, -0.7853076277627973, -0...            0
# 5107  [-0.8126651450342767, -0.9494527313916734, -0....            0
# 5108  [-0.8673801795772353, -0.48437493777652446, -0...            1
# 5109  [-0.18344224779025162, 0.06277540765306251, 0....            1
# 5110  [0.14484795946750056, 0.36370809763933537, 0.5...            0
#
# [5111 rows x 10 columns]

# %% [markdown]
# ### 1.5.1. Preparation of X

# %%
# To filter out data with inconsistent length

for i in tqdm(range(len(data))):
    for j in range(1, 7):
        if len(data.iloc[i, j]) != 24:
            print(i, j, len(data.iloc[i, j]))
        else:
            continue
# Out:
#  79%|████████████████████████████████████████████████████████████▍               | 4062/5111 [00:00<00:00, 5907.50it/s]
# 2791 1 23
# 2791 2 23
# 2791 3 23
# 2791 4 23
# 2791 5 23
# 2791 6 23
# 2801 1 23
# 2801 2 23
# 2801 3 23
# 2801 4 23
# 2801 5 23
# 2801 6 23
# 100%|████████████████████████████████████████████████████████████████████████████| 5111/5111 [00:00<00:00, 5788.00it/s]

# %%
data = data.drop([2791, 2801], axis=0)

# %%
feature_array = []
for i in tqdm(range(len(data))):
    row_array = []
    for j in range(1, 9):
        row_array.append(np.array(data.iloc[i, j]))
    stacked_row_array = np.stack(row_array, axis=0)
    feature_array.append(stacked_row_array)
    
X = np.stack(feature_array, axis=0)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████| 5109/5109 [00:01<00:00, 3756.52it/s]

# %%
X.shape
# Out:
# (5109, 8, 24)

# %% [markdown]
# ### 1.5.2. Transformation of X to 2D using RecurrencePlot()

# %%
transformer = RecurrencePlot()

# %%
X_array = []

for num in range(X.shape[0]):
    X_array.append(transformer.transform(X[num]))
    
X_new = np.stack(X_array, axis=0)

# %%
X_new.shape
# Out:
# (5109, 8, 24, 24)

# %% [markdown]
# ### 1.5.3. Preparation of y

# %%
y = np.array(data["Air_is_bad?"])

# %%
y.shape
# Out:
# (5109,)

# %% [markdown]
# ### 1.5.4. Train/Valid/Test Split for Deep Learning

# %%
# To find the index to split the data into train and test set
len(data.loc[data["date_new"].dt.date < datetime.date(2016, 1, 1)])
# Out:
# 2919

# %%
# To find the index to split the test data into valid and test set
len(data.loc[data["date_new"].dt.date < datetime.date(2018, 1, 1)])
# Out:
# 3650

# %%
X_train = X_new[:2919, :, :, :]
X_valid = X_new[2919:3650, :, :, :]
X_test = X_new[3650:, :, :, :]

y_train = y[:2919]
y_valid = y[2919:3650]
y_test = y[3650:]

# %% [markdown]
# # 2. Multi-Scale Timeseries Classification Using 2-D CNN

# %% [markdown]
# ## 2.1. DataLoader Preparation

# %%
X_train_tensor = torch.Tensor(X_train)
X_valid_tensor = torch.Tensor(X_valid)
X_test_tensor = torch.Tensor(X_test)

y_train_tensor = torch.Tensor(y_train)
y_valid_tensor = torch.Tensor(y_valid)
y_test_tensor = torch.Tensor(y_test)

# %%
train_dataset = TensorDataset(X_train_tensor, y_train_tensor)
trainloader = DataLoader(train_dataset, batch_size=28, shuffle=True)

valid_dataset = TensorDataset(X_valid_tensor, y_valid_tensor)
validloader = DataLoader(valid_dataset, batch_size=10, shuffle=True)

test_dataset = TensorDataset(X_test_tensor, y_test_tensor)
testloader = DataLoader(test_dataset, batch_size=10, shuffle=True)

# %% [markdown]
# ## 2.2. Sample Check

# %%
weather, label = next(iter(trainloader))
i = np.random.randint(0, 28)
fig, axs = plt.subplots(nrows=2, ncols=4)
r = 0
c = 0
for j in range(8):
    axs[r, c].imshow(weather[i, j, :, :])
    axs[r, c].set_title(f"{feature_names[j]}")
    if c < 3:
        c += 1
    else:
        r += 1
        c = 0
fig.suptitle(f"Air Quality Bad? {bool(label[i])}")
plt.tight_layout()
plt.show();

# %% [markdown]
# ## 2.3. Preparation of CNN

# %%
class ConvolutionalNeuralNetwork(nn.Module):
    def __init__(
        self,
        trial,
        num_filter_1,
        num_filter_2,
        num_filter_3,
        num_fc,
        drop_out_rate_1,
        drop_out_rate_2,
        drop_out_rate_3,
    ):
        """
        Parameters:
            - trial (optuna.trial._trial.Trial): Optuna trial
            - num_filters (int):                 Number of filters of conv layers
            - num_fc (int):                      Number of neurons of FC layers
            - drop_out_rate (float):             Dropout ratio
        """
        super(ConvolutionalNeuralNetwork, self).__init__()
        self.main = nn.Sequential(
            nn.Conv2d(8, num_filter_1, kernel_size=(3, 3), padding=1),  # num_filter_1, 24
            nn.ReLU(),
            nn.MaxPool2d((2, 2)),  # num_filter_1, 12
            nn.Dropout(drop_out_rate_1),
            nn.Conv2d(
                num_filter_1, num_filter_2, kernel_size=(3, 3), padding=1
            ),  # num_filter_2, 12
            nn.ReLU(),
            nn.MaxPool2d((2, 2)),  # num_filter_2,  6
            nn.Dropout(drop_out_rate_2),
            nn.Conv2d(
                num_filter_2, num_filter_3, kernel_size=(3, 3), padding=1
            ),  # num_filter_3, 6
            nn.ReLU(),
            nn.MaxPool2d((2, 2)),  # num_filter_3, 3
            nn.Dropout(drop_out_rate_3),
            nn.Flatten(),  # num_filter_3 x 3
            nn.Linear(num_filter_3 * 3 * 3, num_fc),  # num_fc
            nn.ReLU(),
            nn.Linear(num_fc, 1),
        )

    def forward(self, x):
        logits = self.main(x)
        return logits

# %% [markdown]
# ## 2.4. Preparation of Optuna Objective Function

# %%
def train(network, optimizer, trainloader, criterion):
    """Trains the model.

    Parameters:
        - network (__main__.Net):              The CNN
        - optimizer (torch.optim.<optimizer>): The optimizer for the CNN
    """
    network.train()  # Set the module in training mode (only affects certain modules)
    for batch_i, (X, y) in enumerate(trainloader):  # For each batch

        optimizer.zero_grad()  # Clear gradients
        y_hat = network(X)  # Forward propagation
        loss = criterion(
            y_hat, y.unsqueeze(1)
        )  # Compute loss (negative log likelihood: −log(y))
        loss.backward()  # Compute gradients
        optimizer.step()  # Update weights

# %%
def test(network, validloader, criterion):
    """Tests the model.

    Parameters:
        - network (__main__.Net): The CNN

    Returns:
        - accuracy_test (torch.Tensor): The test accuracy
    """
    network.eval()  # Set the module in evaluation mode (only affects certain modules)

    valid_batch_acc = 0

    with torch.no_grad():  # Disable gradient calculation (when you are sure that you will not call Tensor.backward())
        for batch_i, (X, y) in enumerate(validloader):  # For each batch

            y_hat = network(X)  # Forward propagation
            y_hat_labels = torch.sigmoid(y_hat) > 0.5
            valid_batch_acc += (
                (y_hat_labels.squeeze() == y).type(torch.float32).mean().item()
            )

    valid_accuracy = valid_batch_acc / len(validloader)  # accuracy

    return valid_accuracy

# %%
def objective(trial):
    """Objective function to be optimized by Optuna.

    Hyperparameters chosen to be optimized: optimizer, learning rate,
    number of filters, number of neurons in fully connected layer, and dropout values,

    Inputs:
        - trial (optuna.trial._trial.Trial): Optuna trial
    Returns:
        - accuracy(torch.Tensor): The test accuracy. Parameter to be maximized.
    """

    # Define range of values to be tested for the hyperparameters
    num_filter_1 = trial.suggest_int("num_filter_1", 4, 32, 4)
    num_filter_2 = trial.suggest_int("num_filter_2", 4, 32, 4)
    num_filter_3 = trial.suggest_int("num_filter_3", 4, 32, 4)
    num_fc = trial.suggest_int("num_fc", 2, 12, 2)
    drop_out_rate_1 = trial.suggest_float("drop_out_rate_1", 0.1, 0.35, step=0.05)
    drop_out_rate_2 = trial.suggest_float("drop_out_rate_2", 0.1, 0.35, step=0.05)
    drop_out_rate_3 = trial.suggest_float("drop_out_rate_3", 0.1, 0.35, step=0.05)

    # Generate the model
    model = ConvolutionalNeuralNetwork(
        trial,
        num_filter_1,
        num_filter_2,
        num_filter_3,
        num_fc,
        drop_out_rate_1,
        drop_out_rate_2,
        drop_out_rate_3,
    )  # .to(device)

    # Generate the optimizers
    optimizer_name = trial.suggest_categorical(
        "optimizer", ["Adam", "RMSprop", "SGD"]
    )  # Optimizers
    lr = trial.suggest_float("lr", 1e-5, 1e-1, log=True)  # Learning rates
    optimizer = getattr(optim, optimizer_name)(model.parameters(), lr=lr)

    for epoch in range(n_epochs):
        train(model, optimizer, trainloader, criterion)  # Train the model
        accuracy = test(model, validloader, criterion)  # Evaluate the model

        # For pruning (stops trial early if not promising)
        trial.report(accuracy, epoch)
        # Handle pruning based on the intermediate value.
        if trial.should_prune():
            raise optuna.exceptions.TrialPruned()

    return accuracy

# %% [markdown]
# ## 2.5. Hyperparameter Optimization

# %%
n_epochs = 100  # Number of training epochs
number_of_trials = 200  # Number of Optuna trials
criterion = nn.BCEWithLogitsLoss()

# %%
study = optuna.create_study(direction="maximize")
# Out:
# [I 2023-07-29 21:42:42,454] A new study created in memory with name: no-name-0c25fa06-4a8d-4b7c-96c6-6e236368d2af

# %%
study.optimize(objective, n_trials=number_of_trials)
# Out:
# [I 2023-07-29 21:44:55,571] Trial 0 finished with value: 0.6891891940219982 and parameters: {'num_filter_1': 20, 'num_filter_2': 20, 'num_filter_3': 12, 'num_fc': 4, 'drop_out_rate_1': 0.30000000000000004, 'drop_out_rate_2': 0.30000000000000004, 'drop_out_rate_3': 0.15000000000000002, 'optimizer': 'RMSprop', 'lr': 0.0003548210355854598}. Best is trial 0 with value: 0.6891891940219982.
# [I 2023-07-29 21:46:59,135] Trial 1 finished with value: 0.5554054119699711 and parameters: {'num_filter_1': 20, 'num_filter_2': 20, 'num_filter_3': 12, 'num_fc': 8, 'drop_out_rate_1': 0.25, 'drop_out_rate_2': 0.35, 'drop_out_rate_3': 0.35, 'optimizer': 'SGD', 'lr': 2.8822493781046802e-05}. Best is trial 0 with value: 0.6891891940219982.
# [I 2023-07-29 21:48:09,931] Trial 2 finished with value: 0.6743243268212756 and parameters: {'num_filter_1': 4, 'num_filter_2': 24, 'num_filter_3': 28, 'num_fc': 8, 'drop_out_rate_1': 0.2, 'drop_out_rate_2': 0.2, 'drop_out_rate_3': 0.25, 'optimizer': 'SGD', 'lr': 0.0019362270841960633}. Best is trial 0 with value: 0.6891891940219982.
# [I 2023-07-29 21:50:54,091] Trial 3 finished with value: 0.6459459501343805 and parameters: {'num_filter_1': 32, 'num_filter_2': 12, 'num_filter_3': 24, 'num_fc': 10, 'drop_out_rate_1': 0.1, 'drop_out_rate_2': 0.25, 'drop_out_rate_3': 0.2, 'optimizer': 'Adam', 'lr': 1.196504619373781e-05}. Best is trial 0 with value: 0.6891891940219982.
# [I 2023-07-29 21:52:15,155] Trial 4 finished with value: 0.5675675724003766 and parameters: {'num_filter_1': 4, 'num_filter_2': 32, 'num_filter_3': 20, 'num_fc': 10, 'drop_out_rate_1': 0.25, 'drop_out_rate_2': 0.35, 'drop_out_rate_3': 0.30000000000000004, 'optimizer': 'Adam', 'lr': 0.020154623068425245}. Best is trial 0 with value: 0.6891891940219982.
# [I 2023-07-29 21:53:46,608] Trial 5 finished with value: 0.6864864870503142 and parameters: {'num_filter_1': 16, 'num_filter_2': 8, 'num_filter_3': 20, 'num_fc': 12, 'drop_out_rate_1': 0.1, 'drop_out_rate_2': 0.35, 'drop_out_rate_3': 0.25, 'optimizer': 'Adam', 'lr': 7.798603629602597e-05}. Best is trial 0 with value: 0.6891891940219982.
# [I 2023-07-29 21:53:47,952] Trial 6 pruned.
# [I 2023-07-29 21:53:48,864] Trial 7 pruned.
# [I 2023-07-29 21:56:27,876] Trial 8 finished with value: 0.6959459487650845 and parameters: {'num_filter_1': 28, 'num_filter_2': 16, 'num_filter_3': 28, 'num_fc': 10, 'drop_out_rate_1': 0.30000000000000004, 'drop_out_rate_2': 0.35, 'drop_out_rate_3': 0.2, 'optimizer': 'Adam', 'lr': 0.0007887984484126261}. Best is trial 8 with value: 0.6959459487650845.
# [I 2023-07-29 21:58:39,611] Trial 9 finished with value: 0.6864864894667188 and parameters: {'num_filter_1': 20, 'num_filter_2': 20, 'num_filter_3': 8, 'num_fc': 6, 'drop_out_rate_1': 0.15000000000000002, 'drop_out_rate_2': 0.15000000000000002, 'drop_out_rate_3': 0.25, 'optimizer': 'Adam', 'lr': 0.0009146006629648557}. Best is trial 8 with value: 0.6959459487650845.
# [I 2023-07-29 21:58:41,095] Trial 10 pruned.
# [I 2023-07-29 22:01:08,126] Trial 11 finished with value: 0.6810810823698301 and parameters: {'num_filter_1': 28, 'num_filter_2': 12, 'num_filter_3': 12, 'num_fc': 4, 'drop_out_rate_1': 0.35, 'drop_out_rate_2': 0.30000000000000004, 'drop_out_rate_3': 0.1, 'optimizer': 'RMSprop', 'lr': 0.00026252790431819913}. Best is trial 8 with value: 0.6959459487650845.
# [I 2023-07-29 22:03:22,258] Trial 12 finished with value: 0.6864864902721869 and parameters: {'num_filter_1': 24, 'num_filter_2': 16, 'num_filter_3': 12, 'num_fc': 4, 'drop_out_rate_1': 0.30000000000000004, 'drop_out_rate_2': 0.30000000000000004, 'drop_out_rate_3': 0.15000000000000002, 'optimizer': 'RMSprop', 'lr': 0.00027594687008029173}. Best is trial 8 with value: 0.6959459487650845.
# [I 2023-07-29 22:06:02,443] Trial 13 finished with value: 0.6783783782172847 and parameters: {'num_filter_1': 28, 'num_filter_2': 24, 'num_filter_3': 32, 'num_fc': 2, 'drop_out_rate_1': 0.30000000000000004, 'drop_out_rate_2': 0.30000000000000004, 'drop_out_rate_3': 0.15000000000000002, 'optimizer': 'RMSprop', 'lr': 0.00044159875080482773}. Best is trial 8 with value: 0.6959459487650845.
# [I 2023-07-29 22:06:03,477] Trial 14 pruned.
# [I 2023-07-29 22:08:25,637] Trial 15 finished with value: 0.6540540573564736 and parameters: {'num_filter_1': 24, 'num_filter_2': 16, 'num_filter_3': 28, 'num_fc': 4, 'drop_out_rate_1': 0.2, 'drop_out_rate_2': 0.35, 'drop_out_rate_3': 0.2, 'optimizer': 'Adam', 'lr': 0.001102652760216165}. Best is trial 8 with value: 0.6959459487650845.
# [I 2023-07-29 22:08:30,049] Trial 16 pruned.
# [I 2023-07-29 22:08:31,045] Trial 17 pruned.
# [I 2023-07-29 22:10:50,006] Trial 18 finished with value: 0.6891891887864551 and parameters: {'num_filter_1': 24, 'num_filter_2': 16, 'num_filter_3': 24, 'num_fc': 10, 'drop_out_rate_1': 0.25, 'drop_out_rate_2': 0.35, 'drop_out_rate_3': 0.2, 'optimizer': 'RMSprop', 'lr': 0.000550523991150479}. Best is trial 8 with value: 0.6959459487650845.
# [I 2023-07-29 22:10:50,949] Trial 19 pruned.
# [I 2023-07-29 22:10:51,842] Trial 20 pruned.
# [I 2023-07-29 22:13:11,541] Trial 21 finished with value: 0.6878378403347891 and parameters: {'num_filter_1': 24, 'num_filter_2': 16, 'num_filter_3': 28, 'num_fc': 10, 'drop_out_rate_1': 0.25, 'drop_out_rate_2': 0.35, 'drop_out_rate_3': 0.2, 'optimizer': 'RMSprop', 'lr': 0.0005227984601980364}. Best is trial 8 with value: 0.6959459487650845.
# [I 2023-07-29 22:15:30,584] Trial 22 finished with value: 0.7013513522373663 and parameters: {'num_filter_1': 24, 'num_filter_2': 16, 'num_filter_3': 24, 'num_fc': 12, 'drop_out_rate_1': 0.25, 'drop_out_rate_2': 0.35, 'drop_out_rate_3': 0.2, 'optimizer': 'RMSprop', 'lr': 0.000582401195378286}. Best is trial 22 with value: 0.7013513522373663.
# [I 2023-07-29 22:18:11,846] Trial 23 finished with value: 0.679729732709962 and parameters: {'num_filter_1': 28, 'num_filter_2': 20, 'num_filter_3': 24, 'num_fc': 12, 'drop_out_rate_1': 0.30000000000000004, 'drop_out_rate_2': 0.35, 'drop_out_rate_3': 0.25, 'optimizer': 'RMSprop', 'lr': 0.00024401794099267957}. Best is trial 22 with value: 0.7013513522373663.
# [I 2023-07-29 22:20:51,252] Trial 24 finished with value: 0.652702706085669 and parameters: {'num_filter_1': 32, 'num_filter_2': 12, 'num_filter_3': 28, 'num_fc': 12, 'drop_out_rate_1': 0.15000000000000002, 'drop_out_rate_2': 0.30000000000000004, 'drop_out_rate_3': 0.15000000000000002, 'optimizer': 'RMSprop', 'lr': 0.001300013743556633}. Best is trial 22 with value: 0.7013513522373663.
# [I 2023-07-29 22:20:52,586] Trial 25 pruned.
# [I 2023-07-29 22:23:11,040] Trial 26 finished with value: 0.6743243264185416 and parameters: {'num_filter_1': 24, 'num_filter_2': 16, 'num_filter_3': 32, 'num_fc': 8, 'drop_out_rate_1': 0.25, 'drop_out_rate_2': 0.30000000000000004, 'drop_out_rate_3': 0.1, 'optimizer': 'RMSprop', 'lr': 0.0022603578621603025}. Best is trial 22 with value: 0.7013513522373663.
# [I 2023-07-29 22:23:11,983] Trial 27 pruned.
# [I 2023-07-29 22:23:13,648] Trial 28 pruned.
# [I 2023-07-29 22:23:15,179] Trial 29 pruned.
# [I 2023-07-29 22:23:16,557] Trial 30 pruned.
# [I 2023-07-29 22:25:34,780] Trial 31 finished with value: 0.6945945962860778 and parameters: {'num_filter_1': 24, 'num_filter_2': 16, 'num_filter_3': 24, 'num_fc': 10, 'drop_out_rate_1': 0.25, 'drop_out_rate_2': 0.35, 'drop_out_rate_3': 0.2, 'optimizer': 'RMSprop', 'lr': 0.0006159341113575989}. Best is trial 22 with value: 0.7013513522373663.
# [I 2023-07-29 22:25:36,154] Trial 32 pruned.
# [I 2023-07-29 22:25:37,794] Trial 33 pruned.
# [I 2023-07-29 22:25:39,514] Trial 34 pruned.
# [I 2023-07-29 22:27:57,059] Trial 35 finished with value: 0.7108108143548708 and parameters: {'num_filter_1': 24, 'num_filter_2': 12, 'num_filter_3': 20, 'num_fc': 12, 'drop_out_rate_1': 0.15000000000000002, 'drop_out_rate_2': 0.35, 'drop_out_rate_3': 0.15000000000000002, 'optimizer': 'Adam', 'lr': 0.0017540935292184136}. Best is trial 35 with value: 0.7108108143548708.
# [I 2023-07-29 22:27:58,453] Trial 36 pruned.
# [I 2023-07-29 22:30:33,206] Trial 37 finished with value: 0.6689189201271212 and parameters: {'num_filter_1': 28, 'num_filter_2': 12, 'num_filter_3': 24, 'num_fc': 12, 'drop_out_rate_1': 0.1, 'drop_out_rate_2': 0.35, 'drop_out_rate_3': 0.25, 'optimizer': 'Adam', 'lr': 0.003674623637727266}. Best is trial 35 with value: 0.7108108143548708.
# [I 2023-07-29 22:30:34,672] Trial 38 pruned.
# [I 2023-07-29 22:30:36,139] Trial 39 pruned.
# [I 2023-07-29 22:32:53,048] Trial 40 finished with value: 0.6729729735368007 and parameters: {'num_filter_1': 24, 'num_filter_2': 8, 'num_filter_3': 28, 'num_fc': 10, 'drop_out_rate_1': 0.1, 'drop_out_rate_2': 0.25, 'drop_out_rate_3': 0.30000000000000004, 'optimizer': 'Adam', 'lr': 0.001335348578571305}. Best is trial 35 with value: 0.7108108143548708.
# [I 2023-07-29 22:32:54,127] Trial 41 pruned.
# [I 2023-07-29 22:32:55,501] Trial 42 pruned.
# [I 2023-07-29 22:35:16,708] Trial 43 finished with value: 0.6554054074190758 and parameters: {'num_filter_1': 24, 'num_filter_2': 20, 'num_filter_3': 20, 'num_fc': 8, 'drop_out_rate_1': 0.25, 'drop_out_rate_2': 0.30000000000000004, 'drop_out_rate_3': 0.15000000000000002, 'optimizer': 'RMSprop', 'lr': 0.0015421903609239684}. Best is trial 35 with value: 0.7108108143548708.
# [I 2023-07-29 22:35:18,470] Trial 44 pruned.
# [I 2023-07-29 22:37:31,709] Trial 45 finished with value: 0.702702704313639 and parameters: {'num_filter_1': 20, 'num_filter_2': 20, 'num_filter_3': 16, 'num_fc': 12, 'drop_out_rate_1': 0.2, 'drop_out_rate_2': 0.30000000000000004, 'drop_out_rate_3': 0.25, 'optimizer': 'RMSprop', 'lr': 0.0007336066917555987}. Best is trial 35 with value: 0.7108108143548708.
# [I 2023-07-29 22:37:33,086] Trial 46 pruned.
# [I 2023-07-29 22:39:47,985] Trial 47 finished with value: 0.6864864878557824 and parameters: {'num_filter_1': 20, 'num_filter_2': 20, 'num_filter_3': 20, 'num_fc': 12, 'drop_out_rate_1': 0.2, 'drop_out_rate_2': 0.35, 'drop_out_rate_3': 0.25, 'optimizer': 'RMSprop', 'lr': 0.00199133048939271}. Best is trial 35 with value: 0.7108108143548708.
# [I 2023-07-29 22:39:49,134] Trial 48 pruned.
# [I 2023-07-29 22:39:50,711] Trial 49 pruned.
# [I 2023-07-29 22:39:52,216] Trial 50 pruned.
# [I 2023-07-29 22:39:53,559] Trial 51 pruned.
# [I 2023-07-29 22:39:54,944] Trial 52 pruned.
# [I 2023-07-29 22:42:10,421] Trial 53 finished with value: 0.7000000033829663 and parameters: {'num_filter_1': 20, 'num_filter_2': 24, 'num_filter_3': 12, 'num_fc': 12, 'drop_out_rate_1': 0.30000000000000004, 'drop_out_rate_2': 0.35, 'drop_out_rate_3': 0.2, 'optimizer': 'RMSprop', 'lr': 0.0006677124472725522}. Best is trial 35 with value: 0.7108108143548708.
# [I 2023-07-29 22:42:17,300] Trial 54 pruned.
# [I 2023-07-29 22:42:18,699] Trial 55 pruned.
# [I 2023-07-29 22:42:28,807] Trial 56 pruned.
# [I 2023-07-29 22:42:30,516] Trial 57 pruned.
# [I 2023-07-29 22:42:31,492] Trial 58 pruned.
# [I 2023-07-29 22:42:35,746] Trial 59 pruned.
# [I 2023-07-29 22:42:37,216] Trial 60 pruned.
# [I 2023-07-29 22:42:38,631] Trial 61 pruned.
# [I 2023-07-29 22:42:39,631] Trial 62 pruned.
# [I 2023-07-29 22:42:41,026] Trial 63 pruned.
# [I 2023-07-29 22:42:45,348] Trial 64 pruned.
# [I 2023-07-29 22:42:46,756] Trial 65 pruned.
# [I 2023-07-29 22:42:48,275] Trial 66 pruned.
# [I 2023-07-29 22:42:49,300] Trial 67 pruned.
# [I 2023-07-29 22:42:50,961] Trial 68 pruned.
# [I 2023-07-29 22:42:51,989] Trial 69 pruned.
# [I 2023-07-29 22:42:53,621] Trial 70 pruned.
# [I 2023-07-29 22:42:55,287] Trial 71 pruned.
# [I 2023-07-29 22:42:59,563] Trial 72 pruned.
# [I 2023-07-29 22:45:40,031] Trial 73 finished with value: 0.6945946003134186 and parameters: {'num_filter_1': 28, 'num_filter_2': 20, 'num_filter_3': 24, 'num_fc': 10, 'drop_out_rate_1': 0.25, 'drop_out_rate_2': 0.35, 'drop_out_rate_3': 0.2, 'optimizer': 'RMSprop', 'lr': 0.0008728147594926365}. Best is trial 35 with value: 0.7108108143548708.
# [I 2023-07-29 22:45:41,750] Trial 74 pruned.
# [I 2023-07-29 22:48:23,309] Trial 75 finished with value: 0.6797297325085949 and parameters: {'num_filter_1': 28, 'num_filter_2': 24, 'num_filter_3': 28, 'num_fc': 8, 'drop_out_rate_1': 0.30000000000000004, 'drop_out_rate_2': 0.35, 'drop_out_rate_3': 0.25, 'optimizer': 'RMSprop', 'lr': 0.0012522332989755695}. Best is trial 35 with value: 0.7108108143548708.
# [I 2023-07-29 22:48:28,144] Trial 76 pruned.
# [I 2023-07-29 22:48:30,179] Trial 77 pruned.
# [I 2023-07-29 22:48:31,800] Trial 78 pruned.
# [I 2023-07-29 22:48:33,425] Trial 79 pruned.
# [I 2023-07-29 22:48:34,841] Trial 80 pruned.
# [I 2023-07-29 22:48:36,342] Trial 81 pruned.
# [I 2023-07-29 22:48:37,751] Trial 82 pruned.
# [I 2023-07-29 22:48:39,215] Trial 83 pruned.
# [I 2023-07-29 22:48:40,725] Trial 84 pruned.
# [I 2023-07-29 22:48:42,290] Trial 85 pruned.
# [I 2023-07-29 22:48:43,686] Trial 86 pruned.
# [I 2023-07-29 22:48:45,094] Trial 87 pruned.
# [I 2023-07-29 22:50:59,222] Trial 88 finished with value: 0.6905405440846005 and parameters: {'num_filter_1': 20, 'num_filter_2': 20, 'num_filter_3': 8, 'num_fc': 10, 'drop_out_rate_1': 0.25, 'drop_out_rate_2': 0.35, 'drop_out_rate_3': 0.2, 'optimizer': 'Adam', 'lr': 0.0014108592187909203}. Best is trial 35 with value: 0.7108108143548708.
# [I 2023-07-29 22:51:00,707] Trial 89 pruned.
# [I 2023-07-29 22:51:03,824] Trial 90 pruned.
# [I 2023-07-29 22:53:13,980] Trial 91 finished with value: 0.7040540559871776 and parameters: {'num_filter_1': 20, 'num_filter_2': 16, 'num_filter_3': 8, 'num_fc': 10, 'drop_out_rate_1': 0.25, 'drop_out_rate_2': 0.35, 'drop_out_rate_3': 0.2, 'optimizer': 'Adam', 'lr': 0.0010057413534379806}. Best is trial 35 with value: 0.7108108143548708.
# [I 2023-07-29 22:53:15,363] Trial 92 pruned.
# [I 2023-07-29 22:53:16,735] Trial 93 pruned.
# [I 2023-07-29 22:53:17,761] Trial 94 pruned.
# [I 2023-07-29 22:55:35,019] Trial 95 finished with value: 0.6932432442098051 and parameters: {'num_filter_1': 20, 'num_filter_2': 20, 'num_filter_3': 8, 'num_fc': 12, 'drop_out_rate_1': 0.25, 'drop_out_rate_2': 0.35, 'drop_out_rate_3': 0.25, 'optimizer': 'Adam', 'lr': 0.0004596806099464366}. Best is trial 35 with value: 0.7108108143548708.
# [I 2023-07-29 22:55:36,459] Trial 96 pruned.
# [I 2023-07-29 22:55:37,873] Trial 97 pruned.
# [I 2023-07-29 22:55:39,262] Trial 98 pruned.
# [I 2023-07-29 22:55:40,327] Trial 99 pruned.
# [I 2023-07-29 22:55:41,673] Trial 100 pruned.
# [I 2023-07-29 22:55:42,532] Trial 101 pruned.
# [I 2023-07-29 22:55:43,969] Trial 102 pruned.
# [I 2023-07-29 22:55:45,491] Trial 103 pruned.
# [I 2023-07-29 22:55:46,913] Trial 104 pruned.
# [I 2023-07-29 22:55:48,232] Trial 105 pruned.
# [I 2023-07-29 22:55:49,739] Trial 106 pruned.
# [I 2023-07-29 22:55:50,893] Trial 107 pruned.
# [I 2023-07-29 22:55:52,417] Trial 108 pruned.
# [I 2023-07-29 22:55:54,190] Trial 109 pruned.
# [I 2023-07-29 22:58:35,516] Trial 110 finished with value: 0.647297301606552 and parameters: {'num_filter_1': 28, 'num_filter_2': 24, 'num_filter_3': 12, 'num_fc': 8, 'drop_out_rate_1': 0.30000000000000004, 'drop_out_rate_2': 0.30000000000000004, 'drop_out_rate_3': 0.25, 'optimizer': 'Adam', 'lr': 0.0018565688198483787}. Best is trial 35 with value: 0.7108108143548708.
# [I 2023-07-29 22:58:37,000] Trial 111 pruned.
# [I 2023-07-29 22:58:38,503] Trial 112 pruned.
# [I 2023-07-29 22:58:39,825] Trial 113 pruned.
# [I 2023-07-29 22:58:41,445] Trial 114 pruned.
# [I 2023-07-29 22:58:43,111] Trial 115 pruned.
# [I 2023-07-29 22:58:44,521] Trial 116 pruned.
# [I 2023-07-29 22:58:46,083] Trial 117 pruned.
# [I 2023-07-29 23:01:14,249] Trial 118 finished with value: 0.6932432462234754 and parameters: {'num_filter_1': 28, 'num_filter_2': 16, 'num_filter_3': 8, 'num_fc': 4, 'drop_out_rate_1': 0.25, 'drop_out_rate_2': 0.35, 'drop_out_rate_3': 0.2, 'optimizer': 'RMSprop', 'lr': 0.0011173114198674166}. Best is trial 35 with value: 0.7108108143548708.
# [I 2023-07-29 23:01:15,911] Trial 119 pruned.
# [I 2023-07-29 23:01:17,537] Trial 120 pruned.
# [I 2023-07-29 23:01:19,098] Trial 121 pruned.
# [I 2023-07-29 23:01:20,446] Trial 122 pruned.
# [I 2023-07-29 23:01:21,741] Trial 123 pruned.
# [I 2023-07-29 23:01:23,375] Trial 124 pruned.
# [I 2023-07-29 23:01:25,130] Trial 125 pruned.
# [I 2023-07-29 23:03:40,171] Trial 126 finished with value: 0.7202702732505025 and parameters: {'num_filter_1': 20, 'num_filter_2': 20, 'num_filter_3': 20, 'num_fc': 12, 'drop_out_rate_1': 0.2, 'drop_out_rate_2': 0.35, 'drop_out_rate_3': 0.2, 'optimizer': 'RMSprop', 'lr': 0.0006975645498881012}. Best is trial 126 with value: 0.7202702732505025.
# [I 2023-07-29 23:03:41,562] Trial 127 pruned.
# [I 2023-07-29 23:03:43,090] Trial 128 pruned.
# [I 2023-07-29 23:03:44,199] Trial 129 pruned.
# [I 2023-07-29 23:03:45,605] Trial 130 pruned.
# [I 2023-07-29 23:03:46,430] Trial 131 pruned.
# [I 2023-07-29 23:03:47,817] Trial 132 pruned.
# [I 2023-07-29 23:03:49,187] Trial 133 pruned.
# [I 2023-07-29 23:05:54,631] Trial 134 finished with value: 0.6999999997583596 and parameters: {'num_filter_1': 20, 'num_filter_2': 8, 'num_filter_3': 32, 'num_fc': 12, 'drop_out_rate_1': 0.25, 'drop_out_rate_2': 0.35, 'drop_out_rate_3': 0.2, 'optimizer': 'RMSprop', 'lr': 0.0010401456668542534}. Best is trial 126 with value: 0.7202702732505025.
# [I 2023-07-29 23:05:55,991] Trial 135 pruned.
# [I 2023-07-29 23:05:57,404] Trial 136 pruned.
# [I 2023-07-29 23:05:58,671] Trial 137 pruned.
# [I 2023-07-29 23:06:00,117] Trial 138 pruned.
# [I 2023-07-29 23:06:07,465] Trial 139 pruned.
# [I 2023-07-29 23:06:08,546] Trial 140 pruned.
# [I 2023-07-29 23:08:35,266] Trial 141 finished with value: 0.6743243272240097 and parameters: {'num_filter_1': 24, 'num_filter_2': 16, 'num_filter_3': 24, 'num_fc': 10, 'drop_out_rate_1': 0.25, 'drop_out_rate_2': 0.35, 'drop_out_rate_3': 0.2, 'optimizer': 'RMSprop', 'lr': 0.00045803461813408364}. Best is trial 126 with value: 0.7202702732505025.
# [I 2023-07-29 23:08:36,932] Trial 142 pruned.
# [I 2023-07-29 23:08:46,805] Trial 143 pruned.
# [I 2023-07-29 23:08:48,329] Trial 144 pruned.
# [I 2023-07-29 23:08:49,675] Trial 145 pruned.
# [I 2023-07-29 23:08:51,162] Trial 146 pruned.
# [I 2023-07-29 23:08:52,579] Trial 147 pruned.
# [I 2023-07-29 23:08:54,251] Trial 148 pruned.
# [I 2023-07-29 23:08:55,947] Trial 149 pruned.
# [I 2023-07-29 23:08:57,409] Trial 150 pruned.
# [I 2023-07-29 23:08:58,861] Trial 151 pruned.
# [I 2023-07-29 23:09:00,315] Trial 152 pruned.
# [I 2023-07-29 23:09:01,773] Trial 153 pruned.
# [I 2023-07-29 23:09:03,174] Trial 154 pruned.
# [I 2023-07-29 23:09:04,470] Trial 155 pruned.
# [I 2023-07-29 23:09:06,080] Trial 156 pruned.
# [I 2023-07-29 23:09:07,510] Trial 157 pruned.
# [I 2023-07-29 23:09:08,882] Trial 158 pruned.
# [I 2023-07-29 23:09:10,297] Trial 159 pruned.
# [I 2023-07-29 23:09:11,315] Trial 160 pruned.
# [I 2023-07-29 23:09:12,806] Trial 161 pruned.
# [I 2023-07-29 23:11:33,729] Trial 162 finished with value: 0.697297299633155 and parameters: {'num_filter_1': 24, 'num_filter_2': 16, 'num_filter_3': 12, 'num_fc': 4, 'drop_out_rate_1': 0.30000000000000004, 'drop_out_rate_2': 0.30000000000000004, 'drop_out_rate_3': 0.15000000000000002, 'optimizer': 'RMSprop', 'lr': 0.00022797432384921845}. Best is trial 126 with value: 0.7202702732505025.
# [I 2023-07-29 23:11:35,247] Trial 163 pruned.
# [I 2023-07-29 23:11:36,705] Trial 164 pruned.
# [I 2023-07-29 23:11:38,231] Trial 165 pruned.
# [I 2023-07-29 23:11:39,973] Trial 166 pruned.
# [I 2023-07-29 23:11:41,580] Trial 167 pruned.
# [I 2023-07-29 23:11:43,359] Trial 168 pruned.
# [I 2023-07-29 23:11:45,019] Trial 169 pruned.
# [I 2023-07-29 23:11:46,995] Trial 170 pruned.
# [I 2023-07-29 23:11:49,122] Trial 171 pruned.
# [I 2023-07-29 23:14:10,470] Trial 172 finished with value: 0.6945945991052164 and parameters: {'num_filter_1': 24, 'num_filter_2': 16, 'num_filter_3': 12, 'num_fc': 4, 'drop_out_rate_1': 0.30000000000000004, 'drop_out_rate_2': 0.30000000000000004, 'drop_out_rate_3': 0.15000000000000002, 'optimizer': 'RMSprop', 'lr': 0.00021286980469104277}. Best is trial 126 with value: 0.7202702732505025.
# [I 2023-07-29 23:14:11,913] Trial 173 pruned.
# [I 2023-07-29 23:14:13,540] Trial 174 pruned.
# [I 2023-07-29 23:14:15,038] Trial 175 pruned.
# [I 2023-07-29 23:14:16,365] Trial 176 pruned.
# [I 2023-07-29 23:14:17,873] Trial 177 pruned.
# [I 2023-07-29 23:14:19,359] Trial 178 pruned.
# [I 2023-07-29 23:14:20,974] Trial 179 pruned.
# [I 2023-07-29 23:14:22,400] Trial 180 pruned.
# [I 2023-07-29 23:14:23,898] Trial 181 pruned.
# [I 2023-07-29 23:14:25,250] Trial 182 pruned.
# [I 2023-07-29 23:14:26,738] Trial 183 pruned.
# [I 2023-07-29 23:16:47,996] Trial 184 finished with value: 0.687837839529321 and parameters: {'num_filter_1': 24, 'num_filter_2': 20, 'num_filter_3': 12, 'num_fc': 4, 'drop_out_rate_1': 0.30000000000000004, 'drop_out_rate_2': 0.30000000000000004, 'drop_out_rate_3': 0.15000000000000002, 'optimizer': 'RMSprop', 'lr': 0.0005211614115558103}. Best is trial 126 with value: 0.7202702732505025.
# [I 2023-07-29 23:19:12,581] Trial 185 finished with value: 0.6905405412654619 and parameters: {'num_filter_1': 24, 'num_filter_2': 20, 'num_filter_3': 12, 'num_fc': 6, 'drop_out_rate_1': 0.30000000000000004, 'drop_out_rate_2': 0.30000000000000004, 'drop_out_rate_3': 0.15000000000000002, 'optimizer': 'RMSprop', 'lr': 0.0004918064841782448}. Best is trial 126 with value: 0.7202702732505025.
# [I 2023-07-29 23:19:14,065] Trial 186 pruned.
# [I 2023-07-29 23:19:15,516] Trial 187 pruned.
# [I 2023-07-29 23:19:17,284] Trial 188 pruned.
# [I 2023-07-29 23:19:18,682] Trial 189 pruned.
# [I 2023-07-29 23:19:20,292] Trial 190 pruned.
# [I 2023-07-29 23:19:38,850] Trial 191 pruned.
# [I 2023-07-29 23:19:39,923] Trial 192 pruned.
# [I 2023-07-29 23:19:41,470] Trial 193 pruned.
# [I 2023-07-29 23:19:43,003] Trial 194 pruned.
# [I 2023-07-29 23:19:44,659] Trial 195 pruned.
# [I 2023-07-29 23:19:46,212] Trial 196 pruned.
# [I 2023-07-29 23:19:47,757] Trial 197 pruned.
# [I 2023-07-29 23:19:49,464] Trial 198 pruned.
# [I 2023-07-29 23:19:51,049] Trial 199 pruned.

# %%
# Find number of pruned and completed trials
pruned_trials = study.get_trials(deepcopy=False, states=[TrialState.PRUNED])
complete_trials = study.get_trials(deepcopy=False, states=[TrialState.COMPLETE])

# %%
# Display the study statistics
print("\nStudy statistics: ")
print("  Number of finished trials: ", len(study.trials))
print("  Number of pruned trials: ", len(pruned_trials))
print("  Number of complete trials: ", len(complete_trials))
# Out:
# Study statistics:
#   Number of finished trials:  200
#   Number of pruned trials:  160
#   Number of complete trials:  40

# %%
trial = study.best_trial
print("Best trial:")
print("  Value: ", trial.value)
print("  Params: ")
for key, value in trial.params.items():
    print("    {}: {}".format(key, value))
# Out:
# Best trial:
#   Value:  0.7202702732505025
#   Params:
#     num_filter_1: 20
#     num_filter_2: 20
#     num_filter_3: 20
#     num_fc: 12
#     drop_out_rate_1: 0.2
#     drop_out_rate_2: 0.35
#     drop_out_rate_3: 0.2
#     optimizer: RMSprop
#     lr: 0.0006975645498881012

# %%
# Save results to csv file
hyper_df = study.trials_dataframe().drop(
    ["datetime_start", "datetime_complete", "duration"], axis=1
)  # Exclude columns
hyper_df = hyper_df.loc[
    hyper_df["state"] == "COMPLETE"
]  # Keep only results that did not prune
hyper_df = hyper_df.drop("state", axis=1)  # Exclude state column
hyper_df = hyper_df.sort_values("value")  # Sort based on accuracy
hyper_df.to_csv("../data/optuna_results_2d.csv", index=False)  # Save to csv file

# %%
# Display results in a dataframe
print("\nOverall Results (ordered by accuracy):\n")
hyper_df
# Out:
# Overall Results (ordered by accuracy):
#      number     value  params_drop_out_rate_1  params_drop_out_rate_2  \
# 1         1  0.555405                    0.25                    0.35
# 4         4  0.567568                    0.25                    0.35
# 3         3  0.645946                    0.10                    0.25
# 110     110  0.647297                    0.30                    0.30
# 24       24  0.652703                    0.15                    0.30
# 15       15  0.654054                    0.20                    0.35
# 43       43  0.655405                    0.25                    0.30
# 37       37  0.668919                    0.10                    0.35
# 40       40  0.672973                    0.10                    0.25
# 26       26  0.674324                    0.25                    0.30
# 2         2  0.674324                    0.20                    0.20
# 141     141  0.674324                    0.25                    0.35
# 13       13  0.678378                    0.30                    0.30
# 75       75  0.679730                    0.30                    0.35
# 23       23  0.679730                    0.30                    0.35
# 11       11  0.681081                    0.35                    0.30
# 5         5  0.686486                    0.10                    0.35
# 47       47  0.686486                    0.20                    0.35
# 9         9  0.686486                    0.15                    0.15
# 12       12  0.686486                    0.30                    0.30
# 184     184  0.687838                    0.30                    0.30
# 21       21  0.687838                    0.25                    0.35
# 18       18  0.689189                    0.25                    0.35
# 0         0  0.689189                    0.30                    0.30
# 185     185  0.690541                    0.30                    0.30
# 88       88  0.690541                    0.25                    0.35
# 95       95  0.693243                    0.25                    0.35
# 118     118  0.693243                    0.25                    0.35
# 31       31  0.694595                    0.25                    0.35
# 172     172  0.694595                    0.30                    0.30
# 73       73  0.694595                    0.25                    0.35
# 8         8  0.695946                    0.30                    0.35
# 162     162  0.697297                    0.30                    0.30
# 134     134  0.700000                    0.25                    0.35
# 53       53  0.700000                    0.30                    0.35
# 22       22  0.701351                    0.25                    0.35
# 45       45  0.702703                    0.20                    0.30
# 91       91  0.704054                    0.25                    0.35
# 35       35  0.710811                    0.15                    0.35
# 126     126  0.720270                    0.20                    0.35
#
#      params_drop_out_rate_3  params_lr  params_num_fc  params_num_filter_1  \
# 1                      0.35   0.000029              8                   20
# 4                      0.30   0.020155             10                    4
# 3                      0.20   0.000012             10                   32
# 110                    0.25   0.001857              8                   28
# 24                     0.15   0.001300             12                   32
# 15                     0.20   0.001103              4                   24
# 43                     0.15   0.001542              8                   24
# 37                     0.25   0.003675             12                   28
# 40                     0.30   0.001335             10                   24
# 26                     0.10   0.002260              8                   24
# 2                      0.25   0.001936              8                    4
# 141                    0.20   0.000458             10                   24
# 13                     0.15   0.000442              2                   28
# 75                     0.25   0.001252              8                   28
# 23                     0.25   0.000244             12                   28
# 11                     0.10   0.000263              4                   28
# 5                      0.25   0.000078             12                   16
# 47                     0.25   0.001991             12                   20
# 9                      0.25   0.000915              6                   20
# 12                     0.15   0.000276              4                   24
# 184                    0.15   0.000521              4                   24
# 21                     0.20   0.000523             10                   24
# 18                     0.20   0.000551             10                   24
# 0                      0.15   0.000355              4                   20
# 185                    0.15   0.000492              6                   24
# 88                     0.20   0.001411             10                   20
# 95                     0.25   0.000460             12                   20
# 118                    0.20   0.001117              4                   28
# 31                     0.20   0.000616             10                   24
# 172                    0.15   0.000213              4                   24
# 73                     0.20   0.000873             10                   28
# 8                      0.20   0.000789             10                   28
# 162                    0.15   0.000228              4                   24
# 134                    0.20   0.001040             12                   20
# 53                     0.20   0.000668             12                   20
# 22                     0.20   0.000582             12                   24
# 45                     0.25   0.000734             12                   20
# 91                     0.20   0.001006             10                   20
# 35                     0.15   0.001754             12                   24
# 126                    0.20   0.000698             12                   20
#
#      params_num_filter_2  params_num_filter_3 params_optimizer
# 1                     20                   12              SGD
# 4                     32                   20             Adam
# 3                     12                   24             Adam
# 110                   24                   12             Adam
# 24                    12                   28          RMSprop
# 15                    16                   28             Adam
# 43                    20                   20          RMSprop
# 37                    12                   24             Adam
# 40                     8                   28             Adam
# 26                    16                   32          RMSprop
# 2                     24                   28              SGD
# 141                   16                   24          RMSprop
# 13                    24                   32          RMSprop
# 75                    24                   28          RMSprop
# 23                    20                   24          RMSprop
# 11                    12                   12          RMSprop
# 5                      8                   20             Adam
# 47                    20                   20          RMSprop
# 9                     20                    8             Adam
# 12                    16                   12          RMSprop
# 184                   20                   12          RMSprop
# 21                    16                   28          RMSprop
# 18                    16                   24          RMSprop
# 0                     20                   12          RMSprop
# 185                   20                   12          RMSprop
# 88                    20                    8             Adam
# 95                    20                    8             Adam
# 118                   16                    8          RMSprop
# 31                    16                   24          RMSprop
# 172                   16                   12          RMSprop
# 73                    20                   24          RMSprop
# 8                     16                   28             Adam
# 162                   16                   12          RMSprop
# 134                    8                   32          RMSprop
# 53                    24                   12          RMSprop
# 22                    16                   24          RMSprop
# 45                    20                   16          RMSprop
# 91                    16                    8             Adam
# 35                    12                   20             Adam
# 126                   20                   20          RMSprop

# %%
# Find the most important hyperparameters
most_important_parameters = optuna.importance.get_param_importances(study, target=None)

# %%
# Display the most important hyperparameters
print("\nMost important hyperparameters:")
for key, value in most_important_parameters.items():
    print("  {}:{}{:.2f}%".format(key, (15 - len(key)) * " ", value * 100))
# Out:
# Most important hyperparameters:
#   drop_out_rate_3:50.60%
#   lr:             14.60%
#   num_filter_2:   12.17%
#   optimizer:      4.83%
#   drop_out_rate_1:4.13%
#   drop_out_rate_2:3.68%
#   num_filter_1:   3.48%
#   num_filter_3:   3.26%
#   num_fc:         3.25%

# %% [markdown]
# ## 2.6. Model Training

# %%
trial.params
# Out:
# {'num_filter_1': 20,
#  'num_filter_2': 20,
#  'num_filter_3': 20,
#  'num_fc': 12,
#  'drop_out_rate_1': 0.2,
#  'drop_out_rate_2': 0.35,
#  'drop_out_rate_3': 0.2,
#  'optimizer': 'RMSprop',
#  'lr': 0.0006975645498881012}

# %%
model = ConvolutionalNeuralNetwork(
    trial,
    num_filter_1=trial.params["num_filter_1"],
    num_filter_2=trial.params["num_filter_2"],
    num_filter_3=trial.params["num_filter_3"],
    num_fc=trial.params["num_fc"],
    drop_out_rate_1=trial.params["drop_out_rate_1"],
    drop_out_rate_2=trial.params["drop_out_rate_2"],
    drop_out_rate_3=trial.params["drop_out_rate_3"],
)

# %%
def trainer(model, criterion, optimizer, trainloader, validloader, epochs=5, patience=5, verbose=True):
    """Simple training wrapper for PyTorch network."""
    
    train_loss, valid_loss, train_accuracy, valid_accuracy = [], [], [], []
    for epoch in range(epochs):  # for each epoch
        train_batch_loss = 0
        valid_batch_loss = 0
        train_batch_acc = 0
        valid_batch_acc = 0
        
        # Training
        for X, y in trainloader:
            optimizer.zero_grad()       # Zero all the gradients w.r.t. parameters
            # X = X.to(device)
            # y = y.to(device)
            y_hat = model(X)  # forward pass to get output
            y_hat_labels = torch.sigmoid(y_hat) > 0.5
            loss = criterion(y_hat, y.unsqueeze(1))  # Calculate loss based on output
            loss.backward()             # Calculate gradients w.r.t. parameters
            optimizer.step()            # Update parameters
            train_batch_loss += loss.item()  # Add loss for this batch to running total
            train_batch_acc += (y_hat_labels.squeeze() == y).type(torch.float32).mean().item()
        train_loss.append(train_batch_loss / len(trainloader))
        train_accuracy.append(train_batch_acc / len(trainloader))  # accuracy
        
        # Validation
        model.eval()
        with torch.no_grad():  # this stops pytorch doing computational graph stuff under-the-hood and saves memory and time
            for X, y in validloader:
                # X = X.to(device)
                # y = y.to(device)
                y_hat = model(X)  # forward pass to get output
                y_hat_labels = torch.sigmoid(y_hat) > 0.5
                loss = criterion(y_hat, y.unsqueeze(1))
                valid_batch_loss += loss.item()
                valid_batch_acc += (y_hat_labels.squeeze() == y).type(torch.float32).mean().item()
        valid_loss.append(valid_batch_loss / len(validloader))
        valid_accuracy.append(valid_batch_acc / len(validloader))  # accuracy
        
        model.train()
        
        # Print progress
        if verbose:
            if (epoch+1) % 100 == 0:
                print(f"Epoch {epoch + 1}:",
                      f"Train Loss: {train_loss[-1]:.3f}.",
                      f"Valid Loss: {valid_loss[-1]:.3f}.",
                      f"Train Accuracy: {train_accuracy[-1]:.2f}."
                      f"Valid Accuracy: {valid_accuracy[-1]:.2f}.")
            
        # Early stopping
        if epoch > 0 and valid_loss[-1] > valid_loss[-2]:
            consec_increases += 1
        else:
            consec_increases = 0
        if consec_increases == patience:
            print(f"Stopped early at epoch {epoch + 1} - val loss increased for {consec_increases} consecutive epochs!")
            break
        
    print("\nTraining ended.")
    
    loss_fig = pd.DataFrame({"train_loss": train_loss, "valid_loss": valid_loss}).plot.line()
    loss_fig.set_xlabel('Epoch')
    loss_fig.set_ylabel('Loss');
    
    accur_fig = pd.DataFrame({"train_accuracy": train_accuracy, "valid_accuracy": valid_accuracy}).plot.line()
    accur_fig.set_xlabel('Epoch')
    accur_fig.set_ylabel('Accuracy');

# %%
model.apply(weights_init)
# Out:
# ConvolutionalNeuralNetwork(
#   (main): Sequential(
#     (0): Conv2d(8, 20, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): MaxPool2d(kernel_size=(2, 2), stride=(2, 2), padding=0, dilation=1, ceil_mode=False)
#     (3): Dropout(p=0.2, inplace=False)
#     (4): Conv2d(20, 20, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (5): ReLU()
#     (6): MaxPool2d(kernel_size=(2, 2), stride=(2, 2), padding=0, dilation=1, ceil_mode=False)
#     (7): Dropout(p=0.35, inplace=False)
#     (8): Conv2d(20, 20, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (9): ReLU()
#     (10): MaxPool2d(kernel_size=(2, 2), stride=(2, 2), padding=0, dilation=1, ceil_mode=False)
#     (11): Dropout(p=0.2, inplace=False)
#     (12): Flatten(start_dim=1, end_dim=-1)
#     (13): Linear(in_features=180, out_features=12, bias=True)
#     (14): ReLU()
#     (15): Linear(in_features=12, out_features=1, bias=True)
#   )
# )

# %%
criterion = nn.BCEWithLogitsLoss()
optimizer = getattr(optim, trial.params["optimizer"])(
    model.parameters(), lr=trial.params["lr"]
)

# %%
trainer(model, criterion, optimizer, trainloader, validloader, epochs=2001, patience=5, verbose=True)
# Out:
# Epoch 100: Train Loss: 0.374. Valid Loss: 0.681. Train Accuracy: 0.84.Valid Accuracy: 0.68.
# Epoch 200: Train Loss: 0.297. Valid Loss: 0.737. Train Accuracy: 0.87.Valid Accuracy: 0.68.
# Epoch 300: Train Loss: 0.262. Valid Loss: 0.776. Train Accuracy: 0.89.Valid Accuracy: 0.68.
# Epoch 400: Train Loss: 0.220. Valid Loss: 1.056. Train Accuracy: 0.90.Valid Accuracy: 0.67.
# Stopped early at epoch 416 - val loss increased for 5 consecutive epochs!
#
# Training ended.

# %% [markdown]
# ## 2.5. Accuracy on Test Set

# %%
test_accuracy = []
test_batch_acc = 0

model.eval()
with torch.no_grad():
    for X, y in testloader:
        y_hat = model(X)  # forward pass to get output
        y_hat_labels = torch.sigmoid(y_hat) > 0.5
        test_batch_acc += (y_hat_labels.squeeze() == y).type(torch.float32).mean().item()
        
test_accuracy.append(test_batch_acc / len(testloader))  # accuracy

# %%
test_accuracy
# Out:
# [0.7710045651622015]

# %% [markdown]
# ## 2.6. Prediction

# %%
model.eval()
with torch.no_grad():
    wea, lab = next(iter(testloader))
    y_prob = torch.sigmoid(model(wea)[0])
    y_class = int(y_prob > 0.5)
    print(f"Prbability of Bad Air Quality: {y_prob.item():.3g}")
    fig, axs = plt.subplots(nrows=2, ncols=4)
    r = 0
    c = 0
    for j in range(8):
        axs[r, c].imshow(weather[0, j, :])
        axs[r, c].set_title(f"{feature_names[j]}")
        if c < 3:
            c += 1
        else:
            r += 1
            c = 0
    fig.suptitle(f"Air Quality Bad? {bool(lab[0])}")
    plt.tight_layout()
    plt.show();
# Out:
# Prbability of Bad Air Quality: 0.238
